# %% [markdown]
# <a href="https://colab.research.google.com/github/UlrikeDetective/code/blob/main/ADK_Learning_tool_multi_agents.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🚀 Welcome to Your ADK Adventure - MultiAgents! 🚀
#
# Welcome back, Agent Architect! This notebook dives into the heart of the Google Agent Development Kit (ADK): orchestrating teams of specialized agents to tackle complex, multi-step problems that a single agent cannot handle alone.
#
# By the end of this session, you will be an expert in advanced agentic workflows:
#
# - **SequentialAgent**: You'll learn to chain agents together, creating pipelines where the output of one agent becomes the input for the next.
#
# - **LoopAgent**: You'll build iterative systems where agents can plan, critique, and refine their work until a specific goal is met, making them "perfectionists."
#
# - **ParallelAgent**: You'll unleash efficiency by running multiple agents simultaneously and then synthesizing their collective findings into a single, comprehensive answer.
#
# - **The Router**: You will construct a "master" router agent that intelligently analyzes a user's request and delegates it to the correct agent or workflow.
#
# Let's get this adventure started!

# %% [markdown]
# ## Author
#
# HI, I'm Qingyue (Annie) Wang, a developer advocate and AI engineer at **Google**, passionate about helping developers build with AI and cloud technologies :)
#
#
# If you have questions with this notebook, contact me on [LinkedIn](https://www.linkedin.com/in/anniewangtech/) , [X](https://twitter.com/anniewangtech) or email anniewangtech0510@Gmail.com
#
#
# ```
#
#   (\__/)
#   (•ㅅ•)
#   /づ  📚       Enjoy learning AI Agents :)
#
#
# ```

# %% [markdown]
# -------------
# ### 🎁 🛑 Important Prerequisite: Setup Your Environment! 🛑 🎁
# -----------------------------------------------------------------------------
#
# 👉 **Get Your API Key HERE**: https://codelabs.developers.google.com/onramp/instructions#0
#
#  -----------------------------------------------------------------------------

# %% [markdown]
# ```
#  ⬆️  ⬆️  ⬆️  ⬆️  ⬆️  ⬆️  ⬆️  ⬆️  ⬆️  ⬆️  ⬆️  ⬆️  ⬆️  ⬆️  ⬆️
#    /\_/\     /\_/\     /\_/\      /\_/\       /\_/\
#   ( ^_^ )   ( -.- )   ( >_< )   ( =^.^= )    ( o_o )
# ```

# %% [markdown]
# ## Part 0: Setup & Authentication 🔑
#
# First things first, let's get all our tools ready. This step installs the necessary libraries and securely configures your Google API key so your agents can access the power of Gemini.

# %%
# !pip install google-adk google-generativeai -q

# --- Import all necessary libraries for our entire adventure ---
import os
import re
import asyncio
from IPython.display import display, Markdown
import google.generativeai as genai
from google.adk.agents import Agent, SequentialAgent, LoopAgent, ParallelAgent
from google.adk.tools import google_search, ToolContext
from google.adk.runners import Runner
from google.adk.sessions import InMemorySessionService, Session
from google.genai.types import Content, Part
from getpass import getpass

print("✅ All libraries are ready to go!")
# Out:
# ✅ All libraries are ready to go!
# /usr/local/lib/python3.12/dist-packages/pydantic/_internal/_fields.py:198: UserWarning: Field name "config_type" in "SequentialAgent" shadows an attribute in parent "BaseAgent"
#   warnings.warn(

# %%
# --- Securely Configure Your API Key ---

# Prompt the user for their API key securely
api_key = getpass('Enter your Google API Key: ')

# Get Your API Key HERE 👉 https://codelabs.developers.google.com/onramp/instructions#0
# Configure the generative AI library with the provided key
genai.configure(api_key=api_key)

# Set the API key as an environment variable for ADK to use
os.environ['GOOGLE_API_KEY'] = api_key

print("✅ API Key configured successfully! Let the fun begin.")
# Out:
# Enter your Google API Key: ··········
# ✅ API Key configured successfully! Let the fun begin.

# %%
# --- A Helper Function to Run Our Agents ---
# We'll use this function throughout the notebook to make running queries easy.

async def run_agent_query(agent: Agent, query: str, session: Session, user_id: str, is_router: bool = False):
    """Initializes a runner and executes a query for a given agent and session."""
    print(f"\n🚀 Running query for agent: '{agent.name}' in session: '{session.id}'...")

    runner = Runner(
        agent=agent,
        session_service=session_service,
        app_name=agent.name
    )

    final_response = ""
    try:
        async for event in runner.run_async(
            user_id=user_id,
            session_id=session.id,
            new_message=Content(parts=[Part(text=query)], role="user")
        ):
            if not is_router:
                # Let's see what the agent is thinking!
                print(f"EVENT: {event}")
            if event.is_final_response():
                final_response = event.content.parts[0].text
    except Exception as e:
        final_response = f"An error occurred: {e}"

    if not is_router:
     print("\n" + "-"*50)
     print("✅ Final Response:")
     display(Markdown(final_response))
     print("-"*50 + "\n")

    return final_response

# --- Initialize our Session Service ---
# This one service will manage all the different sessions in our notebook.
session_service = InMemorySessionService()
my_user_id = "adk_adventurer_001"

# %% [markdown]
# ---
# ## Part 1: Multi-Agent Mayhem - Sequential Workflows 🧠→🤖→🤖
#
# You've mastered single agents and memory. Now for the most advanced topic: making agents **work together in a sequence**.
#
# Some tasks are too complex for one agent. A user might ask, "Find me a great restaurant and then tell me how to get there." This requires two different skills: food recommendation and navigation.
#
# We'll build a system that can handle this by:
# 1.  Creating a new `transportation_agent` 🚗.
# 2.  Teaching our `router_agent` 🧠 to recognize these special "combo" requests.
# 3.  Writing Python code (the "orchestrator") that runs the agents in a sequence, passing the output of the first agent to the second.

# %% [markdown]
# ```
#                     +---------------------+
#                     |    User Query 🗣️     |
#                     +----------+----------+
#                                |
#                                v
#                     +---------------------+
#                     |   Router Agent 🤖    |
#                     |  (Classify Request) |
#                     +----------+----------+
#                                |
#           +--------------------+----------------------+
#           |                    |                      |
#           v                    v                      v
#   +----------------+   +--------------------+  +----------------------+
#   |  foodie_agent  |   | weekend_guide_agent|  |  day_trip_agent      |
#   |  🍣 Food Search |   | 🎉 Event Discovery |  | 🧳 Trip Planner       |
#   +----------------+   +--------------------+  +----------------------+
#           |
#           v
#   +----------------------------+            (if combo request)
#   |  Restaurant Recommendation |---------------------------+
#   |  ex: "Best sushi is at X"  |                           |
#   +----------------------------+                           v
#                                                         +-----------------------+
#                                                         | transportation_agent  |
#                                                         | 🚗 Get Directions      |
#                                                         +-----------------------+
#                                                         | Input: origin, place  |
#                                                         | Output: directions    |
#                                                         +-----------------------+
#
# Final Output: 🍽️ Recommendation + 🚗 Route Info
# ```

# %%
# --- Agent Definitions for our Specialist Team ---
# --- Agent Definition ---

day_trip_agent = Agent(
    name="day_trip_agent",
    model="gemini-2.5-flash",
    description="Agent specialized in generating spontaneous full-day itineraries based on mood, interests, and budget.",
    instruction="""
    You are the "Spontaneous Day Trip" Generator 🚗 - a specialized AI assistant that creates engaging full-day itineraries.

    Your Mission:
    Transform a simple mood or interest into a complete day-trip adventure with real-time details, while respecting a budget.

    Guidelines:
    1. **Budget-Aware**: Pay close attention to budget hints like 'cheap', 'affordable', or 'splurge'. Use Google Search to find activities (free museums, parks, paid attractions) that match the user's budget.
    2. **Full-Day Structure**: Create morning, afternoon, and evening activities.
    3. **Real-Time Focus**: Search for current operating hours and special events.
    4. **Mood Matching**: Align suggestions with the requested mood (adventurous, relaxing, artsy, etc.).

    RETURN itinerary in MARKDOWN FORMAT with clear time blocks and specific venue names.
    """,
    tools=[google_search]
)

foodie_agent = Agent(
    name="foodie_agent",
    model="gemini-2.5-flash",
    tools=[google_search],
    instruction="You are an expert food critic. Your goal is to find the absolute best food, restaurants, or culinary experiences based on a user's request. When you recommend a place, state its name clearly. For example: 'The best sushi is at **Jin Sho**.'"
)

weekend_guide_agent = Agent(
    name="weekend_guide_agent",
    model="gemini-2.5-flash",
    tools=[google_search],
    instruction="You are a local events guide. Your task is to find interesting events, concerts, festivals, and activities happening on a specific weekend."
)

transportation_agent = Agent(
    name="transportation_agent",
    model="gemini-2.5-flash",
    tools=[google_search],
    instruction="You are a navigation assistant. Given a starting point and a destination, provide clear directions on how to get from the start to the end."
)

# --- The Brain of the Operation: The Router Agent ---
# We update the router's instructions to know about the new 'combo' task.
router_agent = Agent(
    name="router_agent",
    model="gemini-2.5-flash",
    instruction="""
    You are a request router. Your job is to analyze a user's query and decide which of the following agents or workflows is best suited to handle it.
    Do not answer the query yourself, only return the name of the most appropriate choice.

    Available Options:
    - 'foodie_agent': For queries *only* about food, restaurants, or eating.
    - 'weekend_guide_agent': For queries about events, concerts, or activities happening on a specific timeframe like a weekend.
    - 'day_trip_agent': A general planner for any other day trip requests.
    - 'find_and_navigate_combo': Use this for complex queries that ask to *first find a place* and *then get directions* to it.

    Only return the single, most appropriate option's name and nothing else.
    """
)

# We'll create a dictionary of all our individual worker agents
worker_agents = {
    "day_trip_agent": day_trip_agent,
    "foodie_agent": foodie_agent,
    "weekend_guide_agent": weekend_guide_agent,
    "transportation_agent": transportation_agent, # Add the new agent!
}

print("🤖 Agent team assembled for sequential workflows!")
# Out:
# 🤖 Agent team assembled for sequential workflows!

# %%
# --- Let's Test the Sequential Workflow! ---

async def run_sequential_app():
    queries = [
        "I want to eat the best ramen in Palo Alto.", # Should go to foodie_agent
        "Are there any cool outdoor concerts this weekend in the San Francisco Bay Area?", # Should go to weekend_guide_agent
        "Find me the best ramen in Palo Alto and then tell me how to get there from the Caltrain station." # Should trigger the COMBO
    ]

    for query in queries:
        print(f"\n{'='*60}\n🗣️ Processing New Query: '{query}'\n{'='*60}")

        # 1. Ask the Router Agent to choose the right agent or workflow
        router_session = await session_service.create_session(app_name=router_agent.name, user_id=my_user_id)
        print("🧠 Asking the router agent to make a decision...")
        chosen_route = await run_agent_query(router_agent, query, router_session, my_user_id, is_router=True)
        chosen_route = chosen_route.strip().replace("'", "")
        print(f"🚦 Router has selected route: '{chosen_route}'")

        # 2. Execute the chosen route
        if chosen_route == 'find_and_navigate_combo':
            print("\n--- Starting Find and Navigate Combo Workflow ---")

            # STEP 2a: Run the foodie_agent first
            foodie_session = await session_service.create_session(app_name=foodie_agent.name, user_id=my_user_id)
            foodie_response = await run_agent_query(foodie_agent, query, foodie_session, my_user_id)

            # STEP 2b: Extract the destination from the first agent's response
            # (This is a simple regex, a more robust solution might use a structured output format)
            match = re.search(r'\*\*(.*?)\*\*', foodie_response)
            if not match:
                print("🚨 Could not determine the restaurant name from the response.")
                continue
            destination = match.group(1)
            print(f"💡 Extracted Destination: {destination}")

            # STEP 2c: Create a new query and run the transportation_agent
            directions_query = f"Give me directions to {destination} from the Palo Alto Caltrain station."
            print(f"\n🗣️ New Query for Transport Agent: '{directions_query}'")
            transport_session = await session_service.create_session(app_name=transportation_agent.name, user_id=my_user_id)
            await run_agent_query(transportation_agent, directions_query, transport_session, my_user_id)

            print("--- Combo Workflow Complete ---")

        elif chosen_route in worker_agents:
            # This is a simple, single-agent route
            worker_agent = worker_agents[chosen_route]
            worker_session = await session_service.create_session(app_name=worker_agent.name, user_id=my_user_id)
            await run_agent_query(worker_agent, query, worker_session, my_user_id)
        else:
            print(f"🚨 Error: Router chose an unknown route: '{chosen_route}'")

await run_sequential_app()
# Out:
# ============================================================
# 🗣️ Processing New Query: 'I want to eat the best ramen in Palo Alto.'
# ============================================================
# 🧠 Asking the router agent to make a decision...
#
# 🚀 Running query for agent: 'router_agent' in session: '5582daa0-68be-4bd4-b6a7-87d519186bb4'...
# 🚦 Router has selected route: 'foodie_agent'
#
# 🚀 Running query for agent: 'foodie_agent' in session: '1dc89700-ebaa-4165-83cf-c50cb28621d0'...
# EVENT: content=Content(
#   parts=[
#     Part(
#       text="""The best ramen in Palo Alto is at **Ramen Nagi**.
#
# Consistently praised by critics and diners alike, Ramen Nagi is frequently cited as the top ramen spot in Palo Alto and even across the wider Bay Area. It's recognized for its exceptional broth, high-quality ingredients, and extensive customization options, allowing diners to tailor their perfect bowl. The restaurant's popularity often results in long lines, a testament to its highly regarded ramen. Ramen Nagi also earned a spot on Yelp's list of the top 100 ramen shops in California, coming in at number 21."""
#     ),
#   ],
#   role='model'
# ) grounding_metadata=GroundingMetadata(
#   grounding_chunks=[
#     GroundingChunk(
#       web=GroundingChunkWeb(
#         title='tiktok.com',
#         uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQG1hQZ4PZ3ZCN350mWLQOQXCiM0j4j45aWu81rSUsUlBVeFjv8Y6RupprkfNV2943xZ3PbG3Dckz8RpArhmfA0-fBdv6cd_3MMs6kyhA19TGxf4Y32V-KoO83jOll_f8OylaGO5BWMrGRnTy2kK-sTkd-MxhW8Glg=='
#       )
#     ),
#     GroundingChunk(
#       web=GroundingChunkWeb(
#         title='quora.com',
#         uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQFkkNlL7A04gAIeYCMa1JcXZF06MrxnDRzWS9pgOin-Bsdubfhv530W8gxDttPaqdNdfFlq-cLgrnijsCOMIFruWn5gSaIloxfttSABdWwWC0fYh9Ot8T3cMSZlbC08MxtuplydLltEVwhbHIqFadxBt-DZeDUcLFMc2kE2y0ic'
#       )
#     ),
#     GroundingChunk(
#       web=GroundingChunkWeb(
#         title='reddit.com',
#         uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQGOt9vZLIRbDazL6o1glXSx3ubMC4P7Jo1bDwkam68xpRRLrCFUk9hyy6gQWRd5ToofvZd0QPZrClpV9neIl6XSSP_Etja_tPKNeVNNGZVdZSOI_jB3bP9sjXYR5Mq838kid01qCGtsLpC-cvmZs3IQKuXzgkJzQZQiJH7WReJL4KLTwcFc_JvF8289GP4fn6p5Z0-0pqWYycr6_SL6'
#       )
#     ),
#     GroundingChunk(
#       web=GroundingChunkWeb(
#         title='quora.com',
#         uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQEvDrh5Zj0xj62CsQ9V8QOmZpyyOSvZj0QqTxxXOvVXzOTOETi8xAv8DofsAYzEFo389gUXtfZFY2PVM6r6kylATfjrXNLailZSeiw20SAwPYYFIXVbyGIckVKnBZJD2Io1Vu6cP0PV1dgowN7L73LshOk8lXPMFRST_g=='
#       )
#     ),
#     GroundingChunk(
#       web=GroundingChunkWeb(
#         title='sfgate.com',
#         uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQFcz3J6mJQuZkmAZ4ceWEDXNI6d1NFKdZLyC51pDNuwTu1-fz24HgsZXW3tbhdCSOE7F759ATTLG85aZ0wkk274lrZi6Keo1vC_yxkIDpz9IfXrPxSVTw9azvTuy8lw2NBb5M0Yf4a80sjzVZJ9Z1u1051zd6WQZtyIg5J7R2TJFwJ29As='
#       )
#     ),
#   ],
#   grounding_supports=[
#     GroundingSupport(
#       grounding_chunk_indices=[
#         0,
#         1,
#         2,
#         3,
#       ],
#       segment=Segment(
#         end_index=202,
#         start_index=51,
#         text='Consistently praised by critics and diners alike, Ramen Nagi is frequently cited as the top ramen spot in Palo Alto and even across the wider Bay Area.'
#       )
#     ),
#     GroundingSupport(
#       grounding_chunk_indices=[
#         3,
#       ],
#       segment=Segment(
#         end_index=354,
#         start_index=203,
#         text="It's recognized for its exceptional broth, high-quality ingredients, and extensive customization options, allowing diners to tailor their perfect bowl."
#       )
#     ),
#     GroundingSupport(
#       grounding_chunk_indices=[
#         0,
#         1,
#       ],
#       segment=Segment(
#         end_index=453,
#         start_index=355,
#         text="The restaurant's popularity often results in long lines, a testament to its highly regarded ramen."
#       )
#     ),
#     GroundingSupport(
#       grounding_chunk_indices=[
#         4,
#       ],
#       segment=Segment(
#         end_index=564,
#         start_index=454,
#         text="Ramen Nagi also earned a spot on Yelp's list of the top 100 ramen shops in California, coming in at number 21."
#       )
#     ),
#   ],
#   search_entry_point=SearchEntryPoint(
#     rendered_content="""<style>
# .container {
#   align-items: center;
#   border-radius: 8px;
#   display: flex;
#   font-family: Google Sans, Roboto, sans-serif;
#   font-size: 14px;
#   line-height: 20px;
#   padding: 8px 12px;
# }
# .chip {
#   display: inline-block;
#   border: solid 1px;
#   border-radius: 16px;
#   min-width: 14px;
#   padding: 5px 16px;
#   text-align: center;
#   user-select: none;
#   margin: 0 8px;
#   -webkit-tap-highlight-color: transparent;
# }
# .carousel {
#   overflow: auto;
#   scrollbar-width: none;
#   white-space: nowrap;
#   margin-right: -12px;
# }
# .headline {
#   display: flex;
#   margin-right: 4px;
# }
# .gradient-container {
#   position: relative;
# }
# .gradient {
#   position: absolute;
#   transform: translate(3px, -9px);
#   height: 36px;
#   width: 9px;
# }
# @media (prefers-color-scheme: light) {
#   .container {
#     background-color: #fafafa;
#     box-shadow: 0 0 0 1px #0000000f;
#   }
#   .headline-label {
#     color: #1f1f1f;
#   }
#   .chip {
#     background-color: #ffffff;
#     border-color: #d2d2d2;
#     color: #5e5e5e;
#     text-decoration: none;
#   }
#   .chip:hover {
#     background-color: #f2f2f2;
#   }
#   .chip:focus {
#     background-color: #f2f2f2;
#   }
#   .chip:active {
#     background-color: #d8d8d8;
#     border-color: #b6b6b6;
#   }
#   .logo-dark {
#     display: none;
#   }
#   .gradient {
#     background: linear-gradient(90deg, #fafafa 15%, #fafafa00 100%);
#   }
# }
# @media (prefers-color-scheme: dark) {
#   .container {
#     background-color: #1f1f1f;
#     box-shadow: 0 0 0 1px #ffffff26;
#   }
#   .headline-label {
#     color: #fff;
#   }
#   .chip {
#     background-color: #2c2c2c;
#     border-color: #3c4043;
#     color: #fff;
#     text-decoration: none;
#   }
#   .chip:hover {
#     background-color: #353536;
#   }
#   .chip:focus {
#     background-color: #353536;
#   }
#   .chip:active {
#     background-color: #464849;
#     border-color: #53575b;
#   }
#   .logo-light {
#     display: none;
#   }
#   .gradient {
#     background: linear-gradient(90deg, #1f1f1f 15%, #1f1f1f00 100%);
#   }
# }
# </style>
# <div class="container">
#   <div class="headline">
#     <svg class="logo-light" width="18" height="18" viewBox="9 9 35 35" fill="none" xmlns="http://www.w3.org/2000/svg">
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M42.8622 27.0064C42.8622 25.7839 42.7525 24.6084 42.5487 23.4799H26.3109V30.1568H35.5897C35.1821 32.3041 33.9596 34.1222 32.1258 35.3448V39.6864H37.7213C40.9814 36.677 42.8622 32.2571 42.8622 27.0064V27.0064Z" fill="#4285F4"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M26.3109 43.8555C30.9659 43.8555 34.8687 42.3195 37.7213 39.6863L32.1258 35.3447C30.5898 36.3792 28.6306 37.0061 26.3109 37.0061C21.8282 37.0061 18.0195 33.9811 16.6559 29.906H10.9194V34.3573C13.7563 39.9841 19.5712 43.8555 26.3109 43.8555V43.8555Z" fill="#34A853"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M16.6559 29.8904C16.3111 28.8559 16.1074 27.7588 16.1074 26.6146C16.1074 25.4704 16.3111 24.3733 16.6559 23.3388V18.8875H10.9194C9.74388 21.2072 9.06992 23.8247 9.06992 26.6146C9.06992 29.4045 9.74388 32.022 10.9194 34.3417L15.3864 30.8621L16.6559 29.8904V29.8904Z" fill="#FBBC05"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M26.3109 16.2386C28.85 16.2386 31.107 17.1164 32.9095 18.8091L37.8466 13.8719C34.853 11.082 30.9659 9.3736 26.3109 9.3736C19.5712 9.3736 13.7563 13.245 10.9194 18.8875L16.6559 23.3388C18.0195 19.2636 21.8282 16.2386 26.3109 16.2386V16.2386Z" fill="#EA4335"/>
#     </svg>
#     <svg class="logo-dark" width="18" height="18" viewBox="0 0 48 48" xmlns="http://www.w3.org/2000/svg">
#       <circle cx="24" cy="23" fill="#FFF" r="22"/>
#       <path d="M33.76 34.26c2.75-2.56 4.49-6.37 4.49-11.26 0-.89-.08-1.84-.29-3H24.01v5.99h8.03c-.4 2.02-1.5 3.56-3.07 4.56v.75l3.91 2.97h.88z" fill="#4285F4"/>
#       <path d="M15.58 25.77A8.845 8.845 0 0 0 24 31.86c1.92 0 3.62-.46 4.97-1.31l4.79 3.71C31.14 36.7 27.65 38 24 38c-5.93 0-11.01-3.4-13.45-8.36l.17-1.01 4.06-2.85h.8z" fill="#34A853"/>
#       <path d="M15.59 20.21a8.864 8.864 0 0 0 0 5.58l-5.03 3.86c-.98-2-1.53-4.25-1.53-6.64 0-2.39.55-4.64 1.53-6.64l1-.22 3.81 2.98.22 1.08z" fill="#FBBC05"/>
#       <path d="M24 14.14c2.11 0 4.02.75 5.52 1.98l4.36-4.36C31.22 9.43 27.81 8 24 8c-5.93 0-11.01 3.4-13.45 8.36l5.03 3.85A8.86 8.86 0 0 1 24 14.14z" fill="#EA4335"/>
#     </svg>
#     <div class="gradient-container"><div class="gradient"></div></div>
#   </div>
#   <div class="carousel">
#     <a class="chip" href="https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQEwpnFJrTHj_IRPMZT4i5v4X_CIno0LmC69T_zOGmObiNhHqqVivoTO40q8nHef6vALTqK-FYorefp1rDkugVc7cdvjHuPvtUbwWTfrVhWbQTts9cEQip5FiOT_UDMepH5OdtAOZb2MZNCm9wB-vwgwjLstjNp91yB5EpA0zL_C6ngdEdG7ukckM-jIoQrhQQK8d3Dt_MmWCMXwOYboG5zJ">highest rated ramen Palo Alto</a>
#     <a class="chip" href="https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQHN9izmN0cAuXG3w2oKr6FeZXeEDID6T5unfaROO7zv0xDIE2ZJJXI2pZKgU6lFhTlsFamhqPC_3vvhuW3Vkg3XBedLXI4mKOAZri243N0-s0MhkYZjk-n5d92D22ERVE2aK5LdDgbrzsXcHn1wmRcc3NYP0maXuWYaMaPoRQHEEfqHN-xqgZTYKtHlg-uYVbWbbkgvHVBp">best ramen Palo Alto</a>
#     <a class="chip" href="https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQGLUndTVaxryZaXRvWjiDQ_nLkj0ANiy_eDgZlfI4yi8ffXI6JF4Ncc6F7pYDjybL-fxhEtoE-DyLVeprEoTxOzdl3OgThi6pqHzMKsMnM2qt_4-PMZLuG7OFK33Kwf9ZFFel_w6z3F4EdAWK0iSS0alwRM2zBRBk-4oKf7wfqpUc__jV3z1dOMzi0JhOzhdLBsO7Osv5BqZKOE2TqwlYTb8vRd9xHNVh627Q==">top ramen restaurants Palo Alto reviews</a>
#   </div>
# </div>
# """
#   ),
#   web_search_queries=[
#     'best ramen Palo Alto',
#     'highest rated ramen Palo Alto',
#     'top ramen restaurants Palo Alto reviews',
#   ]
# ) partial=None turn_complete=None error_code=None error_message=None interrupted=None custom_metadata=None usage_metadata=GenerateContentResponseUsageMetadata(
#   candidates_token_count=154,
#   prompt_token_count=84,
#   prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=84
#     ),
#   ],
#   thoughts_token_count=212,
#   tool_use_prompt_token_count=169,
#   tool_use_prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=169
#     ),
#   ],
#   total_token_count=619
# ) live_session_resumption_update=None invocation_id='e-4870d103-7e69-4860-bef9-3ebee432bc2d' author='foodie_agent' actions=EventActions(skip_summarization=None, state_delta={}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}) long_running_tool_ids=None branch=None id='0a56ea2e-7db4-406f-8711-016b6a992c09' timestamp=1755966091.992405
#
# --------------------------------------------------
# ✅ Final Response:
# The best ramen in Palo Alto is at **Ramen Nagi**.
#
# Consistently praised by critics and diners alike, Ramen Nagi is frequently cited as the top ramen spot in Palo Alto and even across the wider Bay Area. It's recognized for its exceptional broth, high-quality ingredients, and extensive customization options, allowing diners to tailor their perfect bowl. The restaurant's popularity often results in long lines, a testament to its highly regarded ramen. Ramen Nagi also earned a spot on Yelp's list of the top 100 ramen shops in California, coming in at number 21.
# --------------------------------------------------
#
#
# ============================================================
# 🗣️ Processing New Query: 'Are there any cool outdoor concerts this weekend in the San Francisco Bay Area?'
# ============================================================
# 🧠 Asking the router agent to make a decision...
#
# 🚀 Running query for agent: 'router_agent' in session: '07e3f4fb-03ad-4280-a90e-5e51a0b00186'...
# 🚦 Router has selected route: 'weekend_guide_agent'
#
# 🚀 Running query for agent: 'weekend_guide_agent' in session: 'dfd12216-cda3-4b8b-9db7-552f90f76de1'...
# EVENT: content=Content(
#   parts=[
#     Part(
#       text="""Here are some cool outdoor concerts and music-related events happening this weekend, August 23-24, 2025, in the San Francisco Bay Area:
#
# **Saturday, August 23, 2025**
#
# *   **Oakland Chinatown StreetFest (Oakland)**: Celebrate heritage at this annual party spanning eight blocks, featuring live entertainment, cultural performances, and local cuisine.
# *   **Rock the Dock Concert Series (Redwood City)**: Enjoy live music at 475 Seaport Blvd.
# *   **SF Chinatown's Hungry Ghost Festival (San Francisco)**: Chinatown becomes a vibrant hub with music, art, a procession, and rituals to ward off evil forces.
# *   **SF's "Fern Alley Music Series" feat. Brad Nofal and Friends (Polk Gulch, San Francisco)**: Catch a free outdoor music performance.
#
# **Sunday, August 24, 2025**
#
# *   **Oakland Chinatown StreetFest (Oakland)**: The festivities continue for a second day with live entertainment, cultural performances, and local cuisine.
# *   **Golden Gate Bandshell: Crucial Reggae Sunday (Golden Gate Park, San Francisco)**: Enjoy reggae music in a beautiful outdoor setting."""
#     ),
#   ],
#   role='model'
# ) grounding_metadata=GroundingMetadata(
#   grounding_chunks=[
#     GroundingChunk(
#       web=GroundingChunkWeb(
#         title='visitcalifornia.com',
#         uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQHG4aWee4vNSaN-ve3TmR7-CR5DgWInNnYh6oxUvRPfMqTg-YpOm5xCkFZ7KYibTV8_96Gb6WhGQ3zEm2N6WyK1-layOlJF9kteZMWzI_lRMoodEQPYtXAQqvZmfThy1aoWDtVJU4nEG8AK274T2jucc7sAvF35v1Fcq6rJlt2o'
#       )
#     ),
#     GroundingChunk(
#       web=GroundingChunkWeb(
#         title='funcheap.com',
#         uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQH3zCeQdiMWS64mEcwHnkQxXcTtsIz74lxmr4nqNIikZBhBkW40UHsjzdhUEMnw1WRGqt6P15aP1nx7iBNu4u1J_OE_VQVYLhBdmExQlQ-RM2tms1LfqJMXGUPDb53ITtaxkQgLYhR4_kEVeVbi22vyLjjb8LVChBGsZPAh79I='
#       )
#     ),
#     GroundingChunk(
#       web=GroundingChunkWeb(
#         title='thesanfranciscopeninsula.com',
#         uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQHQO0pgfx3ByRs10RfI0XsF8azPE0STQ1AkUIoa6Nosip3-wpzF7FzAJGTYx4MrCRb-SFZpuk2UPZLYzkDA5N1Hhno6NgzzQZARgKauiHG0GPkW70k5flbLdFAS-0BHuFEkwrDgIPY0Tj4Ii7UxyHyot-GhTgBLbE14jBEQZbIqO-DqPGdFrh8DqLz61zB9qxrXubMgnHSI3KDLUDbRkc_amU0J00RoY1Uj5k_gqI-M8XIHDiFvI4bGZm4VxH21QiETyw0dBRWSgQ=='
#       )
#     ),
#     GroundingChunk(
#       web=GroundingChunkWeb(
#         title='sftravel.com',
#         uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQElqomCxSZMkKcexiMjeaXdqFcrzBU4Kbf79vRov-2MJATK5tL-Ef1wKpdk2Aix_y4nbaZMuLmfqd2riWS4yRVrY7k0GJtJ_aIDXA4TT210NQAsXqWGQE7zi-XHfUrA7mEovqrFshu_1oZ3QbxTJ0dM1gzrro725eT8Vt2RAYaQw54='
#       )
#     ),
#     GroundingChunk(
#       web=GroundingChunkWeb(
#         title='funcheap.com',
#         uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQFkPxDpFdW9O1CtPdfqr-a0t7VYrQaeaMyeRQIWVgad1eC8eEgavmg2NyUHLu7Em-gqPhZLfUAVt55Yd_Go7qX_RyO_sJOBIdB4u7nHIwfQjPs72IyqDXEo-BZxSJgM'
#       )
#     ),
#     <... 1 more items ...>,
#   ],
#   grounding_supports=[
#     GroundingSupport(
#       grounding_chunk_indices=[
#         0,
#         1,
#       ],
#       segment=Segment(
#         end_index=350,
#         start_index=168,
#         text='*   **Oakland Chinatown StreetFest (Oakland)**: Celebrate heritage at this annual party spanning eight blocks, featuring live entertainment, cultural performances, and local cuisine.'
#       )
#     ),
#     GroundingSupport(
#       grounding_chunk_indices=[
#         2,
#       ],
#       segment=Segment(
#         end_index=441,
#         start_index=351,
#         text='*   **Rock the Dock Concert Series (Redwood City)**: Enjoy live music at 475 Seaport Blvd.'
#       )
#     ),
#     GroundingSupport(
#       grounding_chunk_indices=[
#         3,
#         4,
#       ],
#       segment=Segment(
#         end_index=603,
#         start_index=442,
#         text="*   **SF Chinatown's Hungry Ghost Festival (San Francisco)**: Chinatown becomes a vibrant hub with music, art, a procession, and rituals to ward off evil forces."
#       )
#     ),
#     GroundingSupport(
#       grounding_chunk_indices=[
#         1,
#         4,
#       ],
#       segment=Segment(
#         end_index=740,
#         start_index=647,
#         text='Brad Nofal and Friends (Polk Gulch, San Francisco)**: Catch a free outdoor music performance.'
#       )
#     ),
#     GroundingSupport(
#       grounding_chunk_indices=[
#         0,
#         1,
#       ],
#       segment=Segment(
#         end_index=927,
#         start_index=771,
#         text='*   **Oakland Chinatown StreetFest (Oakland)**: The festivities continue for a second day with live entertainment, cultural performances, and local cuisine.'
#       )
#     ),
#     <... 1 more items ...>,
#   ],
#   search_entry_point=SearchEntryPoint(
#     rendered_content="""<style>
# .container {
#   align-items: center;
#   border-radius: 8px;
#   display: flex;
#   font-family: Google Sans, Roboto, sans-serif;
#   font-size: 14px;
#   line-height: 20px;
#   padding: 8px 12px;
# }
# .chip {
#   display: inline-block;
#   border: solid 1px;
#   border-radius: 16px;
#   min-width: 14px;
#   padding: 5px 16px;
#   text-align: center;
#   user-select: none;
#   margin: 0 8px;
#   -webkit-tap-highlight-color: transparent;
# }
# .carousel {
#   overflow: auto;
#   scrollbar-width: none;
#   white-space: nowrap;
#   margin-right: -12px;
# }
# .headline {
#   display: flex;
#   margin-right: 4px;
# }
# .gradient-container {
#   position: relative;
# }
# .gradient {
#   position: absolute;
#   transform: translate(3px, -9px);
#   height: 36px;
#   width: 9px;
# }
# @media (prefers-color-scheme: light) {
#   .container {
#     background-color: #fafafa;
#     box-shadow: 0 0 0 1px #0000000f;
#   }
#   .headline-label {
#     color: #1f1f1f;
#   }
#   .chip {
#     background-color: #ffffff;
#     border-color: #d2d2d2;
#     color: #5e5e5e;
#     text-decoration: none;
#   }
#   .chip:hover {
#     background-color: #f2f2f2;
#   }
#   .chip:focus {
#     background-color: #f2f2f2;
#   }
#   .chip:active {
#     background-color: #d8d8d8;
#     border-color: #b6b6b6;
#   }
#   .logo-dark {
#     display: none;
#   }
#   .gradient {
#     background: linear-gradient(90deg, #fafafa 15%, #fafafa00 100%);
#   }
# }
# @media (prefers-color-scheme: dark) {
#   .container {
#     background-color: #1f1f1f;
#     box-shadow: 0 0 0 1px #ffffff26;
#   }
#   .headline-label {
#     color: #fff;
#   }
#   .chip {
#     background-color: #2c2c2c;
#     border-color: #3c4043;
#     color: #fff;
#     text-decoration: none;
#   }
#   .chip:hover {
#     background-color: #353536;
#   }
#   .chip:focus {
#     background-color: #353536;
#   }
#   .chip:active {
#     background-color: #464849;
#     border-color: #53575b;
#   }
#   .logo-light {
#     display: none;
#   }
#   .gradient {
#     background: linear-gradient(90deg, #1f1f1f 15%, #1f1f1f00 100%);
#   }
# }
# </style>
# <div class="container">
#   <div class="headline">
#     <svg class="logo-light" width="18" height="18" viewBox="9 9 35 35" fill="none" xmlns="http://www.w3.org/2000/svg">
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M42.8622 27.0064C42.8622 25.7839 42.7525 24.6084 42.5487 23.4799H26.3109V30.1568H35.5897C35.1821 32.3041 33.9596 34.1222 32.1258 35.3448V39.6864H37.7213C40.9814 36.677 42.8622 32.2571 42.8622 27.0064V27.0064Z" fill="#4285F4"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M26.3109 43.8555C30.9659 43.8555 34.8687 42.3195 37.7213 39.6863L32.1258 35.3447C30.5898 36.3792 28.6306 37.0061 26.3109 37.0061C21.8282 37.0061 18.0195 33.9811 16.6559 29.906H10.9194V34.3573C13.7563 39.9841 19.5712 43.8555 26.3109 43.8555V43.8555Z" fill="#34A853"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M16.6559 29.8904C16.3111 28.8559 16.1074 27.7588 16.1074 26.6146C16.1074 25.4704 16.3111 24.3733 16.6559 23.3388V18.8875H10.9194C9.74388 21.2072 9.06992 23.8247 9.06992 26.6146C9.06992 29.4045 9.74388 32.022 10.9194 34.3417L15.3864 30.8621L16.6559 29.8904V29.8904Z" fill="#FBBC05"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M26.3109 16.2386C28.85 16.2386 31.107 17.1164 32.9095 18.8091L37.8466 13.8719C34.853 11.082 30.9659 9.3736 26.3109 9.3736C19.5712 9.3736 13.7563 13.245 10.9194 18.8875L16.6559 23.3388C18.0195 19.2636 21.8282 16.2386 26.3109 16.2386V16.2386Z" fill="#EA4335"/>
#     </svg>
#     <svg class="logo-dark" width="18" height="18" viewBox="0 0 48 48" xmlns="http://www.w3.org/2000/svg">
#       <circle cx="24" cy="23" fill="#FFF" r="22"/>
#       <path d="M33.76 34.26c2.75-2.56 4.49-6.37 4.49-11.26 0-.89-.08-1.84-.29-3H24.01v5.99h8.03c-.4 2.02-1.5 3.56-3.07 4.56v.75l3.91 2.97h.88z" fill="#4285F4"/>
#       <path d="M15.58 25.77A8.845 8.845 0 0 0 24 31.86c1.92 0 3.62-.46 4.97-1.31l4.79 3.71C31.14 36.7 27.65 38 24 38c-5.93 0-11.01-3.4-13.45-8.36l.17-1.01 4.06-2.85h.8z" fill="#34A853"/>
#       <path d="M15.59 20.21a8.864 8.864 0 0 0 0 5.58l-5.03 3.86c-.98-2-1.53-4.25-1.53-6.64 0-2.39.55-4.64 1.53-6.64l1-.22 3.81 2.98.22 1.08z" fill="#FBBC05"/>
#       <path d="M24 14.14c2.11 0 4.02.75 5.52 1.98l4.36-4.36C31.22 9.43 27.81 8 24 8c-5.93 0-11.01 3.4-13.45 8.36l5.03 3.85A8.86 8.86 0 0 1 24 14.14z" fill="#EA4335"/>
#     </svg>
#     <div class="gradient-container"><div class="gradient"></div></div>
#   </div>
#   <div class="carousel">
#     <a class="chip" href="https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQFND-TQry44okzwgCIwSINRylZvYNEf6rbrntgbYDeeQ2QvgYf1KEJZXTTKVEHjMk3perxGZou7ABKfdI7UIkaxri-EfvIEuTjlMfT98blYWdVqfCyv89xzCWYoVXenkzjrzegg0OT8vEXZ4tKsZjMyr-qKswDYbUTJwBPLdnA6IuDeJBgVfclMMMd5xLlkV6K2r9SVuBKDE5Y8hGRJ9TohIsGQoYSt86Q3_WHc-6F8ureBauaAgfsBRGaIpg==">music festivals San Francisco Bay Area August 23-24 2025</a>
#     <a class="chip" href="https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQGZOx1Rr74K68IURS1aOdA8NPB7tHKA6xB_hYsGIwytZVYSbao9_MPT4_Rbb-vZ3EVN2sP_ueFIFSlnZIt3Q9X16_Xy03kwTczEkaYDfbdL8iQbHZG6c1HTS6TU-te73aFtrr5aMvUDVO5zVXoQzazOkiAoFbTy9AFKIw-GhDsHaQP7zStre54moClVJpg5wr3Ar2B_KYEFa8BgqmLUqlyI3FFYQpsLgA5ei_gWuZxQ_4Z5HESTlWOPsQXxl3M=">outdoor concerts San Francisco Bay Area August 23-24 2025</a>
#     <a class="chip" href="https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQF2B3gEpCBWnRRSEKm_-yzEEcqO8aq0EJvIFHOPCW5QJBO2LtdO1dOgcffob-1oLWO_gxZKsEFGsir0jWiAcDzKJcIE_hE8RvjqPEn_LYJLMp72Az74hJBny79VeAAoxgjMY_AykbBsficJ7KofCuckegnJvoDiXeQsPl4tnrIz-MO5sYS5Dh3y6Lqx4fYM5IIkkZ8LnJBeiSqOWVQVxywGuDAE3UxGnue7SkImmNHxtMS2phv3GQG8eZCR4x26PiFQkd7rhB2PBDq273gY">live music events San Francisco Bay Area this weekend outdoor August 2025</a>
#   </div>
# </div>
# """
#   ),
#   web_search_queries=[
#     'outdoor concerts San Francisco Bay Area August 23-24 2025',
#     'music festivals San Francisco Bay Area August 23-24 2025',
#     'live music events San Francisco Bay Area this weekend outdoor August 2025',
#   ]
# ) partial=None turn_complete=None error_code=None error_message=None interrupted=None custom_metadata=None usage_metadata=GenerateContentResponseUsageMetadata(
#   candidates_token_count=334,
#   prompt_token_count=61,
#   prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=61
#     ),
#   ],
#   thoughts_token_count=520,
#   tool_use_prompt_token_count=237,
#   tool_use_prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=237
#     ),
#   ],
#   total_token_count=1152
# ) live_session_resumption_update=None invocation_id='e-744d8174-88ac-43a5-9d7a-563f51912ba8' author='weekend_guide_agent' actions=EventActions(skip_summarization=None, state_delta={}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}) long_running_tool_ids=None branch=None id='8621c808-ceaa-4375-be86-86dcecfd25c9' timestamp=1755966103.575498
#
# --------------------------------------------------
# ✅ Final Response:
# Here are some cool outdoor concerts and music-related events happening this weekend, August 23-24, 2025, in the San Francisco Bay Area:
#
# **Saturday, August 23, 2025**
#
# *   **Oakland Chinatown StreetFest (Oakland)**: Celebrate heritage at this annual party spanning eight blocks, featuring live entertainment, cultural performances, and local cuisine.
# *   **Rock the Dock Concert Series (Redwood City)**: Enjoy live music at 475 Seaport Blvd.
# *   **SF Chinatown's Hungry Ghost Festival (San Francisco)**: Chinatown becomes a vibrant hub with music, art, a procession, and rituals to ward off evil forces.
# *   **SF's "Fern Alley Music Series" feat. Brad Nofal and Friends (Polk Gulch, San Francisco)**: Catch a free outdoor music performance.
#
# **Sunday, August 24, 2025**
#
# *   **Oakland Chinatown StreetFest (Oakland)**: The festivities continue for a second day with live entertainment, cultural performances, and local cuisine.
# *   **Golden Gate Bandshell: Crucial Reggae Sunday (Golden Gate Park, San Francisco)**: Enjoy reggae music in a beautiful outdoor setting.
# --------------------------------------------------
#
#
# ============================================================
# 🗣️ Processing New Query: 'Find me the best sushi in Palo Alto and then tell me how to get there from the Caltrain station.'
# ============================================================
# 🧠 Asking the router agent to make a decision...
#
# 🚀 Running query for agent: 'router_agent' in session: '14183e05-4391-4c15-8368-d6f8405b4681'...
# 🚦 Router has selected route: 'find_and_navigate_combo'
#
# --- Starting Find and Navigate Combo Workflow ---
#
# 🚀 Running query for agent: 'foodie_agent' in session: '110f2fc9-22bc-48fc-b884-bca2449d7580'...
# EVENT: content=Content(
#   parts=[
#     Part(
#       text="""The absolute best sushi in Palo Alto is at **Jin Sho**. Reviewers consistently praise its incredibly fresh fish, with the otoro and uni often highlighted as melting in your mouth.
#
# **Jin Sho** is located at 454 California Avenue, Palo Alto, California 94306.
#
# To get to Jin Sho from the Palo Alto Caltrain Station (95 University Avenue, Palo Alto), you have a couple of options:
#
# **By Walking:**
# The walk is approximately 1.6 miles and will take about 31 minutes.
#
# **By Taxi or Rideshare:**
# A taxi or rideshare would be the fastest option, taking around 3 minutes and costing approximately $12-$15."""
#     ),
#   ],
#   role='model'
# ) grounding_metadata=GroundingMetadata(
#   grounding_chunks=[
#     GroundingChunk(
#       web=GroundingChunkWeb(
#         title='jinshorestaurant.com',
#         uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQErwD2u6jH5FY-3V_lZY_4Xw4KURhU-evIDyznHPXnmv7vYAjjutJ4hpXtW9GroHoCjrtzzPMbiQcwkoPP8rs_z_6AP9apWggR_D_5F4hwT7XV1gRuYhNkX2zQ97g=='
#       )
#     ),
#     GroundingChunk(
#       web=GroundingChunkWeb(
#         title='netwaiter.com',
#         uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQF7yYzoqFsR8-e5rr6MB3mwyNsNRbgvQvssKPTe89xOW41skSXYZsnjZhexMUmHKtf55N6lxUM6Bp7ndernkIZrnASSzcoUtfBPML6EqN3_wcBT7JBxHGhH'
#       )
#     ),
#     GroundingChunk(
#       web=GroundingChunkWeb(
#         title='aaa.com',
#         uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQGxjQDAL6WPGQlyOtv4ZxD_0Rt8A0_5tf95kBEmvqPhBtcbjStsvGNsNqs-Y8rznYOHnbcUxoxRqY30qCYjUFgyKjmoCwGJOa-WX9KI2U4MnzhfI9tT9CBjT1C8g01ZV8725nRpDXnYZxIjwe9aLZ3cE-4r'
#       )
#     ),
#     GroundingChunk(
#       web=GroundingChunkWeb(
#         title='sfbaytransit.org',
#         uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQEw8qHJUg377T113CWnU9l18vttmcSoDyB4ARPlJjbEqBqwF68EOUoLiSeMM6GuSEkLNRSqdT-I5G66X6yaKrFZtESVkQ9IWmNHRJ_1PP8vYOSwHEUThnGM3Hs4AwY4xEEureN_ZmXpnlQeaD6Lzw=='
#       )
#     ),
#     GroundingChunk(
#       web=GroundingChunkWeb(
#         title='waze.com',
#         uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQHej-dfJBSYgJo6hBlcswP8CVaa5_L1sJnHqeXW1rYliyDss0m4ONnI7_R7gofR_l7Po8d0uI164UOslcfgaSuwZOSqgDl93oLzmuzgLainu2Tc3Mgxu-JxUmfXl4Cv8nV5VZ6yXZqqYOtsM8X8Js2Py5NLBkQTGqf16fIdICI9UcJSp9-v6YXuXBZugUTS_PWEQxGcV0lOKViczhrZV0u4qHEljCtFa53ySY-0pn5b6c-H-A=='
#       )
#     ),
#     <... 2 more items ...>,
#   ],
#   grounding_supports=[
#     GroundingSupport(
#       grounding_chunk_indices=[
#         0,
#       ],
#       segment=Segment(
#         end_index=179,
#         start_index=56,
#         text='Reviewers consistently praise its incredibly fresh fish, with the otoro and uni often highlighted as melting in your mouth.'
#       )
#     ),
#     GroundingSupport(
#       grounding_chunk_indices=[
#         0,
#         1,
#         2,
#       ],
#       segment=Segment(
#         end_index=258,
#         start_index=181,
#         text='**Jin Sho** is located at 454 California Avenue, Palo Alto, California 94306.'
#       )
#     ),
#     GroundingSupport(
#       grounding_chunk_indices=[
#         3,
#         4,
#         5,
#       ],
#       segment=Segment(
#         end_index=346,
#         start_index=260,
#         text='To get to Jin Sho from the Palo Alto Caltrain Station (95 University Avenue, Palo Alto'
#       )
#     ),
#     GroundingSupport(
#       grounding_chunk_indices=[
#         6,
#       ],
#       segment=Segment(
#         end_index=463,
#         start_index=380,
#         text="""**By Walking:**
# The walk is approximately 1.6 miles and will take about 31 minutes."""
#       )
#     ),
#     GroundingSupport(
#       grounding_chunk_indices=[
#         6,
#       ],
#       segment=Segment(
#         end_index=598,
#         start_index=465,
#         text="""**By Taxi or Rideshare:**
# A taxi or rideshare would be the fastest option, taking around 3 minutes and costing approximately $12-$15."""
#       )
#     ),
#   ],
#   search_entry_point=SearchEntryPoint(
#     rendered_content="""<style>
# .container {
#   align-items: center;
#   border-radius: 8px;
#   display: flex;
#   font-family: Google Sans, Roboto, sans-serif;
#   font-size: 14px;
#   line-height: 20px;
#   padding: 8px 12px;
# }
# .chip {
#   display: inline-block;
#   border: solid 1px;
#   border-radius: 16px;
#   min-width: 14px;
#   padding: 5px 16px;
#   text-align: center;
#   user-select: none;
#   margin: 0 8px;
#   -webkit-tap-highlight-color: transparent;
# }
# .carousel {
#   overflow: auto;
#   scrollbar-width: none;
#   white-space: nowrap;
#   margin-right: -12px;
# }
# .headline {
#   display: flex;
#   margin-right: 4px;
# }
# .gradient-container {
#   position: relative;
# }
# .gradient {
#   position: absolute;
#   transform: translate(3px, -9px);
#   height: 36px;
#   width: 9px;
# }
# @media (prefers-color-scheme: light) {
#   .container {
#     background-color: #fafafa;
#     box-shadow: 0 0 0 1px #0000000f;
#   }
#   .headline-label {
#     color: #1f1f1f;
#   }
#   .chip {
#     background-color: #ffffff;
#     border-color: #d2d2d2;
#     color: #5e5e5e;
#     text-decoration: none;
#   }
#   .chip:hover {
#     background-color: #f2f2f2;
#   }
#   .chip:focus {
#     background-color: #f2f2f2;
#   }
#   .chip:active {
#     background-color: #d8d8d8;
#     border-color: #b6b6b6;
#   }
#   .logo-dark {
#     display: none;
#   }
#   .gradient {
#     background: linear-gradient(90deg, #fafafa 15%, #fafafa00 100%);
#   }
# }
# @media (prefers-color-scheme: dark) {
#   .container {
#     background-color: #1f1f1f;
#     box-shadow: 0 0 0 1px #ffffff26;
#   }
#   .headline-label {
#     color: #fff;
#   }
#   .chip {
#     background-color: #2c2c2c;
#     border-color: #3c4043;
#     color: #fff;
#     text-decoration: none;
#   }
#   .chip:hover {
#     background-color: #353536;
#   }
#   .chip:focus {
#     background-color: #353536;
#   }
#   .chip:active {
#     background-color: #464849;
#     border-color: #53575b;
#   }
#   .logo-light {
#     display: none;
#   }
#   .gradient {
#     background: linear-gradient(90deg, #1f1f1f 15%, #1f1f1f00 100%);
#   }
# }
# </style>
# <div class="container">
#   <div class="headline">
#     <svg class="logo-light" width="18" height="18" viewBox="9 9 35 35" fill="none" xmlns="http://www.w3.org/2000/svg">
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M42.8622 27.0064C42.8622 25.7839 42.7525 24.6084 42.5487 23.4799H26.3109V30.1568H35.5897C35.1821 32.3041 33.9596 34.1222 32.1258 35.3448V39.6864H37.7213C40.9814 36.677 42.8622 32.2571 42.8622 27.0064V27.0064Z" fill="#4285F4"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M26.3109 43.8555C30.9659 43.8555 34.8687 42.3195 37.7213 39.6863L32.1258 35.3447C30.5898 36.3792 28.6306 37.0061 26.3109 37.0061C21.8282 37.0061 18.0195 33.9811 16.6559 29.906H10.9194V34.3573C13.7563 39.9841 19.5712 43.8555 26.3109 43.8555V43.8555Z" fill="#34A853"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M16.6559 29.8904C16.3111 28.8559 16.1074 27.7588 16.1074 26.6146C16.1074 25.4704 16.3111 24.3733 16.6559 23.3388V18.8875H10.9194C9.74388 21.2072 9.06992 23.8247 9.06992 26.6146C9.06992 29.4045 9.74388 32.022 10.9194 34.3417L15.3864 30.8621L16.6559 29.8904V29.8904Z" fill="#FBBC05"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M26.3109 16.2386C28.85 16.2386 31.107 17.1164 32.9095 18.8091L37.8466 13.8719C34.853 11.082 30.9659 9.3736 26.3109 9.3736C19.5712 9.3736 13.7563 13.245 10.9194 18.8875L16.6559 23.3388C18.0195 19.2636 21.8282 16.2386 26.3109 16.2386V16.2386Z" fill="#EA4335"/>
#     </svg>
#     <svg class="logo-dark" width="18" height="18" viewBox="0 0 48 48" xmlns="http://www.w3.org/2000/svg">
#       <circle cx="24" cy="23" fill="#FFF" r="22"/>
#       <path d="M33.76 34.26c2.75-2.56 4.49-6.37 4.49-11.26 0-.89-.08-1.84-.29-3H24.01v5.99h8.03c-.4 2.02-1.5 3.56-3.07 4.56v.75l3.91 2.97h.88z" fill="#4285F4"/>
#       <path d="M15.58 25.77A8.845 8.845 0 0 0 24 31.86c1.92 0 3.62-.46 4.97-1.31l4.79 3.71C31.14 36.7 27.65 38 24 38c-5.93 0-11.01-3.4-13.45-8.36l.17-1.01 4.06-2.85h.8z" fill="#34A853"/>
#       <path d="M15.59 20.21a8.864 8.864 0 0 0 0 5.58l-5.03 3.86c-.98-2-1.53-4.25-1.53-6.64 0-2.39.55-4.64 1.53-6.64l1-.22 3.81 2.98.22 1.08z" fill="#FBBC05"/>
#       <path d="M24 14.14c2.11 0 4.02.75 5.52 1.98l4.36-4.36C31.22 9.43 27.81 8 24 8c-5.93 0-11.01 3.4-13.45 8.36l5.03 3.85A8.86 8.86 0 0 1 24 14.14z" fill="#EA4335"/>
#     </svg>
#     <div class="gradient-container"><div class="gradient"></div></div>
#   </div>
#   <div class="carousel">
#     <a class="chip" href="https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQFWKqeLwlYbeeuRFncMfBsY-sOtS3w8R1dqmL7dx7ikhtMiZR786g6bZLZk7Z2kS2_yaL_tB5gUYf_TUkhdHE81Uszr_dc4qDX1dK1ORGGyOeto15UHLny2JpreUF0XhL7NrjDrj8QOuVmdakMDQabT9D9LRwSyZLgzjUwy-SXizjcBUVtRhd_EpSDXXjs5XTbH663jJTjriuWxYCw=">Jin Sho Palo Alto address</a>
#     <a class="chip" href="https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQGBgWc4HvXXJ6M8KyZubtcrD3bPIis1qQzwkG4ewAADVDTqNuM5kwK3oB7TlQPbSUiDGAwg9o0Q1_-Gl0_2RgngJ-hRNtLo8BX-tszEdCqo7b8hd-AfBLP7sIx4soXxQuT1eHE4HVNNYgjVWiXgC0iK6txLS690JnAXlXMu1Vcp35HXo2Orbqs4J4-rIVH00JiCq-G86AB_6uRWXCzYYx8N66qY1Sw2WuV5fTEerlPQgLLaOZYxymtU6XfrCxo91_zay6AmdaUTgZKdXA==">walking directions from Palo Alto Caltrain station to Jin Sho Palo Alto</a>
#     <a class="chip" href="https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQGYRMg4G6S35-zl1ibv-InttvheqJTV1dqDiV3oVzxbUzmKVG-qEKpdxIGyBWmP7L-_yD3yDBpoIErczlHA6hcrrDoTP-4NpAvzYZsSIhPtf8oqe2DvROV0QtRv3JGMWh3ToOiC10iHcbi0zpAhwildQ-uO9q5YX1ABzCQAS4n9puLG6IMAS4TW48C05A3IltZNVPmPv3rahSbje5xMUvlsJ2AiHuY=">Palo Alto Caltrain station address</a>
#   </div>
# </div>
# """
#   ),
#   web_search_queries=[
#     'best sushi in Palo Alto',
#     'Palo Alto Caltrain station address',
#     'directions from Palo Alto Caltrain Station to Jin Sho Palo Alto',
#     'walking directions from Palo Alto Caltrain station to Jin Sho Palo Alto',
#     'Jin Sho Palo Alto address',
#     <... 1 more items ...>,
#   ]
# ) partial=None turn_complete=None error_code=None error_message=None interrupted=None custom_metadata=None usage_metadata=GenerateContentResponseUsageMetadata(
#   cache_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=49
#     ),
#   ],
#   cached_content_token_count=49,
#   candidates_token_count=238,
#   prompt_token_count=95,
#   prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=95
#     ),
#   ],
#   thoughts_token_count=954,
#   tool_use_prompt_token_count=1552,
#   tool_use_prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=1552
#     ),
#   ],
#   total_token_count=2839
# ) live_session_resumption_update=None invocation_id='e-8bdcac4e-5195-4c4d-93ae-e77b7a11c209' author='foodie_agent' actions=EventActions(skip_summarization=None, state_delta={}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}) long_running_tool_ids=None branch=None id='0dec88cf-5dc4-4ab6-bbef-7ead3158e1f2' timestamp=1755966118.377228
#
# --------------------------------------------------
# ✅ Final Response:
# The absolute best sushi in Palo Alto is at **Jin Sho**. Reviewers consistently praise its incredibly fresh fish, with the otoro and uni often highlighted as melting in your mouth.
#
# **Jin Sho** is located at 454 California Avenue, Palo Alto, California 94306.
#
# To get to Jin Sho from the Palo Alto Caltrain Station (95 University Avenue, Palo Alto), you have a couple of options:
#
# **By Walking:**
# The walk is approximately 1.6 miles and will take about 31 minutes.
#
# **By Taxi or Rideshare:**
# A taxi or rideshare would be the fastest option, taking around 3 minutes and costing approximately $12-$15.
# --------------------------------------------------
#
# 💡 Extracted Destination: Jin Sho
#
# 🗣️ New Query for Transport Agent: 'Give me directions to Jin Sho from the Palo Alto Caltrain station.'
#
# 🚀 Running query for agent: 'transportation_agent' in session: '4ef4d0dd-147a-418f-b06c-caa644d225bd'...
# EVENT: content=Content(
#   parts=[
#     Part(
#       text="""To get to Jin Sho from the Palo Alto Caltrain station, you have several transportation options: walking, taking public transit, or using a taxi/rideshare service. Jin Sho is located at 454 California Avenue, Palo Alto, CA 94306.
#
# **By Walking (Approximately 30-35 minutes):**
#
# 1.  Exit the Palo Alto Caltrain Station and head southwest on University Avenue towards Alma Street.
# 2.  Turn right onto Alma Street.
# 3.  Turn left onto Cambridge Avenue.
# 4.  Turn right onto El Camino Real.
# 5.  Turn left onto California Avenue. Jin Sho will be on your right.
#
# **By Public Transit (Bus - Approximately 10-15 minutes, plus walking):**
#
# 1.  From the Palo Alto Caltrain Station (Palo Alto Transit Center), take the **VTA Line 21 bus** towards Middlefield & Embarcadero.
# 2.  Ride the bus for about 10 minutes until you reach the Middlefield & Embarcadero stop.
# 3.  From there, it's a short walk (a few minutes) to Jin Sho on California Avenue.
#
# **By Taxi or Rideshare (Approximately 3-5 minutes):**
#
# 1.  You can easily hail a taxi or use a rideshare service from the Palo Alto Caltrain Station.
# 2.  The drive to Jin Sho at 454 California Avenue typically takes about 3-5 minutes, depending on traffic."""
#     ),
#   ],
#   role='model'
# ) grounding_metadata=GroundingMetadata(
#   grounding_chunks=[
#     GroundingChunk(
#       web=GroundingChunkWeb(
#         title='jinshorestaurant.com',
#         uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQGjIx8JDKhMEU3LXWKfkf1MVBhV5DSvt0z6dL3Ryunhp7tYErpue_rLVS0sbVjQb9BSmbJN4OMX2Bdz9-Sfz2COVpWR68mpPPkIe3o1zZbWH51WOYRGeoogTUlvfQ=='
#       )
#     ),
#     GroundingChunk(
#       web=GroundingChunkWeb(
#         title='restaurants-world.com',
#         uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQGEGD_BGLVD55dbC5UgwWEZA1VVyrfrsfmTQ1bCDxFduOiANMHyJdjGfOOMXo_tQGqDMz5FP5HM8965DkTVkq-9JQCsGIVWeTuf-Z1qD2edQPXHWq2nMW_dyIxN-3PvxVfH'
#       )
#     ),
#     GroundingChunk(
#       web=GroundingChunkWeb(
#         title='rome2rio.com',
#         uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQGA6UBRZt7rLCRonvbdQbT1pCa4jeABBMJ3nBBW4mmvZK45R50CQAMz_HrIsMFXT04IXt-YbX_xyKraXqnaYe9ZKVNm0zYq7Pg4k7i_-5RcLXORQMbVxiumF3eAPod69v01973jA3itWpVKFpS0j6VmpvnyRfoMrjkQcw=='
#       )
#     ),
#   ],
#   grounding_supports=[
#     GroundingSupport(
#       grounding_chunk_indices=[
#         0,
#         1,
#       ],
#       segment=Segment(
#         end_index=228,
#         start_index=163,
#         text='Jin Sho is located at 454 California Avenue, Palo Alto, CA 94306.'
#       )
#     ),
#     GroundingSupport(
#       grounding_chunk_indices=[
#         2,
#       ],
#       segment=Segment(
#         end_index=759,
#         start_index=632,
#         text='From the Palo Alto Caltrain Station (Palo Alto Transit Center), take the **VTA Line 21 bus** towards Middlefield & Embarcadero.'
#       )
#     ),
#     GroundingSupport(
#       grounding_chunk_indices=[
#         2,
#       ],
#       segment=Segment(
#         end_index=849,
#         start_index=764,
#         text='Ride the bus for about 10 minutes until you reach the Middlefield & Embarcadero stop.'
#       )
#     ),
#     GroundingSupport(
#       grounding_chunk_indices=[
#         2,
#       ],
#       segment=Segment(
#         end_index=1190,
#         start_index=1088,
#         text='The drive to Jin Sho at 454 California Avenue typically takes about 3-5 minutes, depending on traffic.'
#       )
#     ),
#   ],
#   search_entry_point=SearchEntryPoint(
#     rendered_content="""<style>
# .container {
#   align-items: center;
#   border-radius: 8px;
#   display: flex;
#   font-family: Google Sans, Roboto, sans-serif;
#   font-size: 14px;
#   line-height: 20px;
#   padding: 8px 12px;
# }
# .chip {
#   display: inline-block;
#   border: solid 1px;
#   border-radius: 16px;
#   min-width: 14px;
#   padding: 5px 16px;
#   text-align: center;
#   user-select: none;
#   margin: 0 8px;
#   -webkit-tap-highlight-color: transparent;
# }
# .carousel {
#   overflow: auto;
#   scrollbar-width: none;
#   white-space: nowrap;
#   margin-right: -12px;
# }
# .headline {
#   display: flex;
#   margin-right: 4px;
# }
# .gradient-container {
#   position: relative;
# }
# .gradient {
#   position: absolute;
#   transform: translate(3px, -9px);
#   height: 36px;
#   width: 9px;
# }
# @media (prefers-color-scheme: light) {
#   .container {
#     background-color: #fafafa;
#     box-shadow: 0 0 0 1px #0000000f;
#   }
#   .headline-label {
#     color: #1f1f1f;
#   }
#   .chip {
#     background-color: #ffffff;
#     border-color: #d2d2d2;
#     color: #5e5e5e;
#     text-decoration: none;
#   }
#   .chip:hover {
#     background-color: #f2f2f2;
#   }
#   .chip:focus {
#     background-color: #f2f2f2;
#   }
#   .chip:active {
#     background-color: #d8d8d8;
#     border-color: #b6b6b6;
#   }
#   .logo-dark {
#     display: none;
#   }
#   .gradient {
#     background: linear-gradient(90deg, #fafafa 15%, #fafafa00 100%);
#   }
# }
# @media (prefers-color-scheme: dark) {
#   .container {
#     background-color: #1f1f1f;
#     box-shadow: 0 0 0 1px #ffffff26;
#   }
#   .headline-label {
#     color: #fff;
#   }
#   .chip {
#     background-color: #2c2c2c;
#     border-color: #3c4043;
#     color: #fff;
#     text-decoration: none;
#   }
#   .chip:hover {
#     background-color: #353536;
#   }
#   .chip:focus {
#     background-color: #353536;
#   }
#   .chip:active {
#     background-color: #464849;
#     border-color: #53575b;
#   }
#   .logo-light {
#     display: none;
#   }
#   .gradient {
#     background: linear-gradient(90deg, #1f1f1f 15%, #1f1f1f00 100%);
#   }
# }
# </style>
# <div class="container">
#   <div class="headline">
#     <svg class="logo-light" width="18" height="18" viewBox="9 9 35 35" fill="none" xmlns="http://www.w3.org/2000/svg">
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M42.8622 27.0064C42.8622 25.7839 42.7525 24.6084 42.5487 23.4799H26.3109V30.1568H35.5897C35.1821 32.3041 33.9596 34.1222 32.1258 35.3448V39.6864H37.7213C40.9814 36.677 42.8622 32.2571 42.8622 27.0064V27.0064Z" fill="#4285F4"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M26.3109 43.8555C30.9659 43.8555 34.8687 42.3195 37.7213 39.6863L32.1258 35.3447C30.5898 36.3792 28.6306 37.0061 26.3109 37.0061C21.8282 37.0061 18.0195 33.9811 16.6559 29.906H10.9194V34.3573C13.7563 39.9841 19.5712 43.8555 26.3109 43.8555V43.8555Z" fill="#34A853"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M16.6559 29.8904C16.3111 28.8559 16.1074 27.7588 16.1074 26.6146C16.1074 25.4704 16.3111 24.3733 16.6559 23.3388V18.8875H10.9194C9.74388 21.2072 9.06992 23.8247 9.06992 26.6146C9.06992 29.4045 9.74388 32.022 10.9194 34.3417L15.3864 30.8621L16.6559 29.8904V29.8904Z" fill="#FBBC05"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M26.3109 16.2386C28.85 16.2386 31.107 17.1164 32.9095 18.8091L37.8466 13.8719C34.853 11.082 30.9659 9.3736 26.3109 9.3736C19.5712 9.3736 13.7563 13.245 10.9194 18.8875L16.6559 23.3388C18.0195 19.2636 21.8282 16.2386 26.3109 16.2386V16.2386Z" fill="#EA4335"/>
#     </svg>
#     <svg class="logo-dark" width="18" height="18" viewBox="0 0 48 48" xmlns="http://www.w3.org/2000/svg">
#       <circle cx="24" cy="23" fill="#FFF" r="22"/>
#       <path d="M33.76 34.26c2.75-2.56 4.49-6.37 4.49-11.26 0-.89-.08-1.84-.29-3H24.01v5.99h8.03c-.4 2.02-1.5 3.56-3.07 4.56v.75l3.91 2.97h.88z" fill="#4285F4"/>
#       <path d="M15.58 25.77A8.845 8.845 0 0 0 24 31.86c1.92 0 3.62-.46 4.97-1.31l4.79 3.71C31.14 36.7 27.65 38 24 38c-5.93 0-11.01-3.4-13.45-8.36l.17-1.01 4.06-2.85h.8z" fill="#34A853"/>
#       <path d="M15.59 20.21a8.864 8.864 0 0 0 0 5.58l-5.03 3.86c-.98-2-1.53-4.25-1.53-6.64 0-2.39.55-4.64 1.53-6.64l1-.22 3.81 2.98.22 1.08z" fill="#FBBC05"/>
#       <path d="M24 14.14c2.11 0 4.02.75 5.52 1.98l4.36-4.36C31.22 9.43 27.81 8 24 8c-5.93 0-11.01 3.4-13.45 8.36l5.03 3.85A8.86 8.86 0 0 1 24 14.14z" fill="#EA4335"/>
#     </svg>
#     <div class="gradient-container"><div class="gradient"></div></div>
#   </div>
#   <div class="carousel">
#     <a class="chip" href="https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQHKDjw9dzxpOr16zcEySX3tLL732v1uIna6FVvGU2FqOoScR0FuiAIyah1oU5clwbjdO-Id6mo1YTatKggROjJU_rak30EN2gLjCGyoM_N-wGG4rIJiV2-PIXmS9geHguXjggQGmb4uHALjuJR8l7xclN1gA0tgVNFWn0Zc9CWrYtXQQe5vr5zRrhBlgJX-MCw9kKRBLGSoxOYWgmZ-JZJe_zcvee_xe-xs4cwZVTRl-4rKlw==">Palo Alto Caltrain station to Jin Sho directions</a>
#     <a class="chip" href="https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQEGB8qXHgE3w0xxom5d6sxMz-JtF04QvXcX33aQhqWtrkeZ2cil_TyQlQBoQuoiU92R_wGjMNdKfk0BydR903gchXrlq33Gqx8qaULWB81JKXXo2ZvQCAnf0VuzJtfIOK_Oub9V_8qHe6DzOxU69nsBXhslNyK4yG2Cbbwws-b3SvxbuFsPiW2unJUV51bWX4TGCW-WxNhFyv4OHNY=">Jin Sho Palo Alto address</a>
#   </div>
# </div>
# """
#   ),
#   web_search_queries=[
#     'Jin Sho Palo Alto address',
#     'Palo Alto Caltrain station to Jin Sho directions',
#   ]
# ) partial=None turn_complete=None error_code=None error_message=None interrupted=None custom_metadata=None usage_metadata=GenerateContentResponseUsageMetadata(
#   candidates_token_count=347,
#   prompt_token_count=60,
#   prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=60
#     ),
#   ],
#   thoughts_token_count=153,
#   tool_use_prompt_token_count=151,
#   tool_use_prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=151
#     ),
#   ],
#   total_token_count=711
# ) live_session_resumption_update=None invocation_id='e-e1c8e76b-8a41-4356-96e9-5ae5ee83bd64' author='transportation_agent' actions=EventActions(skip_summarization=None, state_delta={}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}) long_running_tool_ids=None branch=None id='0ad84c34-681e-4375-9ea4-6476c3a63ce1' timestamp=1755966133.25139
#
# --------------------------------------------------
# ✅ Final Response:
# To get to Jin Sho from the Palo Alto Caltrain station, you have several transportation options: walking, taking public transit, or using a taxi/rideshare service. Jin Sho is located at 454 California Avenue, Palo Alto, CA 94306.
#
# **By Walking (Approximately 30-35 minutes):**
#
# 1.  Exit the Palo Alto Caltrain Station and head southwest on University Avenue towards Alma Street.
# 2.  Turn right onto Alma Street.
# 3.  Turn left onto Cambridge Avenue.
# 4.  Turn right onto El Camino Real.
# 5.  Turn left onto California Avenue. Jin Sho will be on your right.
#
# **By Public Transit (Bus - Approximately 10-15 minutes, plus walking):**
#
# 1.  From the Palo Alto Caltrain Station (Palo Alto Transit Center), take the **VTA Line 21 bus** towards Middlefield & Embarcadero.
# 2.  Ride the bus for about 10 minutes until you reach the Middlefield & Embarcadero stop.
# 3.  From there, it's a short walk (a few minutes) to Jin Sho on California Avenue.
#
# **By Taxi or Rideshare (Approximately 3-5 minutes):**
#
# 1.  You can easily hail a taxi or use a rideshare service from the Palo Alto Caltrain Station.
# 2.  The drive to Jin Sho at 454 California Avenue typically takes about 3-5 minutes, depending on traffic.
# --------------------------------------------------
#
# --- Combo Workflow Complete ---

# %% [markdown]
# ---
# ### Part 2 (The ADK Way): Multi-Agent Mayhem with `SequentialAgent` 🧠→⛓️→🤖
#
# You've seen how to manually link agents together with custom Python code. It works, but it can get complicated. Now, let's refactor our workflow to use a powerful, built-in ADK feature designed specifically for this: the **`SequentialAgent`**.
#
# The `SequentialAgent` is a *workflow agent*. It's not powered by an LLM itself; instead, its only job is to execute a list of other agents in a strict, predefined order.
#
# The real magic ✨ is how it passes information. The ADK uses a shared `state` dictionary that each agent in the sequence can read from and write to.
#
# **Our New Workflow:**
#
# 1.  **Foodie Agent**: Finds the restaurant and saves the name to `state['destination']`.
# 2.  **Transportation Agent**: Automatically reads `state['destination']` and uses it to find directions.
#
# This means we no longer need custom Python code to extract text or build new queries! The ADK handles the plumbing for us.

# %% [markdown]
# ```
# +-------------------------------+
# |  find_and_navigate_agent 🧭   |
# | SequentialAgent:             |
# | 1. Find destination          |
# | 2. Get directions            |
# +---------------+---------------+
#                 |
#      +----------+----------+
#      |                     |
#      v                     v
# +----------------+   +------------------------+
# | foodie_agent 🍣 |   | transportation_agent 🚗 |
# | Finds place     |   | Uses {destination}     |
# | Output: 'Jin Sho'|   | Output: Directions     |
# +----------------+   +------------------------+
#
# Final Output: 🍣 Restaurant + 🚗 Route
# ```

# %%
# --- Agent Definitions for our Specialist Team (Refactored for Sequential Workflow) ---

# ✨ CHANGE 1: We tell foodie_agent to save its output to the shared state.
# Note the new `output_key` and the more specific instruction.
foodie_agent = Agent(
    name="foodie_agent",
    model="gemini-2.5-flash",
    tools=[google_search],
    instruction="""You are an expert food critic. Your goal is to find the best restaurant based on a user's request.

    When you recommend a place, you must output *only* the name of the establishment and nothing else.
    For example, if the best sushi is at 'Jin Sho', you should output only: Jin Sho
    """,
    output_key="destination"  # ADK will save the agent's final response to state['destination']
)

# ✨ CHANGE 2: We tell transportation_agent to read from the shared state.
# The `{destination}` placeholder is automatically filled by the ADK from the state.
transportation_agent = Agent(
    name="transportation_agent",
    model="gemini-2.5-flash",
    tools=[google_search],
    instruction="""You are a navigation assistant. Given a destination, provide clear directions.
    The user wants to go to: {destination}.

    Analyze the user's full original query to find their starting point.
    Then, provide clear directions from that starting point to {destination}.
    """,
)

# ✨ CHANGE 3: Define the SequentialAgent to manage the workflow.
# This agent will run foodie_agent, then transportation_agent, in that exact order.
find_and_navigate_agent = SequentialAgent(
    name="find_and_navigate_agent",
    sub_agents=[foodie_agent, transportation_agent],
    description="A workflow that first finds a location and then provides directions to it."
)

weekend_guide_agent = Agent(
    name="weekend_guide_agent",
    model="gemini-2.5-flash",
    tools=[google_search],
    instruction="You are a local events guide. Your task is to find interesting events, concerts, festivals, and activities happening on a specific weekend."
)

# --- The Brain of the Operation: The Router Agent ---

# We update the router to know about our new, powerful SequentialAgent.
router_agent = Agent(
    name="router_agent",
    model="gemini-2.5-flash",
    instruction="""
    You are a request router. Your job is to analyze a user's query and decide which of the following agents or workflows is best suited to handle it.
    Do not answer the query yourself, only return the name of the most appropriate choice.

    Available Options:
    - 'foodie_agent': For queries *only* about food, restaurants, or eating.
    - 'weekend_guide_agent': For queries about events, concerts, or activities happening on a specific timeframe like a weekend.
    - 'day_trip_agent': A general planner for any other day trip requests.
    - 'find_and_navigate_agent': Use this for complex queries that ask to *first find a place* and *then get directions* to it.

    Only return the single, most appropriate option's name and nothing else.
    """
)

# We create a dictionary of all our executable agents for easy lookup.
# This now includes our powerful new workflow agent!
worker_agents = {
    "day_trip_agent": day_trip_agent,
    "foodie_agent": foodie_agent,
    "weekend_guide_agent": weekend_guide_agent,
    "find_and_navigate_agent": find_and_navigate_agent, # Add the new sequential agent
}

print("🤖 Agent team assembled with a SequentialAgent workflow!")
# Out:
# 🤖 Agent team assembled with a SequentialAgent workflow!

# %%
# --- Let's Test the Streamlined Workflow! ---

async def run_sequential_app():
    queries = [
        "I want to eat the best vegetarian food in Palo Alto.", # Should go to foodie_agent
        "Are there any cool outdoor concerts this weekend in the San Francisco Bay Area?", # Should go to weekend_guide_agent
        "Find me the best vegetarian food in Palo Alto and then tell me how to get there from the Caltrain station." # Should trigger the SequentialAgent
    ]

    for query in queries:
        print(f"\n{'='*60}\n🗣️ Processing New Query: '{query}'\n{'='*60}")

        # 1. Ask the Router Agent to choose the right agent or workflow
        router_session = await session_service.create_session(app_name=router_agent.name, user_id=my_user_id)
        print("🧠 Asking the router agent to make a decision...")
        chosen_route = await run_agent_query(router_agent, query, router_session, my_user_id, is_router=True)
        chosen_route = chosen_route.strip().replace("'", "")
        print(f"🚦 Router has selected route: '{chosen_route}'")

        # 2. Execute the chosen route
        # This logic is now much simpler! The SequentialAgent is treated just like any other worker.
        if chosen_route in worker_agents:
            worker_agent = worker_agents[chosen_route]
            print(f"--- Handing off to {worker_agent.name} ---")
            worker_session = await session_service.create_session(app_name=worker_agent.name, user_id=my_user_id)
            await run_agent_query(worker_agent, query, worker_session, my_user_id)
            print(f"--- {worker_agent.name} Complete ---")
        else:
            print(f"🚨 Error: Router chose an unknown route: '{chosen_route}'")

await run_sequential_app()
# Out:
# ============================================================
# 🗣️ Processing New Query: 'I want to eat the best vegetarian food in Palo Alto.'
# ============================================================
# 🧠 Asking the router agent to make a decision...
#
# 🚀 Running query for agent: 'router_agent' in session: '7b919150-ef39-4b30-8e89-a1ecb91d05e8'...
# 🚦 Router has selected route: 'foodie_agent'
# --- Handing off to foodie_agent ---
#
# 🚀 Running query for agent: 'foodie_agent' in session: 'ff549177-9ccf-4786-9282-ac4a1996201b'...
# EVENT: content=Content(
#   parts=[
#     Part(
#       text='Wildseed'
#     ),
#   ],
#   role='model'
# ) grounding_metadata=GroundingMetadata(
#   search_entry_point=SearchEntryPoint(
#     rendered_content="""<style>
# .container {
#   align-items: center;
#   border-radius: 8px;
#   display: flex;
#   font-family: Google Sans, Roboto, sans-serif;
#   font-size: 14px;
#   line-height: 20px;
#   padding: 8px 12px;
# }
# .chip {
#   display: inline-block;
#   border: solid 1px;
#   border-radius: 16px;
#   min-width: 14px;
#   padding: 5px 16px;
#   text-align: center;
#   user-select: none;
#   margin: 0 8px;
#   -webkit-tap-highlight-color: transparent;
# }
# .carousel {
#   overflow: auto;
#   scrollbar-width: none;
#   white-space: nowrap;
#   margin-right: -12px;
# }
# .headline {
#   display: flex;
#   margin-right: 4px;
# }
# .gradient-container {
#   position: relative;
# }
# .gradient {
#   position: absolute;
#   transform: translate(3px, -9px);
#   height: 36px;
#   width: 9px;
# }
# @media (prefers-color-scheme: light) {
#   .container {
#     background-color: #fafafa;
#     box-shadow: 0 0 0 1px #0000000f;
#   }
#   .headline-label {
#     color: #1f1f1f;
#   }
#   .chip {
#     background-color: #ffffff;
#     border-color: #d2d2d2;
#     color: #5e5e5e;
#     text-decoration: none;
#   }
#   .chip:hover {
#     background-color: #f2f2f2;
#   }
#   .chip:focus {
#     background-color: #f2f2f2;
#   }
#   .chip:active {
#     background-color: #d8d8d8;
#     border-color: #b6b6b6;
#   }
#   .logo-dark {
#     display: none;
#   }
#   .gradient {
#     background: linear-gradient(90deg, #fafafa 15%, #fafafa00 100%);
#   }
# }
# @media (prefers-color-scheme: dark) {
#   .container {
#     background-color: #1f1f1f;
#     box-shadow: 0 0 0 1px #ffffff26;
#   }
#   .headline-label {
#     color: #fff;
#   }
#   .chip {
#     background-color: #2c2c2c;
#     border-color: #3c4043;
#     color: #fff;
#     text-decoration: none;
#   }
#   .chip:hover {
#     background-color: #353536;
#   }
#   .chip:focus {
#     background-color: #353536;
#   }
#   .chip:active {
#     background-color: #464849;
#     border-color: #53575b;
#   }
#   .logo-light {
#     display: none;
#   }
#   .gradient {
#     background: linear-gradient(90deg, #1f1f1f 15%, #1f1f1f00 100%);
#   }
# }
# </style>
# <div class="container">
#   <div class="headline">
#     <svg class="logo-light" width="18" height="18" viewBox="9 9 35 35" fill="none" xmlns="http://www.w3.org/2000/svg">
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M42.8622 27.0064C42.8622 25.7839 42.7525 24.6084 42.5487 23.4799H26.3109V30.1568H35.5897C35.1821 32.3041 33.9596 34.1222 32.1258 35.3448V39.6864H37.7213C40.9814 36.677 42.8622 32.2571 42.8622 27.0064V27.0064Z" fill="#4285F4"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M26.3109 43.8555C30.9659 43.8555 34.8687 42.3195 37.7213 39.6863L32.1258 35.3447C30.5898 36.3792 28.6306 37.0061 26.3109 37.0061C21.8282 37.0061 18.0195 33.9811 16.6559 29.906H10.9194V34.3573C13.7563 39.9841 19.5712 43.8555 26.3109 43.8555V43.8555Z" fill="#34A853"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M16.6559 29.8904C16.3111 28.8559 16.1074 27.7588 16.1074 26.6146C16.1074 25.4704 16.3111 24.3733 16.6559 23.3388V18.8875H10.9194C9.74388 21.2072 9.06992 23.8247 9.06992 26.6146C9.06992 29.4045 9.74388 32.022 10.9194 34.3417L15.3864 30.8621L16.6559 29.8904V29.8904Z" fill="#FBBC05"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M26.3109 16.2386C28.85 16.2386 31.107 17.1164 32.9095 18.8091L37.8466 13.8719C34.853 11.082 30.9659 9.3736 26.3109 9.3736C19.5712 9.3736 13.7563 13.245 10.9194 18.8875L16.6559 23.3388C18.0195 19.2636 21.8282 16.2386 26.3109 16.2386V16.2386Z" fill="#EA4335"/>
#     </svg>
#     <svg class="logo-dark" width="18" height="18" viewBox="0 0 48 48" xmlns="http://www.w3.org/2000/svg">
#       <circle cx="24" cy="23" fill="#FFF" r="22"/>
#       <path d="M33.76 34.26c2.75-2.56 4.49-6.37 4.49-11.26 0-.89-.08-1.84-.29-3H24.01v5.99h8.03c-.4 2.02-1.5 3.56-3.07 4.56v.75l3.91 2.97h.88z" fill="#4285F4"/>
#       <path d="M15.58 25.77A8.845 8.845 0 0 0 24 31.86c1.92 0 3.62-.46 4.97-1.31l4.79 3.71C31.14 36.7 27.65 38 24 38c-5.93 0-11.01-3.4-13.45-8.36l.17-1.01 4.06-2.85h.8z" fill="#34A853"/>
#       <path d="M15.59 20.21a8.864 8.864 0 0 0 0 5.58l-5.03 3.86c-.98-2-1.53-4.25-1.53-6.64 0-2.39.55-4.64 1.53-6.64l1-.22 3.81 2.98.22 1.08z" fill="#FBBC05"/>
#       <path d="M24 14.14c2.11 0 4.02.75 5.52 1.98l4.36-4.36C31.22 9.43 27.81 8 24 8c-5.93 0-11.01 3.4-13.45 8.36l5.03 3.85A8.86 8.86 0 0 1 24 14.14z" fill="#EA4335"/>
#     </svg>
#     <div class="gradient-container"><div class="gradient"></div></div>
#   </div>
#   <div class="carousel">
#     <a class="chip" href="https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQFsRdmpKyP1jHzEZYNxJQ-pBK5b3w0AkvbNeGvHWbrfdprIL0ArZXMl7QCHQX8QWK_bu-91S0IsCY1DQYcyyIp0TO7nCnYzk1uAX9O7R9vlmyqZrG6Q2Keav8Xsw5zHh4eVBWsTTiNY0do7KRB2A_lCVTWqF7rOUtl3MpTi9wQbT9jQuwzwgOX9qr5qOe8cLL9M0NuxYjm96W-FmD6VlkOljZPS3YKoFmWXfiwNA84y78FHCbfW">Palo Alto restaurants with best vegetarian options</a>
#     <a class="chip" href="https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQHcQ5k7UuQ7ZXe5w3FM4vA-p8gOXo69DMBKqK5G_doSpydC4tSThvYmF8_DsZgYeP9UrvGIwqGXhtIRuPG3dBJCt3Miann9R7johg6GJy6qDo-iW4gwFT-DXN1yzLOY2KQLN7w6O2jpu6FKcsxW4hrl2GNy9eb6N3vZQybvCIOP1Pbn_Pc9QhB4aDEUZnY0zl8XuViDflXcuSRvnvFcCQhl">best vegetarian food Palo Alto</a>
#     <a class="chip" href="https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQEGmh4f7KJAUsuEPNuNnm8HjZBOvpsP7-DQjv_NvCpR0U5xQmWVv5DJFyMmQbNJwOXuR3rtntYUM4fNtsaFPcKq8nvSyhSBqxdpbrXcU8NxUeMPc5Td3_dMH-LlRffqXEquLKmTbItu3VEiDhVulk3DtkpEOvsBsQBB-gada-fvsxXIGR3fpYazBTXjttNVc0b-mjFK53WvC4W9O-U3kMonpDpkcGcFw7nD3xcA">top-rated vegetarian restaurants Palo Alto</a>
#   </div>
# </div>
# """
#   ),
#   web_search_queries=[
#     'best vegetarian food Palo Alto',
#     'top-rated vegetarian restaurants Palo Alto',
#     'Palo Alto restaurants with best vegetarian options',
#   ]
# ) partial=None turn_complete=None error_code=None error_message=None interrupted=None custom_metadata=None usage_metadata=GenerateContentResponseUsageMetadata(
#   candidates_token_count=37,
#   prompt_token_count=100,
#   prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=100
#     ),
#   ],
#   thoughts_token_count=555,
#   tool_use_prompt_token_count=184,
#   tool_use_prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=184
#     ),
#   ],
#   total_token_count=876
# ) live_session_resumption_update=None invocation_id='e-08a085cf-9b7f-44ae-b020-e3ca330aab3a' author='foodie_agent' actions=EventActions(skip_summarization=None, state_delta={'destination': 'Wildseed'}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}) long_running_tool_ids=None branch=None id='65056543-5c07-4a61-97e8-326fb15ea5f7' timestamp=1755966384.64131
#
# --------------------------------------------------
# ✅ Final Response:
# Wildseed
# --------------------------------------------------
#
# --- foodie_agent Complete ---
#
# ============================================================
# 🗣️ Processing New Query: 'Are there any cool outdoor concerts this weekend in the San Francisco Bay Area?'
# ============================================================
# 🧠 Asking the router agent to make a decision...
#
# 🚀 Running query for agent: 'router_agent' in session: 'a861b13a-b911-4633-be67-2b5558dbb583'...
# 🚦 Router has selected route: 'weekend_guide_agent'
# --- Handing off to weekend_guide_agent ---
#
# 🚀 Running query for agent: 'weekend_guide_agent' in session: 'f4c1224a-98b3-43a6-8ddb-0ad3c9c5347f'...
# EVENT: content=Content(
#   parts=[
#     Part(
#       text="""Here are some cool outdoor concerts and music events happening this weekend, August 23-24, 2025, in the San Francisco Bay Area:
#
# **Saturday, August 23, 2025**
#
# *   **SF's "Pier Party" at Fisherman's Wharf: Free Summer Concert Series (San Francisco)**
#     Enjoy free live music as part of this ongoing summer tradition on the second and fourth Saturdays of the month.
# *   **Rockridge's 1-Mile "Rock-N-Stroll" Fest 2025 (Oakland)**
#     This lively festival in Oakland will feature over 20 street performances.
# *   **SF's "Fern Alley Music Series" (Polk Gulch, San Francisco)**
#     Catch Brad Nofal and Friends performing at this outdoor music series.
#
# **Sunday, August 24, 2025**
#
# *   **Golden Gate Park's Free "Crucial Reggae" Sunday Bandshell Concert (San Francisco)**
#     Head to the Golden Gate Bandshell for an afternoon of reggae with DJ Irie Dole, DJ Guidance, and a special guest. The concert typically runs from 4:20 PM to 7:30 PM.
# *   **Corte Madera Summer Concerts (Menke Park, Corte Madera)**
#     This summer concert series concludes on August 24th, offering live music in Menke Park.
# *   **4th Annual Green Party (The Midway, San Francisco)**
#     The Midway is hosting its "4th Annual Green Party" on their outdoor terrace.
#
# While other recurring outdoor music series like the Vallejo August Summer Nights Music Series and Salesforce Park Live Outdoor Music Series are active in August, specific musical acts for this particular weekend were not detailed in the search results."""
#     ),
#   ],
#   role='model'
# ) grounding_metadata=GroundingMetadata(
#   grounding_chunks=[
#     GroundingChunk(
#       web=GroundingChunkWeb(
#         title='visitcalifornia.com',
#         uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQHnekAikKVu43ff4qoArmhpqg24_jycozqeBYDz3KS3uiQYFqInU_0uXx6lX3PE1UVNu205B_bMeuycHcZ4DgS5ZIpvJqw64rfikuLc8Sftv1d2JE6LN7FFUZtn-KWAKEwPnD8ZCa90xNBtocjz3LYW4uRYlSm_330uPUsMYNY='
#       )
#     ),
#     GroundingChunk(
#       web=GroundingChunkWeb(
#         title='funcheap.com',
#         uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQESC-ieyXMDLY3Oxh0OxONDt9FowduSean9Q2P9s9p5bvZfhDNgs7idsEVUbbFgiGUvix_n549kso7sUuld9mVe8hFps_AmYCzVofyPB29xqPPYAlyDESYUudyEQr0='
#       )
#     ),
#     GroundingChunk(
#       web=GroundingChunkWeb(
#         title='funcheap.com',
#         uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQGvkQcCy0K3E2LoJ3EhXtMsGLMO4adRDvOfTBwTczhwYgP-38iPbmJqvtSGBjVZE8gLz3QPsVldIY_LH1gcoAYWB397dLy_x-xwBNdBEzBwBIb4TwwOzvleEnslXTzTpx-PBSYEyUuBcBBEktZ0k5QaalcJh4XCN547EQPJFiXQdqHvQI4SxScP4esopkY='
#       )
#     ),
#     GroundingChunk(
#       web=GroundingChunkWeb(
#         title='sfchronicle.com',
#         uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQGiixypVMxJwxegXvJL9IwwOPstF5ddO2jekXqZN-zyvJwCGleNWAlD4tGFv038dWPxY866yvAYe3A1ew0Ebots_zgDe6EIx628tbLrJDpN-WI6VxcRYwqA5MdN60zyHX5BycwjSdXlDYBUe4AhOb6BrB1CKtN4WsD5aeY='
#       )
#     ),
#     GroundingChunk(
#       web=GroundingChunkWeb(
#         title='sfrecpark.org',
#         uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQFSrjQiskY_TE_V1KsU0XDumaG8RxKjnF_10LJWxTE1iCFQ0Re_sKbXLjbwd5x3IN5RT0lspexdeUpOyuIc54Tgd7oOSgVHG4OZeUkthKt4Y11uE0cms7Ew1lnA5B0ynwgYIsnG'
#       )
#     ),
#     <... 3 more items ...>,
#   ],
#   grounding_supports=[
#     GroundingSupport(
#       grounding_chunk_indices=[
#         0,
#         1,
#       ],
#       segment=Segment(
#         end_index=366,
#         start_index=160,
#         text="""*   **SF's "Pier Party" at Fisherman's Wharf: Free Summer Concert Series (San Francisco)**
#     Enjoy free live music as part of this ongoing summer tradition on the second and fourth Saturdays of the month."""
#       )
#     ),
#     GroundingSupport(
#       grounding_chunk_indices=[
#         1,
#       ],
#       segment=Segment(
#         end_index=507,
#         start_index=367,
#         text="""*   **Rockridge's 1-Mile "Rock-N-Stroll" Fest 2025 (Oakland)**
#     This lively festival in Oakland will feature over 20 street performances."""
#       )
#     ),
#     GroundingSupport(
#       grounding_chunk_indices=[
#         1,
#       ],
#       segment=Segment(
#         end_index=648,
#         start_index=508,
#         text="""*   **SF's "Fern Alley Music Series" (Polk Gulch, San Francisco)**
#     Catch Brad Nofal and Friends performing at this outdoor music series."""
#       )
#     ),
#     GroundingSupport(
#       grounding_chunk_indices=[
#         2,
#         3,
#         4,
#         5,
#       ],
#       segment=Segment(
#         end_index=938,
#         start_index=887,
#         text='The concert typically runs from 4:20 PM to 7:30 PM.'
#       )
#     ),
#     GroundingSupport(
#       grounding_chunk_indices=[
#         3,
#         6,
#       ],
#       segment=Segment(
#         end_index=1094,
#         start_index=939,
#         text="""*   **Corte Madera Summer Concerts (Menke Park, Corte Madera)**
#     This summer concert series concludes on August 24th, offering live music in Menke Park."""
#       )
#     ),
#     <... 2 more items ...>,
#   ],
#   search_entry_point=SearchEntryPoint(
#     rendered_content="""<style>
# .container {
#   align-items: center;
#   border-radius: 8px;
#   display: flex;
#   font-family: Google Sans, Roboto, sans-serif;
#   font-size: 14px;
#   line-height: 20px;
#   padding: 8px 12px;
# }
# .chip {
#   display: inline-block;
#   border: solid 1px;
#   border-radius: 16px;
#   min-width: 14px;
#   padding: 5px 16px;
#   text-align: center;
#   user-select: none;
#   margin: 0 8px;
#   -webkit-tap-highlight-color: transparent;
# }
# .carousel {
#   overflow: auto;
#   scrollbar-width: none;
#   white-space: nowrap;
#   margin-right: -12px;
# }
# .headline {
#   display: flex;
#   margin-right: 4px;
# }
# .gradient-container {
#   position: relative;
# }
# .gradient {
#   position: absolute;
#   transform: translate(3px, -9px);
#   height: 36px;
#   width: 9px;
# }
# @media (prefers-color-scheme: light) {
#   .container {
#     background-color: #fafafa;
#     box-shadow: 0 0 0 1px #0000000f;
#   }
#   .headline-label {
#     color: #1f1f1f;
#   }
#   .chip {
#     background-color: #ffffff;
#     border-color: #d2d2d2;
#     color: #5e5e5e;
#     text-decoration: none;
#   }
#   .chip:hover {
#     background-color: #f2f2f2;
#   }
#   .chip:focus {
#     background-color: #f2f2f2;
#   }
#   .chip:active {
#     background-color: #d8d8d8;
#     border-color: #b6b6b6;
#   }
#   .logo-dark {
#     display: none;
#   }
#   .gradient {
#     background: linear-gradient(90deg, #fafafa 15%, #fafafa00 100%);
#   }
# }
# @media (prefers-color-scheme: dark) {
#   .container {
#     background-color: #1f1f1f;
#     box-shadow: 0 0 0 1px #ffffff26;
#   }
#   .headline-label {
#     color: #fff;
#   }
#   .chip {
#     background-color: #2c2c2c;
#     border-color: #3c4043;
#     color: #fff;
#     text-decoration: none;
#   }
#   .chip:hover {
#     background-color: #353536;
#   }
#   .chip:focus {
#     background-color: #353536;
#   }
#   .chip:active {
#     background-color: #464849;
#     border-color: #53575b;
#   }
#   .logo-light {
#     display: none;
#   }
#   .gradient {
#     background: linear-gradient(90deg, #1f1f1f 15%, #1f1f1f00 100%);
#   }
# }
# </style>
# <div class="container">
#   <div class="headline">
#     <svg class="logo-light" width="18" height="18" viewBox="9 9 35 35" fill="none" xmlns="http://www.w3.org/2000/svg">
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M42.8622 27.0064C42.8622 25.7839 42.7525 24.6084 42.5487 23.4799H26.3109V30.1568H35.5897C35.1821 32.3041 33.9596 34.1222 32.1258 35.3448V39.6864H37.7213C40.9814 36.677 42.8622 32.2571 42.8622 27.0064V27.0064Z" fill="#4285F4"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M26.3109 43.8555C30.9659 43.8555 34.8687 42.3195 37.7213 39.6863L32.1258 35.3447C30.5898 36.3792 28.6306 37.0061 26.3109 37.0061C21.8282 37.0061 18.0195 33.9811 16.6559 29.906H10.9194V34.3573C13.7563 39.9841 19.5712 43.8555 26.3109 43.8555V43.8555Z" fill="#34A853"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M16.6559 29.8904C16.3111 28.8559 16.1074 27.7588 16.1074 26.6146C16.1074 25.4704 16.3111 24.3733 16.6559 23.3388V18.8875H10.9194C9.74388 21.2072 9.06992 23.8247 9.06992 26.6146C9.06992 29.4045 9.74388 32.022 10.9194 34.3417L15.3864 30.8621L16.6559 29.8904V29.8904Z" fill="#FBBC05"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M26.3109 16.2386C28.85 16.2386 31.107 17.1164 32.9095 18.8091L37.8466 13.8719C34.853 11.082 30.9659 9.3736 26.3109 9.3736C19.5712 9.3736 13.7563 13.245 10.9194 18.8875L16.6559 23.3388C18.0195 19.2636 21.8282 16.2386 26.3109 16.2386V16.2386Z" fill="#EA4335"/>
#     </svg>
#     <svg class="logo-dark" width="18" height="18" viewBox="0 0 48 48" xmlns="http://www.w3.org/2000/svg">
#       <circle cx="24" cy="23" fill="#FFF" r="22"/>
#       <path d="M33.76 34.26c2.75-2.56 4.49-6.37 4.49-11.26 0-.89-.08-1.84-.29-3H24.01v5.99h8.03c-.4 2.02-1.5 3.56-3.07 4.56v.75l3.91 2.97h.88z" fill="#4285F4"/>
#       <path d="M15.58 25.77A8.845 8.845 0 0 0 24 31.86c1.92 0 3.62-.46 4.97-1.31l4.79 3.71C31.14 36.7 27.65 38 24 38c-5.93 0-11.01-3.4-13.45-8.36l.17-1.01 4.06-2.85h.8z" fill="#34A853"/>
#       <path d="M15.59 20.21a8.864 8.864 0 0 0 0 5.58l-5.03 3.86c-.98-2-1.53-4.25-1.53-6.64 0-2.39.55-4.64 1.53-6.64l1-.22 3.81 2.98.22 1.08z" fill="#FBBC05"/>
#       <path d="M24 14.14c2.11 0 4.02.75 5.52 1.98l4.36-4.36C31.22 9.43 27.81 8 24 8c-5.93 0-11.01 3.4-13.45 8.36l5.03 3.85A8.86 8.86 0 0 1 24 14.14z" fill="#EA4335"/>
#     </svg>
#     <div class="gradient-container"><div class="gradient"></div></div>
#   </div>
#   <div class="carousel">
#     <a class="chip" href="https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQHwo_7LpfnaMVRUwpkim_4TBp50UE1Bc8jcpRkns-MwXDbUg2cZbf-JAUeKdMEY8MMTlx02xmnTKmPHv7k39lXNmlTXriCPRCrvxc3znJKxnm7t5DBnWWKZPyh1ilgPSQyxriY3XzKJzVRfNno1gzL0WOo2K-Xb0k7q40AJJDHZK_mHWYVqZnq1M_OmZEMhJr5e3qfqyYs_pVEAjijaUxmhPpepMLP23rAMwsqLa4y95xDThUgghaiB">concerts in Golden Gate Park this weekend August 2025</a>
#     <a class="chip" href="https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQEegjUZoXUPLEENQQNjRpIHOkq3dGX-Z40SuCIfbbjy3ln5EE65UyG28STEOn9Vb15tcx27Pts4ZNJAW0lZ7tzsRWebrLWCa5trI3K9gaPVcneyQk86AVl7mrHgpeJd_nEKDKBKBW9_E8HwukVOPXHG8UjEaH0cu8fb1FwObbpj1uIH8-A-j-vYzBA0UaCFBnIA_han796CSqo0c3c33nr53PDUFsAFw9-8Yb3341Fpp8Qd_S0QWh1i5BuR">music festivals San Francisco Bay Area August 23-24 2025</a>
#     <a class="chip" href="https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQEIfaeaOEBcVOTBJfkRM0NAjqAXsBmvpzc6cAMnsIyvoDl9vxy7gjzgayi0P2UqZvdkT-2jyWg5TgmkXlvC6asTV9JPZc3-3DZQDaofAgUXo0eJs6wgnfQGctoQETGKeztFDP-1P2asA115CP6cjZt1MBqermC-vHIqHrEbH0Czlk_CBnzD5jQ_op_pfqN2z8aLjtgu5PFg5-c0q9cUfCyb7I8ij0oEeP_YNS_q5FNo1qAecgoHwBzhZXLWAw==">outdoor concerts San Francisco Bay Area August 23-24 2025</a>
#     <a class="chip" href="https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQG_WxnBTCYkFhXOXPBtIfpDommBoCFgsPjArDqet3pPtCO5iWyZH2hibiIsQemoPXN-Sfd5lb2bVhdnY2DFfXANP9g_2zKBECgz6OYlMyBNS219Hgnv6lWS_Oc7kfuRG6OhHdY2HFly_ew5CWpWyvpJ0uhqjTSijWAbasgZeAp5XB2EqZ5_zx0r7dztCZvzwv8CVql4t-CDjPwBhi-jJnb6bTOdwmgpEfjAopsMefL3xyN4hpWYAXVH5dZcO2qWzjrXgGJ5iAmlLg==">San Francisco Bay Area free outdoor concerts this weekend August 2025</a>
#   </div>
# </div>
# """
#   ),
#   web_search_queries=[
#     'outdoor concerts San Francisco Bay Area August 23-24 2025',
#     'San Francisco Bay Area free outdoor concerts this weekend August 2025',
#     'music festivals San Francisco Bay Area August 23-24 2025',
#     'concerts in Golden Gate Park this weekend August 2025',
#   ]
# ) partial=None turn_complete=None error_code=None error_message=None interrupted=None custom_metadata=None usage_metadata=GenerateContentResponseUsageMetadata(
#   candidates_token_count=467,
#   prompt_token_count=61,
#   prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=61
#     ),
#   ],
#   thoughts_token_count=683,
#   tool_use_prompt_token_count=204,
#   tool_use_prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=204
#     ),
#   ],
#   total_token_count=1415
# ) live_session_resumption_update=None invocation_id='e-c4439165-e4f3-4699-ab60-eef92bdbd9d7' author='weekend_guide_agent' actions=EventActions(skip_summarization=None, state_delta={}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}) long_running_tool_ids=None branch=None id='65b2cc33-751d-4958-bba9-480628dd12f0' timestamp=1755966395.706321
#
# --------------------------------------------------
# ✅ Final Response:
# Here are some cool outdoor concerts and music events happening this weekend, August 23-24, 2025, in the San Francisco Bay Area:
#
# **Saturday, August 23, 2025**
#
# *   **SF's "Pier Party" at Fisherman's Wharf: Free Summer Concert Series (San Francisco)**
#     Enjoy free live music as part of this ongoing summer tradition on the second and fourth Saturdays of the month.
# *   **Rockridge's 1-Mile "Rock-N-Stroll" Fest 2025 (Oakland)**
#     This lively festival in Oakland will feature over 20 street performances.
# *   **SF's "Fern Alley Music Series" (Polk Gulch, San Francisco)**
#     Catch Brad Nofal and Friends performing at this outdoor music series.
#
# **Sunday, August 24, 2025**
#
# *   **Golden Gate Park's Free "Crucial Reggae" Sunday Bandshell Concert (San Francisco)**
#     Head to the Golden Gate Bandshell for an afternoon of reggae with DJ Irie Dole, DJ Guidance, and a special guest. The concert typically runs from 4:20 PM to 7:30 PM.
# *   **Corte Madera Summer Concerts (Menke Park, Corte Madera)**
#     This summer concert series concludes on August 24th, offering live music in Menke Park.
# *   **4th Annual Green Party (The Midway, San Francisco)**
#     The Midway is hosting its "4th Annual Green Party" on their outdoor terrace.
#
# While other recurring outdoor music series like the Vallejo August Summer Nights Music Series and Salesforce Park Live Outdoor Music Series are active in August, specific musical acts for this particular weekend were not detailed in the search results.
# --------------------------------------------------
#
# --- weekend_guide_agent Complete ---
#
# ============================================================
# 🗣️ Processing New Query: 'Find me the best vegetarian food in Palo Alto and then tell me how to get there from the Caltrain station.'
# ============================================================
# 🧠 Asking the router agent to make a decision...
#
# 🚀 Running query for agent: 'router_agent' in session: 'd4b4da1b-8c89-4e13-88cc-b4cc160eda19'...
# 🚦 Router has selected route: 'find_and_navigate_agent'
# --- Handing off to find_and_navigate_agent ---
#
# 🚀 Running query for agent: 'find_and_navigate_agent' in session: 'fd771a0d-3e8b-4dd5-9608-e6591a6d4684'...
# EVENT: content=Content(
#   parts=[
#     Part(
#       text='Wildseed'
#     ),
#   ],
#   role='model'
# ) grounding_metadata=GroundingMetadata(
#   search_entry_point=SearchEntryPoint(
#     rendered_content="""<style>
# .container {
#   align-items: center;
#   border-radius: 8px;
#   display: flex;
#   font-family: Google Sans, Roboto, sans-serif;
#   font-size: 14px;
#   line-height: 20px;
#   padding: 8px 12px;
# }
# .chip {
#   display: inline-block;
#   border: solid 1px;
#   border-radius: 16px;
#   min-width: 14px;
#   padding: 5px 16px;
#   text-align: center;
#   user-select: none;
#   margin: 0 8px;
#   -webkit-tap-highlight-color: transparent;
# }
# .carousel {
#   overflow: auto;
#   scrollbar-width: none;
#   white-space: nowrap;
#   margin-right: -12px;
# }
# .headline {
#   display: flex;
#   margin-right: 4px;
# }
# .gradient-container {
#   position: relative;
# }
# .gradient {
#   position: absolute;
#   transform: translate(3px, -9px);
#   height: 36px;
#   width: 9px;
# }
# @media (prefers-color-scheme: light) {
#   .container {
#     background-color: #fafafa;
#     box-shadow: 0 0 0 1px #0000000f;
#   }
#   .headline-label {
#     color: #1f1f1f;
#   }
#   .chip {
#     background-color: #ffffff;
#     border-color: #d2d2d2;
#     color: #5e5e5e;
#     text-decoration: none;
#   }
#   .chip:hover {
#     background-color: #f2f2f2;
#   }
#   .chip:focus {
#     background-color: #f2f2f2;
#   }
#   .chip:active {
#     background-color: #d8d8d8;
#     border-color: #b6b6b6;
#   }
#   .logo-dark {
#     display: none;
#   }
#   .gradient {
#     background: linear-gradient(90deg, #fafafa 15%, #fafafa00 100%);
#   }
# }
# @media (prefers-color-scheme: dark) {
#   .container {
#     background-color: #1f1f1f;
#     box-shadow: 0 0 0 1px #ffffff26;
#   }
#   .headline-label {
#     color: #fff;
#   }
#   .chip {
#     background-color: #2c2c2c;
#     border-color: #3c4043;
#     color: #fff;
#     text-decoration: none;
#   }
#   .chip:hover {
#     background-color: #353536;
#   }
#   .chip:focus {
#     background-color: #353536;
#   }
#   .chip:active {
#     background-color: #464849;
#     border-color: #53575b;
#   }
#   .logo-light {
#     display: none;
#   }
#   .gradient {
#     background: linear-gradient(90deg, #1f1f1f 15%, #1f1f1f00 100%);
#   }
# }
# </style>
# <div class="container">
#   <div class="headline">
#     <svg class="logo-light" width="18" height="18" viewBox="9 9 35 35" fill="none" xmlns="http://www.w3.org/2000/svg">
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M42.8622 27.0064C42.8622 25.7839 42.7525 24.6084 42.5487 23.4799H26.3109V30.1568H35.5897C35.1821 32.3041 33.9596 34.1222 32.1258 35.3448V39.6864H37.7213C40.9814 36.677 42.8622 32.2571 42.8622 27.0064V27.0064Z" fill="#4285F4"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M26.3109 43.8555C30.9659 43.8555 34.8687 42.3195 37.7213 39.6863L32.1258 35.3447C30.5898 36.3792 28.6306 37.0061 26.3109 37.0061C21.8282 37.0061 18.0195 33.9811 16.6559 29.906H10.9194V34.3573C13.7563 39.9841 19.5712 43.8555 26.3109 43.8555V43.8555Z" fill="#34A853"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M16.6559 29.8904C16.3111 28.8559 16.1074 27.7588 16.1074 26.6146C16.1074 25.4704 16.3111 24.3733 16.6559 23.3388V18.8875H10.9194C9.74388 21.2072 9.06992 23.8247 9.06992 26.6146C9.06992 29.4045 9.74388 32.022 10.9194 34.3417L15.3864 30.8621L16.6559 29.8904V29.8904Z" fill="#FBBC05"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M26.3109 16.2386C28.85 16.2386 31.107 17.1164 32.9095 18.8091L37.8466 13.8719C34.853 11.082 30.9659 9.3736 26.3109 9.3736C19.5712 9.3736 13.7563 13.245 10.9194 18.8875L16.6559 23.3388C18.0195 19.2636 21.8282 16.2386 26.3109 16.2386V16.2386Z" fill="#EA4335"/>
#     </svg>
#     <svg class="logo-dark" width="18" height="18" viewBox="0 0 48 48" xmlns="http://www.w3.org/2000/svg">
#       <circle cx="24" cy="23" fill="#FFF" r="22"/>
#       <path d="M33.76 34.26c2.75-2.56 4.49-6.37 4.49-11.26 0-.89-.08-1.84-.29-3H24.01v5.99h8.03c-.4 2.02-1.5 3.56-3.07 4.56v.75l3.91 2.97h.88z" fill="#4285F4"/>
#       <path d="M15.58 25.77A8.845 8.845 0 0 0 24 31.86c1.92 0 3.62-.46 4.97-1.31l4.79 3.71C31.14 36.7 27.65 38 24 38c-5.93 0-11.01-3.4-13.45-8.36l.17-1.01 4.06-2.85h.8z" fill="#34A853"/>
#       <path d="M15.59 20.21a8.864 8.864 0 0 0 0 5.58l-5.03 3.86c-.98-2-1.53-4.25-1.53-6.64 0-2.39.55-4.64 1.53-6.64l1-.22 3.81 2.98.22 1.08z" fill="#FBBC05"/>
#       <path d="M24 14.14c2.11 0 4.02.75 5.52 1.98l4.36-4.36C31.22 9.43 27.81 8 24 8c-5.93 0-11.01 3.4-13.45 8.36l5.03 3.85A8.86 8.86 0 0 1 24 14.14z" fill="#EA4335"/>
#     </svg>
#     <div class="gradient-container"><div class="gradient"></div></div>
#   </div>
#   <div class="carousel">
#     <a class="chip" href="https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQGcwhqCjRzFlMXpIE5pCno_jWR-KjJCILk952Vxhm6LetBWhKrpSRrwsiooXwvc5iLIREPAznlUtlvdmhOK1wBZVrYDBBc14jTOGhnKEIWzikrzjkCiYe9UKsY7-380gH__Oqk0xdKUNm-9fQ2ShN-q-PTVjqUKloBGOWdiGEBaLJhEpJeblcWrei_agYd2Dt-l9qpApJAo-87jTOLdMF-J0A==">best vegetarian food Palo Alto</a>
#     <a class="chip" href="https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQFt8Pouszl-c3_VrGfV3NrUa_itNjtZTo0BlbMgWPYK1sn4MmCvvyZm91St8Wmiqi6sk1oilGWe2bBFqbEm3pd8FLR1kD1O6H1A5A0O71_hLdMkM2L59YmN3Kc13AjLdvvZo4lL-S_bb_GE25iCjw518NGxuqLiz6MagcgR-h_x5W9wO-ZKIImKLQBNTqQy6mwX62NKI-2pnsUzNDMw5zMuWOk1OuQG9fSXKFO1fA==">top rated vegetarian restaurants Palo Alto</a>
#   </div>
# </div>
# """
#   ),
#   web_search_queries=[
#     'best vegetarian food Palo Alto',
#     'top rated vegetarian restaurants Palo Alto',
#   ]
# ) partial=None turn_complete=None error_code=None error_message=None interrupted=None custom_metadata=None usage_metadata=GenerateContentResponseUsageMetadata(
#   candidates_token_count=26,
#   prompt_token_count=111,
#   prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=111
#     ),
#   ],
#   thoughts_token_count=2106,
#   tool_use_prompt_token_count=1642,
#   tool_use_prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=1642
#     ),
#   ],
#   total_token_count=3885
# ) live_session_resumption_update=None invocation_id='e-dab20e52-06db-4121-9e31-6bbcf8aa9752' author='foodie_agent' actions=EventActions(skip_summarization=None, state_delta={'destination': 'Wildseed'}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}) long_running_tool_ids=None branch=None id='2d9d65a5-7db6-4192-ada0-087946ed76db' timestamp=1755966411.248644
# EVENT: content=Content(
#   parts=[
#     Part(
#       text="""To get to Wildseed from the Palo Alto Caltrain Station, follow these directions:
#
# 1.  **Start at Palo Alto Caltrain Station:** The station is located at 95 University Ave, Palo Alto, CA 94301.
# 2.  **Walk or Take Public Transit to Wildseed:** Wildseed is located at 855 El Camino Real, Palo Alto, CA 94301. This is approximately 0.8 miles away from the Caltrain station. You can walk there in about 15-20 minutes, or consider a short bus ride or ride-share option for a quicker trip."""
#     ),
#   ],
#   role='model'
# ) grounding_metadata=GroundingMetadata(
#   grounding_chunks=[
#     GroundingChunk(
#       web=GroundingChunkWeb(
#         title='sfbaytransit.org',
#         uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQGVu6j6TJfQNXOZ8AbgsLjXQ6okjaa38rxGdqoiwiH9uQdYzs8raqJvQFacXItpZ2Qz3eXQvNUEAyUIzB-QD3Kj5j7jJ5rvwInGuUpuGCTXusFeSl3D3poN6MbawKTBSwyJjb5YsAwvPE3ZycYkQQ=='
#       )
#     ),
#     GroundingChunk(
#       web=GroundingChunkWeb(
#         title='waze.com',
#         uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQEPrMpE4KB8xefG84aP-rkMIthhnz39LjSUgmvBK6MFkWsftLoZCp_Wl3FeV4Z6X2MtUs7HGFyL4MayweAxTa_nPdJHUNBdq4OYrq-d01DuI4N4ucwK8FOTc2EdDmpF2c5YwFTKukjHvq1_ZcTpomlWCfiMGmRuD5uRyYlshUNwW5cCPgrKD8GJ2rQwfAN7MzQnN5mVHVeOJoJrHx2htVW5rMuo-fgapK0f-UlirFbsVo2T0g=='
#       )
#     ),
#     GroundingChunk(
#       web=GroundingChunkWeb(
#         title='birdeye.com',
#         uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQHd3qLBVM3eyfsXP6SYVFGJpKICTKIL565ZP73s9_9ktWVbIqYZ2FEYmpb2j878bdwVYrdnqbIvmLDCLdnTaD6YvQAlSW5qXGqItiO0QB-m4rz1eLZcGD3UtZyIE0mVlgdYbb4WNof4UCITqJAQCCfbGEeMYxq2kQ10pSzfkNEeiDQ='
#       )
#     ),
#     GroundingChunk(
#       web=GroundingChunkWeb(
#         title='healthyanywhere.com',
#         uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQGtxhp0HSeo0RsjRmdCORx8Hjw__-OoaQN8FIoPLuuDIWbEWAZ3-4xxEv5SwdjiX6dZGO8M1U9Xz_E_HfZTDNRwoOFs8VofMe5T1hHDyxKTquDtgg5WIbG2dnMyKxlqEIJ5-xggsPAO57BsnE7VLmNYBaysCottUX6z9QJL'
#       )
#     ),
#   ],
#   grounding_supports=[
#     GroundingSupport(
#       grounding_chunk_indices=[
#         0,
#         1,
#         2,
#       ],
#       segment=Segment(
#         end_index=192,
#         start_index=86,
#         text='**Start at Palo Alto Caltrain Station:** The station is located at 95 University Ave, Palo Alto, CA 94301.'
#       )
#     ),
#     GroundingSupport(
#       grounding_chunk_indices=[
#         3,
#       ],
#       segment=Segment(
#         end_index=305,
#         start_index=197,
#         text='**Walk or Take Public Transit to Wildseed:** Wildseed is located at 855 El Camino Real, Palo Alto, CA 94301.'
#       )
#     ),
#   ],
#   search_entry_point=SearchEntryPoint(
#     rendered_content="""<style>
# .container {
#   align-items: center;
#   border-radius: 8px;
#   display: flex;
#   font-family: Google Sans, Roboto, sans-serif;
#   font-size: 14px;
#   line-height: 20px;
#   padding: 8px 12px;
# }
# .chip {
#   display: inline-block;
#   border: solid 1px;
#   border-radius: 16px;
#   min-width: 14px;
#   padding: 5px 16px;
#   text-align: center;
#   user-select: none;
#   margin: 0 8px;
#   -webkit-tap-highlight-color: transparent;
# }
# .carousel {
#   overflow: auto;
#   scrollbar-width: none;
#   white-space: nowrap;
#   margin-right: -12px;
# }
# .headline {
#   display: flex;
#   margin-right: 4px;
# }
# .gradient-container {
#   position: relative;
# }
# .gradient {
#   position: absolute;
#   transform: translate(3px, -9px);
#   height: 36px;
#   width: 9px;
# }
# @media (prefers-color-scheme: light) {
#   .container {
#     background-color: #fafafa;
#     box-shadow: 0 0 0 1px #0000000f;
#   }
#   .headline-label {
#     color: #1f1f1f;
#   }
#   .chip {
#     background-color: #ffffff;
#     border-color: #d2d2d2;
#     color: #5e5e5e;
#     text-decoration: none;
#   }
#   .chip:hover {
#     background-color: #f2f2f2;
#   }
#   .chip:focus {
#     background-color: #f2f2f2;
#   }
#   .chip:active {
#     background-color: #d8d8d8;
#     border-color: #b6b6b6;
#   }
#   .logo-dark {
#     display: none;
#   }
#   .gradient {
#     background: linear-gradient(90deg, #fafafa 15%, #fafafa00 100%);
#   }
# }
# @media (prefers-color-scheme: dark) {
#   .container {
#     background-color: #1f1f1f;
#     box-shadow: 0 0 0 1px #ffffff26;
#   }
#   .headline-label {
#     color: #fff;
#   }
#   .chip {
#     background-color: #2c2c2c;
#     border-color: #3c4043;
#     color: #fff;
#     text-decoration: none;
#   }
#   .chip:hover {
#     background-color: #353536;
#   }
#   .chip:focus {
#     background-color: #353536;
#   }
#   .chip:active {
#     background-color: #464849;
#     border-color: #53575b;
#   }
#   .logo-light {
#     display: none;
#   }
#   .gradient {
#     background: linear-gradient(90deg, #1f1f1f 15%, #1f1f1f00 100%);
#   }
# }
# </style>
# <div class="container">
#   <div class="headline">
#     <svg class="logo-light" width="18" height="18" viewBox="9 9 35 35" fill="none" xmlns="http://www.w3.org/2000/svg">
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M42.8622 27.0064C42.8622 25.7839 42.7525 24.6084 42.5487 23.4799H26.3109V30.1568H35.5897C35.1821 32.3041 33.9596 34.1222 32.1258 35.3448V39.6864H37.7213C40.9814 36.677 42.8622 32.2571 42.8622 27.0064V27.0064Z" fill="#4285F4"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M26.3109 43.8555C30.9659 43.8555 34.8687 42.3195 37.7213 39.6863L32.1258 35.3447C30.5898 36.3792 28.6306 37.0061 26.3109 37.0061C21.8282 37.0061 18.0195 33.9811 16.6559 29.906H10.9194V34.3573C13.7563 39.9841 19.5712 43.8555 26.3109 43.8555V43.8555Z" fill="#34A853"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M16.6559 29.8904C16.3111 28.8559 16.1074 27.7588 16.1074 26.6146C16.1074 25.4704 16.3111 24.3733 16.6559 23.3388V18.8875H10.9194C9.74388 21.2072 9.06992 23.8247 9.06992 26.6146C9.06992 29.4045 9.74388 32.022 10.9194 34.3417L15.3864 30.8621L16.6559 29.8904V29.8904Z" fill="#FBBC05"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M26.3109 16.2386C28.85 16.2386 31.107 17.1164 32.9095 18.8091L37.8466 13.8719C34.853 11.082 30.9659 9.3736 26.3109 9.3736C19.5712 9.3736 13.7563 13.245 10.9194 18.8875L16.6559 23.3388C18.0195 19.2636 21.8282 16.2386 26.3109 16.2386V16.2386Z" fill="#EA4335"/>
#     </svg>
#     <svg class="logo-dark" width="18" height="18" viewBox="0 0 48 48" xmlns="http://www.w3.org/2000/svg">
#       <circle cx="24" cy="23" fill="#FFF" r="22"/>
#       <path d="M33.76 34.26c2.75-2.56 4.49-6.37 4.49-11.26 0-.89-.08-1.84-.29-3H24.01v5.99h8.03c-.4 2.02-1.5 3.56-3.07 4.56v.75l3.91 2.97h.88z" fill="#4285F4"/>
#       <path d="M15.58 25.77A8.845 8.845 0 0 0 24 31.86c1.92 0 3.62-.46 4.97-1.31l4.79 3.71C31.14 36.7 27.65 38 24 38c-5.93 0-11.01-3.4-13.45-8.36l.17-1.01 4.06-2.85h.8z" fill="#34A853"/>
#       <path d="M15.59 20.21a8.864 8.864 0 0 0 0 5.58l-5.03 3.86c-.98-2-1.53-4.25-1.53-6.64 0-2.39.55-4.64 1.53-6.64l1-.22 3.81 2.98.22 1.08z" fill="#FBBC05"/>
#       <path d="M24 14.14c2.11 0 4.02.75 5.52 1.98l4.36-4.36C31.22 9.43 27.81 8 24 8c-5.93 0-11.01 3.4-13.45 8.36l5.03 3.85A8.86 8.86 0 0 1 24 14.14z" fill="#EA4335"/>
#     </svg>
#     <div class="gradient-container"><div class="gradient"></div></div>
#   </div>
#   <div class="carousel">
#     <a class="chip" href="https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQEVL9mLmq7TqSwnfw2pq8kMeu-tUSqI1fgN3ZRjFf2k7qddmAkX-dC8tF0MXUQ7BXcprt1MGlf-ccj_iJenb_Yiez5itPSI-FJWtliMXorZRvFiGo-Oc5f_I9dEECNs_bbttUEp5GjTj9B0rMBDKsuA5s9kPi2VPvsXDiDKsjDRS7Na5ypHIP9_1hWMpUwDSosuNEGIg2V5-Nt7TNMB">Wildseed Palo Alto address</a>
#     <a class="chip" href="https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQE6qO_XUlQs_SWcIONn-DIMaIRhAInStbifHMx7bPFQQbBOkvD3dyChrQx8R9lQpyfYIxgTVJw2lOY3j0bTCtOhqqCzGM_ln86cbqvneSlCImKRyBIRMjqlWWAYwg9gt8KwaTfv0Z-MinXtQOpUjCw7c91F-byAfHaaHOVxrmxTDRUCxnLM_e-MVqP_-CIh5yBnSo0ZoUlkw1QO86dnbpIEHF7tmBQ=">Caltrain Palo Alto station address</a>
#   </div>
# </div>
# """
#   ),
#   web_search_queries=[
#     'Wildseed Palo Alto address',
#     'Caltrain Palo Alto station address',
#   ]
# ) partial=None turn_complete=None error_code=None error_message=None interrupted=None custom_metadata=None usage_metadata=GenerateContentResponseUsageMetadata(
#   candidates_token_count=160,
#   prompt_token_count=114,
#   prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=114
#     ),
#   ],
#   thoughts_token_count=136,
#   tool_use_prompt_token_count=185,
#   tool_use_prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=185
#     ),
#   ],
#   total_token_count=595
# ) live_session_resumption_update=None invocation_id='e-dab20e52-06db-4121-9e31-6bbcf8aa9752' author='transportation_agent' actions=EventActions(skip_summarization=None, state_delta={}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}) long_running_tool_ids=None branch=None id='0a632656-a4d3-489b-bf42-bd3052f4324c' timestamp=1755966430.321476
#
# --------------------------------------------------
# ✅ Final Response:
# To get to Wildseed from the Palo Alto Caltrain Station, follow these directions:
#
# 1.  **Start at Palo Alto Caltrain Station:** The station is located at 95 University Ave, Palo Alto, CA 94301.
# 2.  **Walk or Take Public Transit to Wildseed:** Wildseed is located at 855 El Camino Real, Palo Alto, CA 94301. This is approximately 0.8 miles away from the Caltrain station. You can walk there in about 15-20 minutes, or consider a short bus ride or ride-share option for a quicker trip.
# --------------------------------------------------
#
# --- find_and_navigate_agent Complete ---

# %% [markdown]
# ### Running the Streamlined App
#
# Notice how much simpler the code below is. There is no longer a special `if chosen_route == 'find_and_navigate_combo':` block with custom logic.
#
# The `find_and_navigate_agent` is now a self-contained unit. We can treat it just like any other agent, hand it the query, and trust the `SequentialAgent` to handle all the internal steps. This makes our main application code much cleaner and easier to read.

# %% [markdown]
# ---
# ## Iterative Ideas with `LoopAgent` 🧠→🔁→🤖
#
# Sometimes a task isn't a straight line; it's a loop of refinement. A user might ask for a plan, but have constraints that require checking and re-planning. For this, the ADK provides the **`LoopAgent`**.
#
# The `LoopAgent` executes a sequence of sub-agents repeatedly until a condition is met. This is perfect for workflows involving trial and error, like planning a trip with a tight schedule.
#
# **Our New Workflow: The Perfectionist Planner**
#
# 1. **Planner Agent**: Proposes an itinerary (e.g., a museum and a restaurant).
# 2. **Critic Agent**: Checks the plan against a constraint (e.g., "Is the travel time between these two places less than 30 minutes?").
# 3. **Refiner Agent**: If the critic finds a problem, this agent takes the feedback and creates a new, improved plan. If the critic is happy, it calls a special `exit_loop` tool to stop the process.
#
# The `LoopAgent` manages this cycle, ensuring we don't get stuck in an infinite loop by setting a `max_iterations` limit.

# %% [markdown]
# ```
# +-------------------------------+
# |  iterative_planner_agent 🔁   |
# | SequentialAgent:              |
# | 1. Propose Plan               |
# | 2. Refine in loop (≤ 3 times) |
# +---------------+---------------+
#                 |
#      +----------+----------+
#      |                     |
#      v                     v
# +----------------+   +-----------------------+
# | planner_agent  |   | refinement_loop 🔁     |
# | Propose plan   |   | LoopAgent             |
# | e.g., Activity +  | 1. Critic (time check) |
# | Restaurant       | 2. Refiner (fix/exit)   |
# +----------------+   +-----------------------+
#
# Uses shared state: {current_plan}, {criticism}
# Exits when: "Plan is feasible..."
#
# ```

# %%
# --- Agent Definitions for an Iterative Workflow ---

# A tool to signal that the loop should terminate
COMPLETION_PHRASE = "The plan is feasible and meets all constraints."
def exit_loop(tool_context: ToolContext):
  """Call this function ONLY when the plan is approved, signaling the loop should end."""
  print(f"  [Tool Call] exit_loop triggered by {tool_context.agent_name}")
  tool_context.actions.escalate = True
  return {}

# Agent 1: Proposes an initial plan
planner_agent = Agent(
    name="planner_agent", model="gemini-2.5-flash", tools=[google_search],
    instruction="You are a trip planner. Based on the user's request, propose a single activity and a single restaurant. Output only the names, like: 'Activity: Exploratorium, Restaurant: La Mar'.",
    output_key="current_plan"
)

# Agent 2 (in loop): Critiques the plan
critic_agent = Agent(
    name="critic_agent", model="gemini-2.5-flash", tools=[google_search],
    instruction=f"""You are a logistics expert. Your job is to critique a travel plan. The user has a strict constraint: total travel time must be short.
    Current Plan: {{current_plan}}
    Use your tools to check the travel time between the two locations.
    IF the travel time is over 45 minutes, provide a critique, like: 'This plan is inefficient. Find a restaurant closer to the activity.'
    ELSE, respond with the exact phrase: '{COMPLETION_PHRASE}'""",
    output_key="criticism"
)

# Agent 3 (in loop): Refines the plan or exits
refiner_agent = Agent(
    name="refiner_agent", model="gemini-2.5-flash", tools=[google_search, exit_loop],
    instruction=f"""You are a trip planner, refining a plan based on criticism.
    Original Request: {{session.query}}
    Critique: {{criticism}}
    IF the critique is '{COMPLETION_PHRASE}', you MUST call the 'exit_loop' tool.
    ELSE, generate a NEW plan that addresses the critique. Output only the new plan names, like: 'Activity: de Young Museum, Restaurant: Nopa'.""",
    output_key="current_plan"
)

# ✨ The LoopAgent orchestrates the critique-refine cycle ✨
refinement_loop = LoopAgent(
    name="refinement_loop",
    sub_agents=[critic_agent, refiner_agent],
    max_iterations=3
)

# ✨ The SequentialAgent puts it all together ✨
iterative_planner_agent = SequentialAgent(
    name="iterative_planner_agent",
    sub_agents=[planner_agent, refinement_loop],
    description="A workflow that iteratively plans and refines a trip to meet constraints."
)

print("🤖 Agent team updated with an iterative LoopAgent workflow!")
# Out:
# 🤖 Agent team updated with an iterative LoopAgent workflow!

# %% [markdown]
# ---
# ## Parallel Power with `ParallelAgent` 🧠→⚡️→🤖🤖🤖
#
# What if a user wants to find multiple, unrelated things at once? "Find me a museum, a concert, AND a restaurant." Running these searches one by one is slow and inefficient.
#
# Enter the **`ParallelAgent`**. This workflow agent executes a list of sub-agents *concurrently*, dramatically speeding up tasks that can be performed independently.
#
# **Our New Workflow: The Multi-Researcher**
#
# 1.  **Parallel Agent**: Simultaneously runs three specialist agents:
#     - `MuseumFinderAgent`: Finds a museum.
#     - `ConcertFinderAgent`: Finds a concert.
#     - `FoodieAgent`: Finds a restaurant.
# 2.  **Synthesis Agent**: Once all three parallel searches are complete, this final agent gathers the results (which were saved to the shared `state`) and formats them into a single, neat summary for the user.
#
# This pattern lets us get a lot of work done, fast! 🚀

# %% [markdown]
# ```
# +-------------------------------+
# |  parallel_planner_agent ⚡     |
# | SequentialAgent:              |
# | 1. Run parallel research      |
# | 2. Synthesize results         |
# +---------------+---------------+
#                 |
#      +----------+----------------------+
#      |                                 |
#      v                                 v
# +-------------------------+       +-----------------------------+
# | parallel_research_agent ⚡   |   | synthesis_agent 📋          |
# | ParallelAgent:              |   | Combine results            |
# | - museum_finder_agent 🖼️     |   | Output: Bulleted summary   |
# | - concert_finder_agent 🎵    |   +-----------------------------+
# | - restaurant_finder_agent 🍽️ |
# +-------------------------+
#
# Final Output:
# • Museum: XYZ
# • Concert: Artist at Venue
# • Restaurant: ABC
# ```

# %%
# --- Agent Definitions for a Parallel Workflow ---

# Specialist Agent 1
museum_finder_agent = Agent(
    name="museum_finder_agent", model="gemini-2.5-flash", tools=[google_search],
    instruction="You are a museum expert. Find the best museum based on the user's query. Output only the museum's name.",
    output_key="museum_result"
)

# Specialist Agent 2
concert_finder_agent = Agent(
    name="concert_finder_agent", model="gemini-2.5-flash", tools=[google_search],
    instruction="You are an events guide. Find a concert based on the user's query. Output only the concert name and artist.",
    output_key="concert_result"
)

# We can reuse our foodie_agent for the third parallel task!
# Just need to give it a new output_key for this workflow.
# restaurant_finder_agent = foodie_agent.copy(update={"output_key": "restaurant_result"})
restaurant_finder_agent = Agent(
    name="restaurant_finder_agent",
    model="gemini-2.5-flash",
    tools=[google_search],
    instruction="""You are an expert food critic. Your goal is to find the best restaurant based on a user's request.

    When you recommend a place, you must output *only* the name of the establishment.
    For example, if the best sushi is at 'Jin Sho', you should output only: Jin Sho
    """,
    output_key="restaurant_result" # Set the correct output key for this workflow
)


# ✨ The ParallelAgent runs all three specialists at once ✨
parallel_research_agent = ParallelAgent(
    name="parallel_research_agent",
    sub_agents=[museum_finder_agent, concert_finder_agent, restaurant_finder_agent]
)

# Agent to synthesize the parallel results
synthesis_agent = Agent(
    name="synthesis_agent", model="gemini-2.5-flash",
    instruction="""You are a helpful assistant. Combine the following research results into a clear, bulleted list for the user.
    - Museum: {museum_result}
    - Concert: {concert_result}
    - Restaurant: {restaurant_result}
    """
)

# ✨ The SequentialAgent runs the parallel search, then the synthesis ✨
parallel_planner_agent = SequentialAgent(
    name="parallel_planner_agent",
    sub_agents=[parallel_research_agent, synthesis_agent],
    description="A workflow that finds multiple things in parallel and then summarizes the results."
)

print("🤖 Agent team supercharged with a ParallelAgent workflow!")
# Out:
# 🤖 Agent team supercharged with a ParallelAgent workflow!

# %% [markdown]
# ---
# ### Final Step: Updating the Router and Running the App
#
# Now we just have one last thing to do: make our `router_agent` aware of these powerful new workflows! We'll add `iterative_planner_agent` and `parallel_planner_agent` to its list of available options.
#
# Then we can run our app with new queries designed to trigger these advanced, multi-agent workflows.

# %% [markdown]
# ```
#                     +---------------------+
#                     |    User Query 🗣️     |
#                     +----------+----------+
#                                |
#                                v
#                     +---------------------+
#                     |   Router Agent 🤖    |
#                     |  (Classify Request) |
#                     +----------+----------+
#                                |
#       +-----------+-----------+-----------+-----------+------------+
#       |           |           |           |           |            |
#       v           v           v           v           v            v
# +-------------+  +------------------+  +------------------+  +------------------+  +-----------------+
# | foodie_agent|  | find_and_navigate|  | iterative_planner|  | parallel_planner |  | day_trip_agent  |
# | 🍣 Food Only |  | 🧭 Seq Workflow   |  | 🔁 Loop Workflow  |  | ⚡ Parallel Tasks |  | 🧳 Basic Plan     |
# +-------------+  +------------------+  +------------------+  +------------------+  +-----------------+
# ```

# %%
# --- The ULTIMATE Router Agent --- #

router_agent = Agent(
    name="router_agent",
    model="gemini-2.5-flash",
    instruction="""
    You are a master request router. Your job is to analyze a user's query and decide which of the following agents or workflows is best suited to handle it.
    Do not answer the query yourself, only return the name of the most appropriate choice.

    Available Options:
    - 'foodie_agent': For queries *only* about finding a single food place.
    - 'find_and_navigate_agent': For queries that ask to *first find a place* and *then get directions* to it.
    - 'iterative_planner_agent': For planning a trip with a specific constraint that needs checking, like travel time.
    - 'parallel_planner_agent': For queries that ask to find multiple, independent things at once (e.g., a museum AND a concert AND a restaurant).
    - 'day_trip_agent': A general planner for any other simple day trip requests.

    Only return the single, most appropriate option's name and nothing else.
    """
)

# The master dictionary of all our executable agents and workflows
worker_agents = {
    "day_trip_agent": day_trip_agent,
    "foodie_agent": foodie_agent, # For simple food queries
    "find_and_navigate_agent": find_and_navigate_agent, # Sequential
    "iterative_planner_agent": iterative_planner_agent, # Loop
    "parallel_planner_agent": parallel_planner_agent,   # Parallel
}

# --- Let's Test Everything! ---

async def run_fully_loaded_app():
    queries = [
        # Test Case 1: Simple Sequential Flow
        "Find me the best sushi in Palo Alto and then tell me how to get there from the Caltrain station.",

        # Test Case 2: Iterative Loop Flow
        "Plan me a day in San Francisco with a museum and a nice dinner, but make sure the travel time between them is very short.",

        # Test Case 3: Parallel Flow
        "Help me plan a trip to SF. I need one museum, one concert, and one great restaurant."
    ]

    for query in queries:
        print(f"\n{'='*60}\n🗣️ Processing New Query: '{query}'\n{'='*60}")

        # 1. Ask the Router Agent to choose the right agent or workflow
        router_session = await session_service.create_session(app_name=router_agent.name, user_id=my_user_id)
        print("🧠 Asking the router agent to make a decision...")
        chosen_route = await run_agent_query(router_agent, query, router_session, my_user_id, is_router=True)
        chosen_route = chosen_route.strip().replace("'", "")
        print(f"🚦 Router has selected route: '{chosen_route}'")

        # 2. Execute the chosen route
        if chosen_route in worker_agents:
            worker_agent = worker_agents[chosen_route]
            print(f"--- Handing off to {worker_agent.name} ---")
            worker_session = await session_service.create_session(app_name=worker_agent.name, user_id=my_user_id)
            await run_agent_query(worker_agent, query, worker_session, my_user_id)
            print(f"--- {worker_agent.name} Complete ---")
        else:
            print(f"🚨 Error: Router chose an unknown route: '{chosen_route}'")

await run_fully_loaded_app()
# Out:
# ============================================================
# 🗣️ Processing New Query: 'Find me the best sushi in Palo Alto and then tell me how to get there from the Caltrain station.'
# ============================================================
# 🧠 Asking the router agent to make a decision...
#
# 🚀 Running query for agent: 'router_agent' in session: 'bc7cc3a7-c696-4f20-b0c8-52b23e21537a'...
# 🚦 Router has selected route: 'find_and_navigate_agent'
# --- Handing off to find_and_navigate_agent ---
#
# 🚀 Running query for agent: 'find_and_navigate_agent' in session: 'dca7ce7a-cc1d-4cc3-9208-c5590eab20b4'...
# EVENT: content=Content(
#   parts=[
#     Part(
#       text='Jin Sho'
#     ),
#   ],
#   role='model'
# ) grounding_metadata=GroundingMetadata(
#   search_entry_point=SearchEntryPoint(
#     rendered_content="""<style>
# .container {
#   align-items: center;
#   border-radius: 8px;
#   display: flex;
#   font-family: Google Sans, Roboto, sans-serif;
#   font-size: 14px;
#   line-height: 20px;
#   padding: 8px 12px;
# }
# .chip {
#   display: inline-block;
#   border: solid 1px;
#   border-radius: 16px;
#   min-width: 14px;
#   padding: 5px 16px;
#   text-align: center;
#   user-select: none;
#   margin: 0 8px;
#   -webkit-tap-highlight-color: transparent;
# }
# .carousel {
#   overflow: auto;
#   scrollbar-width: none;
#   white-space: nowrap;
#   margin-right: -12px;
# }
# .headline {
#   display: flex;
#   margin-right: 4px;
# }
# .gradient-container {
#   position: relative;
# }
# .gradient {
#   position: absolute;
#   transform: translate(3px, -9px);
#   height: 36px;
#   width: 9px;
# }
# @media (prefers-color-scheme: light) {
#   .container {
#     background-color: #fafafa;
#     box-shadow: 0 0 0 1px #0000000f;
#   }
#   .headline-label {
#     color: #1f1f1f;
#   }
#   .chip {
#     background-color: #ffffff;
#     border-color: #d2d2d2;
#     color: #5e5e5e;
#     text-decoration: none;
#   }
#   .chip:hover {
#     background-color: #f2f2f2;
#   }
#   .chip:focus {
#     background-color: #f2f2f2;
#   }
#   .chip:active {
#     background-color: #d8d8d8;
#     border-color: #b6b6b6;
#   }
#   .logo-dark {
#     display: none;
#   }
#   .gradient {
#     background: linear-gradient(90deg, #fafafa 15%, #fafafa00 100%);
#   }
# }
# @media (prefers-color-scheme: dark) {
#   .container {
#     background-color: #1f1f1f;
#     box-shadow: 0 0 0 1px #ffffff26;
#   }
#   .headline-label {
#     color: #fff;
#   }
#   .chip {
#     background-color: #2c2c2c;
#     border-color: #3c4043;
#     color: #fff;
#     text-decoration: none;
#   }
#   .chip:hover {
#     background-color: #353536;
#   }
#   .chip:focus {
#     background-color: #353536;
#   }
#   .chip:active {
#     background-color: #464849;
#     border-color: #53575b;
#   }
#   .logo-light {
#     display: none;
#   }
#   .gradient {
#     background: linear-gradient(90deg, #1f1f1f 15%, #1f1f1f00 100%);
#   }
# }
# </style>
# <div class="container">
#   <div class="headline">
#     <svg class="logo-light" width="18" height="18" viewBox="9 9 35 35" fill="none" xmlns="http://www.w3.org/2000/svg">
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M42.8622 27.0064C42.8622 25.7839 42.7525 24.6084 42.5487 23.4799H26.3109V30.1568H35.5897C35.1821 32.3041 33.9596 34.1222 32.1258 35.3448V39.6864H37.7213C40.9814 36.677 42.8622 32.2571 42.8622 27.0064V27.0064Z" fill="#4285F4"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M26.3109 43.8555C30.9659 43.8555 34.8687 42.3195 37.7213 39.6863L32.1258 35.3447C30.5898 36.3792 28.6306 37.0061 26.3109 37.0061C21.8282 37.0061 18.0195 33.9811 16.6559 29.906H10.9194V34.3573C13.7563 39.9841 19.5712 43.8555 26.3109 43.8555V43.8555Z" fill="#34A853"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M16.6559 29.8904C16.3111 28.8559 16.1074 27.7588 16.1074 26.6146C16.1074 25.4704 16.3111 24.3733 16.6559 23.3388V18.8875H10.9194C9.74388 21.2072 9.06992 23.8247 9.06992 26.6146C9.06992 29.4045 9.74388 32.022 10.9194 34.3417L15.3864 30.8621L16.6559 29.8904V29.8904Z" fill="#FBBC05"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M26.3109 16.2386C28.85 16.2386 31.107 17.1164 32.9095 18.8091L37.8466 13.8719C34.853 11.082 30.9659 9.3736 26.3109 9.3736C19.5712 9.3736 13.7563 13.245 10.9194 18.8875L16.6559 23.3388C18.0195 19.2636 21.8282 16.2386 26.3109 16.2386V16.2386Z" fill="#EA4335"/>
#     </svg>
#     <svg class="logo-dark" width="18" height="18" viewBox="0 0 48 48" xmlns="http://www.w3.org/2000/svg">
#       <circle cx="24" cy="23" fill="#FFF" r="22"/>
#       <path d="M33.76 34.26c2.75-2.56 4.49-6.37 4.49-11.26 0-.89-.08-1.84-.29-3H24.01v5.99h8.03c-.4 2.02-1.5 3.56-3.07 4.56v.75l3.91 2.97h.88z" fill="#4285F4"/>
#       <path d="M15.58 25.77A8.845 8.845 0 0 0 24 31.86c1.92 0 3.62-.46 4.97-1.31l4.79 3.71C31.14 36.7 27.65 38 24 38c-5.93 0-11.01-3.4-13.45-8.36l.17-1.01 4.06-2.85h.8z" fill="#34A853"/>
#       <path d="M15.59 20.21a8.864 8.864 0 0 0 0 5.58l-5.03 3.86c-.98-2-1.53-4.25-1.53-6.64 0-2.39.55-4.64 1.53-6.64l1-.22 3.81 2.98.22 1.08z" fill="#FBBC05"/>
#       <path d="M24 14.14c2.11 0 4.02.75 5.52 1.98l4.36-4.36C31.22 9.43 27.81 8 24 8c-5.93 0-11.01 3.4-13.45 8.36l5.03 3.85A8.86 8.86 0 0 1 24 14.14z" fill="#EA4335"/>
#     </svg>
#     <div class="gradient-container"><div class="gradient"></div></div>
#   </div>
#   <div class="carousel">
#     <a class="chip" href="https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQFsXz-KNLJOchycl-Ohk1f3h1Dv-XpsP2ugcCnJITKS5_tOby1_zzWmEAKi7wQswIDdO2pLM-9Zl7_ZWfPKOuhQV8pv0oJ9DJsiYpv1-IfJiXqVGkml706nsUdW2IW-jjdWTJBRllfN5lstgWkEzqc441ndz6tH_B8PdPkphkk9OWd8SnTe4C0LdjXq4dAILT7xfrkenJ4SJPlp--BaiU9opVEgKZ3PfjZTJw0UbCRuQ2wUFBdgo_wzkVz-ImN-G5-TzkeO-GQHpQofDZ6JeH3rnAmQmGfFfjv-vw==">walking directions from 95 University Ave Palo Alto to 454 California Avenue Palo Alto</a>
#   </div>
# </div>
# """
#   ),
#   web_search_queries=[
#     'best sushi in Palo Alto',
#     'Palo Alto Caltrain station to [restaurant name] directions',
#     'Jin Sho Palo Alto address',
#     'Palo Alto Caltrain station to Jin Sho directions',
#     'Palo Alto Caltrain station to 454 California Avenue Palo Alto walking directions',
#     <... 3 more items ...>,
#   ]
# ) partial=None turn_complete=None error_code=None error_message=None interrupted=None custom_metadata=None usage_metadata=GenerateContentResponseUsageMetadata(
#   cache_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=28
#     ),
#   ],
#   cached_content_token_count=28,
#   candidates_token_count=157,
#   prompt_token_count=110,
#   prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=110
#     ),
#   ],
#   thoughts_token_count=1359,
#   tool_use_prompt_token_count=2921,
#   tool_use_prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=2921
#     ),
#   ],
#   total_token_count=4547
# ) live_session_resumption_update=None invocation_id='e-86d80aac-12be-4f36-9fee-cb1455ff69f4' author='foodie_agent' actions=EventActions(skip_summarization=None, state_delta={'destination': 'Jin Sho'}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}) long_running_tool_ids=None branch=None id='e6973f58-a0f0-49ca-8eee-3e650abb487c' timestamp=1755966716.834453
# EVENT: content=Content(
#   parts=[
#     Part(
#       text="""To get to Jin Sho, a highly-rated sushi restaurant in Palo Alto, from the Caltrain station, you'll head to 454 California Avenue.
#
# Here are a few ways to get there:
#
# *   **By Bus (approximately 10 minutes):** Take the Line 21 bus from the Palo Alto Transit Center (which is at the Caltrain station) to Middlefield & Embarcadero. Services depart hourly.
# *   **By Taxi (approximately 3 minutes):** A taxi ride will take about 3 minutes and cost around $12-$15.
# *   **By Foot (approximately 31 minutes):** The walk from the Caltrain station to Jin Sho is about 1.6 miles and will take roughly 31 minutes."""
#     ),
#   ],
#   role='model'
# ) grounding_metadata=GroundingMetadata(
#   grounding_chunks=[
#     GroundingChunk(
#       web=GroundingChunkWeb(
#         title='jinshorestaurant.com',
#         uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQGAbsOHxHdX4w0CGdHL5zcmxJsV5sdLJ1CyA75ZZeWKFoj1FoVItnczhTYZ_tLpw9U7cEkC32u4awxnbVkh6oZ6-AgyXhurxp6eQPImPd0NjElmcZpqLOr_qcdUEA=='
#       )
#     ),
#     GroundingChunk(
#       web=GroundingChunkWeb(
#         title='restaurant.com',
#         uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQENiTfChRqBeAnYSVvFxDgZjKSfvReXGkiX5bOfvgIfGHuQkakEmgZqyFvXA6S4uzbkYpjPLgvz5E8wu0BQfWziP6JQK62SkaSBfO7LtTi0CnsOkhYDW0hjCLOYl3NVwzPRH6GTsXEjc1iJ32BJvNseAUPGSL4W4cd5tbpjJBiHlMCWQsEqYJP6mc9A6WSMH6QiAyBZYbyMYg=='
#       )
#     ),
#     GroundingChunk(
#       web=GroundingChunkWeb(
#         title='restaurants-world.com',
#         uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQGYAApHbHUbyXlcPQIAaINT7BzPQMGPAKzJukODXDiiK6BiaH6u1kuP8yByc48XD4Hqv8K3x7KCvIuTAOHarZ0H1sYzav-AcPKeBOepQeM4tnyNJkRt8Z9QOszN2Wr3tukl'
#       )
#     ),
#     GroundingChunk(
#       web=GroundingChunkWeb(
#         title='rome2rio.com',
#         uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQGeMR6qbGobFY1FDJsuG-nNRn0E21nJWWkvME2SPPLMh8-kfXXo6uOXYGiAm-4TSXwAVYwlPs81k6PFGuDbvja3eVs-WXoarp-dW0xMI6Nr_UZmDQ7ZITYBk015yAJU0NnmWPqHvLxEE_4TuxBrnt-EiZTFMkkZkVarqQ=='
#       )
#     ),
#   ],
#   grounding_supports=[
#     GroundingSupport(
#       grounding_chunk_indices=[
#         0,
#         1,
#         2,
#       ],
#       segment=Segment(
#         end_index=129,
#         text="To get to Jin Sho, a highly-rated sushi restaurant in Palo Alto, from the Caltrain station, you'll head to 454 California Avenue."
#       )
#     ),
#     GroundingSupport(
#       grounding_chunk_indices=[
#         3,
#       ],
#       segment=Segment(
#         end_index=352,
#         start_index=329,
#         text='Services depart hourly.'
#       )
#     ),
#     GroundingSupport(
#       grounding_chunk_indices=[
#         3,
#       ],
#       segment=Segment(
#         end_index=458,
#         start_index=353,
#         text='*   **By Taxi (approximately 3 minutes):** A taxi ride will take about 3 minutes and cost around $12-$15.'
#       )
#     ),
#     GroundingSupport(
#       grounding_chunk_indices=[
#         3,
#       ],
#       segment=Segment(
#         end_index=601,
#         start_index=459,
#         text='*   **By Foot (approximately 31 minutes):** The walk from the Caltrain station to Jin Sho is about 1.6 miles and will take roughly 31 minutes.'
#       )
#     ),
#   ],
#   search_entry_point=SearchEntryPoint(
#     rendered_content="""<style>
# .container {
#   align-items: center;
#   border-radius: 8px;
#   display: flex;
#   font-family: Google Sans, Roboto, sans-serif;
#   font-size: 14px;
#   line-height: 20px;
#   padding: 8px 12px;
# }
# .chip {
#   display: inline-block;
#   border: solid 1px;
#   border-radius: 16px;
#   min-width: 14px;
#   padding: 5px 16px;
#   text-align: center;
#   user-select: none;
#   margin: 0 8px;
#   -webkit-tap-highlight-color: transparent;
# }
# .carousel {
#   overflow: auto;
#   scrollbar-width: none;
#   white-space: nowrap;
#   margin-right: -12px;
# }
# .headline {
#   display: flex;
#   margin-right: 4px;
# }
# .gradient-container {
#   position: relative;
# }
# .gradient {
#   position: absolute;
#   transform: translate(3px, -9px);
#   height: 36px;
#   width: 9px;
# }
# @media (prefers-color-scheme: light) {
#   .container {
#     background-color: #fafafa;
#     box-shadow: 0 0 0 1px #0000000f;
#   }
#   .headline-label {
#     color: #1f1f1f;
#   }
#   .chip {
#     background-color: #ffffff;
#     border-color: #d2d2d2;
#     color: #5e5e5e;
#     text-decoration: none;
#   }
#   .chip:hover {
#     background-color: #f2f2f2;
#   }
#   .chip:focus {
#     background-color: #f2f2f2;
#   }
#   .chip:active {
#     background-color: #d8d8d8;
#     border-color: #b6b6b6;
#   }
#   .logo-dark {
#     display: none;
#   }
#   .gradient {
#     background: linear-gradient(90deg, #fafafa 15%, #fafafa00 100%);
#   }
# }
# @media (prefers-color-scheme: dark) {
#   .container {
#     background-color: #1f1f1f;
#     box-shadow: 0 0 0 1px #ffffff26;
#   }
#   .headline-label {
#     color: #fff;
#   }
#   .chip {
#     background-color: #2c2c2c;
#     border-color: #3c4043;
#     color: #fff;
#     text-decoration: none;
#   }
#   .chip:hover {
#     background-color: #353536;
#   }
#   .chip:focus {
#     background-color: #353536;
#   }
#   .chip:active {
#     background-color: #464849;
#     border-color: #53575b;
#   }
#   .logo-light {
#     display: none;
#   }
#   .gradient {
#     background: linear-gradient(90deg, #1f1f1f 15%, #1f1f1f00 100%);
#   }
# }
# </style>
# <div class="container">
#   <div class="headline">
#     <svg class="logo-light" width="18" height="18" viewBox="9 9 35 35" fill="none" xmlns="http://www.w3.org/2000/svg">
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M42.8622 27.0064C42.8622 25.7839 42.7525 24.6084 42.5487 23.4799H26.3109V30.1568H35.5897C35.1821 32.3041 33.9596 34.1222 32.1258 35.3448V39.6864H37.7213C40.9814 36.677 42.8622 32.2571 42.8622 27.0064V27.0064Z" fill="#4285F4"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M26.3109 43.8555C30.9659 43.8555 34.8687 42.3195 37.7213 39.6863L32.1258 35.3447C30.5898 36.3792 28.6306 37.0061 26.3109 37.0061C21.8282 37.0061 18.0195 33.9811 16.6559 29.906H10.9194V34.3573C13.7563 39.9841 19.5712 43.8555 26.3109 43.8555V43.8555Z" fill="#34A853"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M16.6559 29.8904C16.3111 28.8559 16.1074 27.7588 16.1074 26.6146C16.1074 25.4704 16.3111 24.3733 16.6559 23.3388V18.8875H10.9194C9.74388 21.2072 9.06992 23.8247 9.06992 26.6146C9.06992 29.4045 9.74388 32.022 10.9194 34.3417L15.3864 30.8621L16.6559 29.8904V29.8904Z" fill="#FBBC05"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M26.3109 16.2386C28.85 16.2386 31.107 17.1164 32.9095 18.8091L37.8466 13.8719C34.853 11.082 30.9659 9.3736 26.3109 9.3736C19.5712 9.3736 13.7563 13.245 10.9194 18.8875L16.6559 23.3388C18.0195 19.2636 21.8282 16.2386 26.3109 16.2386V16.2386Z" fill="#EA4335"/>
#     </svg>
#     <svg class="logo-dark" width="18" height="18" viewBox="0 0 48 48" xmlns="http://www.w3.org/2000/svg">
#       <circle cx="24" cy="23" fill="#FFF" r="22"/>
#       <path d="M33.76 34.26c2.75-2.56 4.49-6.37 4.49-11.26 0-.89-.08-1.84-.29-3H24.01v5.99h8.03c-.4 2.02-1.5 3.56-3.07 4.56v.75l3.91 2.97h.88z" fill="#4285F4"/>
#       <path d="M15.58 25.77A8.845 8.845 0 0 0 24 31.86c1.92 0 3.62-.46 4.97-1.31l4.79 3.71C31.14 36.7 27.65 38 24 38c-5.93 0-11.01-3.4-13.45-8.36l.17-1.01 4.06-2.85h.8z" fill="#34A853"/>
#       <path d="M15.59 20.21a8.864 8.864 0 0 0 0 5.58l-5.03 3.86c-.98-2-1.53-4.25-1.53-6.64 0-2.39.55-4.64 1.53-6.64l1-.22 3.81 2.98.22 1.08z" fill="#FBBC05"/>
#       <path d="M24 14.14c2.11 0 4.02.75 5.52 1.98l4.36-4.36C31.22 9.43 27.81 8 24 8c-5.93 0-11.01 3.4-13.45 8.36l5.03 3.85A8.86 8.86 0 0 1 24 14.14z" fill="#EA4335"/>
#     </svg>
#     <div class="gradient-container"><div class="gradient"></div></div>
#   </div>
#   <div class="carousel">
#     <a class="chip" href="https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQGYyJogWwWIWGkQqrS1LrHj1uEPqLsdVJPG1766ZLCmEFMtejKZ_ul8CPJBmunwOpopEinq7x9BK0COgmBjLUMvPsMIZqynbHFUQ6i0BJha1gh-Vkr3aVKzAjfr6LFUD2uy4ecDTI9s_pwReuYr67hJYIfSW_FidGJ2mihbfAPR9Xtpk5sLFgqJVo1zzgfsgZDxupZ4EOEMBinmUXc=">Jin Sho Palo Alto address</a>
#     <a class="chip" href="https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQHHQslcfp4I0FlJbplElVsBJLsD5Xdx6Ta4WwFxTyOfvUYVPPs3p-ri3P1UTo0VR8QXarGPTIbV-e3yLiYvFSxfoC0grR_GvvLdZU_XtPNYOLka6HhxdGmk9C-BIOP9tZBdXsqb1V3Il3lS15loMZLEYEkXKtVJr82NHgPNEStmXx0l9GiJ6uX0F4cmrTc4umZsu1XpdVgNWMuhxJyVrXnw9lCON7PXcQ8oOSX4jYJLM29-Ww==">Caltrain station Palo Alto to Jin Sho directions</a>
#   </div>
# </div>
# """
#   ),
#   web_search_queries=[
#     'Jin Sho Palo Alto address',
#     'Caltrain station Palo Alto to Jin Sho directions',
#   ]
# ) partial=None turn_complete=None error_code=None error_message=None interrupted=None custom_metadata=None usage_metadata=GenerateContentResponseUsageMetadata(
#   candidates_token_count=192,
#   prompt_token_count=113,
#   prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=113
#     ),
#   ],
#   thoughts_token_count=156,
#   tool_use_prompt_token_count=200,
#   tool_use_prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=200
#     ),
#   ],
#   total_token_count=661
# ) live_session_resumption_update=None invocation_id='e-86d80aac-12be-4f36-9fee-cb1455ff69f4' author='transportation_agent' actions=EventActions(skip_summarization=None, state_delta={}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}) long_running_tool_ids=None branch=None id='df731d22-6aea-4da7-90a3-41ad5c0cf057' timestamp=1755966735.01964
#
# --------------------------------------------------
# ✅ Final Response:
# To get to Jin Sho, a highly-rated sushi restaurant in Palo Alto, from the Caltrain station, you'll head to 454 California Avenue.
#
# Here are a few ways to get there:
#
# *   **By Bus (approximately 10 minutes):** Take the Line 21 bus from the Palo Alto Transit Center (which is at the Caltrain station) to Middlefield & Embarcadero. Services depart hourly.
# *   **By Taxi (approximately 3 minutes):** A taxi ride will take about 3 minutes and cost around $12-$15.
# *   **By Foot (approximately 31 minutes):** The walk from the Caltrain station to Jin Sho is about 1.6 miles and will take roughly 31 minutes.
# --------------------------------------------------
#
# --- find_and_navigate_agent Complete ---
#
# ============================================================
# 🗣️ Processing New Query: 'Plan me a day in San Francisco with a museum and a nice dinner, but make sure the travel time between them is very short.'
# ============================================================
# 🧠 Asking the router agent to make a decision...
#
# 🚀 Running query for agent: 'router_agent' in session: '0ef02605-dd24-4719-891d-231207306f06'...
# 🚦 Router has selected route: 'iterative_planner_agent'
# --- Handing off to iterative_planner_agent ---
#
# 🚀 Running query for agent: 'iterative_planner_agent' in session: 'ec97f691-a278-47b8-a082-e39eecbdc68c'...
# EVENT: content=Content(
#   parts=[
#     Part(
#       text="""Activity: Legion of Honor
# Restaurant: Legion of Honor Cafe"""
#     ),
#   ],
#   role='model'
# ) grounding_metadata=GroundingMetadata(
#   grounding_chunks=[
#     GroundingChunk(
#       web=GroundingChunkWeb(
#         title='wikipedia.org',
#         uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQHPF6e60_vRa8T39suRm3JsEk-SMcx6lzNBadyAvf1pzDIXTXHzBhJ3T7uVgpvwefMFoQoTYLUJmtPV5sO4UGi41CwHDmalbVEUpmWDx8GFDof4K5zNXT-pOJzOmrtl3UZ2XUOFT14ba1_zUTi1cN9bDA=='
#       )
#     ),
#     GroundingChunk(
#       web=GroundingChunkWeb(
#         title='bartgrocerybbq.com',
#         uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQEm24qxV2S5tnRA-HuhJuccWpuL-ZPTwVrGWRBjwbnolZbsbLKvfM5GuGBOBJNRCb40N9BllEkv3IGWSu4f1G0BLUbNLjcf43_6U9QG_DzQ2jaV95Yx_I-fW679NUrVmaRiX8EuJfPJICDCaw=='
#       )
#     ),
#   ],
#   grounding_supports=[
#     GroundingSupport(
#       grounding_chunk_indices=[
#         0,
#       ],
#       segment=Segment(
#         end_index=25,
#         text='Activity: Legion of Honor'
#       )
#     ),
#     GroundingSupport(
#       grounding_chunk_indices=[
#         1,
#       ],
#       segment=Segment(
#         end_index=58,
#         start_index=26,
#         text='Restaurant: Legion of Honor Cafe'
#       )
#     ),
#   ],
#   search_entry_point=SearchEntryPoint(
#     rendered_content="""<style>
# .container {
#   align-items: center;
#   border-radius: 8px;
#   display: flex;
#   font-family: Google Sans, Roboto, sans-serif;
#   font-size: 14px;
#   line-height: 20px;
#   padding: 8px 12px;
# }
# .chip {
#   display: inline-block;
#   border: solid 1px;
#   border-radius: 16px;
#   min-width: 14px;
#   padding: 5px 16px;
#   text-align: center;
#   user-select: none;
#   margin: 0 8px;
#   -webkit-tap-highlight-color: transparent;
# }
# .carousel {
#   overflow: auto;
#   scrollbar-width: none;
#   white-space: nowrap;
#   margin-right: -12px;
# }
# .headline {
#   display: flex;
#   margin-right: 4px;
# }
# .gradient-container {
#   position: relative;
# }
# .gradient {
#   position: absolute;
#   transform: translate(3px, -9px);
#   height: 36px;
#   width: 9px;
# }
# @media (prefers-color-scheme: light) {
#   .container {
#     background-color: #fafafa;
#     box-shadow: 0 0 0 1px #0000000f;
#   }
#   .headline-label {
#     color: #1f1f1f;
#   }
#   .chip {
#     background-color: #ffffff;
#     border-color: #d2d2d2;
#     color: #5e5e5e;
#     text-decoration: none;
#   }
#   .chip:hover {
#     background-color: #f2f2f2;
#   }
#   .chip:focus {
#     background-color: #f2f2f2;
#   }
#   .chip:active {
#     background-color: #d8d8d8;
#     border-color: #b6b6b6;
#   }
#   .logo-dark {
#     display: none;
#   }
#   .gradient {
#     background: linear-gradient(90deg, #fafafa 15%, #fafafa00 100%);
#   }
# }
# @media (prefers-color-scheme: dark) {
#   .container {
#     background-color: #1f1f1f;
#     box-shadow: 0 0 0 1px #ffffff26;
#   }
#   .headline-label {
#     color: #fff;
#   }
#   .chip {
#     background-color: #2c2c2c;
#     border-color: #3c4043;
#     color: #fff;
#     text-decoration: none;
#   }
#   .chip:hover {
#     background-color: #353536;
#   }
#   .chip:focus {
#     background-color: #353536;
#   }
#   .chip:active {
#     background-color: #464849;
#     border-color: #53575b;
#   }
#   .logo-light {
#     display: none;
#   }
#   .gradient {
#     background: linear-gradient(90deg, #1f1f1f 15%, #1f1f1f00 100%);
#   }
# }
# </style>
# <div class="container">
#   <div class="headline">
#     <svg class="logo-light" width="18" height="18" viewBox="9 9 35 35" fill="none" xmlns="http://www.w3.org/2000/svg">
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M42.8622 27.0064C42.8622 25.7839 42.7525 24.6084 42.5487 23.4799H26.3109V30.1568H35.5897C35.1821 32.3041 33.9596 34.1222 32.1258 35.3448V39.6864H37.7213C40.9814 36.677 42.8622 32.2571 42.8622 27.0064V27.0064Z" fill="#4285F4"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M26.3109 43.8555C30.9659 43.8555 34.8687 42.3195 37.7213 39.6863L32.1258 35.3447C30.5898 36.3792 28.6306 37.0061 26.3109 37.0061C21.8282 37.0061 18.0195 33.9811 16.6559 29.906H10.9194V34.3573C13.7563 39.9841 19.5712 43.8555 26.3109 43.8555V43.8555Z" fill="#34A853"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M16.6559 29.8904C16.3111 28.8559 16.1074 27.7588 16.1074 26.6146C16.1074 25.4704 16.3111 24.3733 16.6559 23.3388V18.8875H10.9194C9.74388 21.2072 9.06992 23.8247 9.06992 26.6146C9.06992 29.4045 9.74388 32.022 10.9194 34.3417L15.3864 30.8621L16.6559 29.8904V29.8904Z" fill="#FBBC05"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M26.3109 16.2386C28.85 16.2386 31.107 17.1164 32.9095 18.8091L37.8466 13.8719C34.853 11.082 30.9659 9.3736 26.3109 9.3736C19.5712 9.3736 13.7563 13.245 10.9194 18.8875L16.6559 23.3388C18.0195 19.2636 21.8282 16.2386 26.3109 16.2386V16.2386Z" fill="#EA4335"/>
#     </svg>
#     <svg class="logo-dark" width="18" height="18" viewBox="0 0 48 48" xmlns="http://www.w3.org/2000/svg">
#       <circle cx="24" cy="23" fill="#FFF" r="22"/>
#       <path d="M33.76 34.26c2.75-2.56 4.49-6.37 4.49-11.26 0-.89-.08-1.84-.29-3H24.01v5.99h8.03c-.4 2.02-1.5 3.56-3.07 4.56v.75l3.91 2.97h.88z" fill="#4285F4"/>
#       <path d="M15.58 25.77A8.845 8.845 0 0 0 24 31.86c1.92 0 3.62-.46 4.97-1.31l4.79 3.71C31.14 36.7 27.65 38 24 38c-5.93 0-11.01-3.4-13.45-8.36l.17-1.01 4.06-2.85h.8z" fill="#34A853"/>
#       <path d="M15.59 20.21a8.864 8.864 0 0 0 0 5.58l-5.03 3.86c-.98-2-1.53-4.25-1.53-6.64 0-2.39.55-4.64 1.53-6.64l1-.22 3.81 2.98.22 1.08z" fill="#FBBC05"/>
#       <path d="M24 14.14c2.11 0 4.02.75 5.52 1.98l4.36-4.36C31.22 9.43 27.81 8 24 8c-5.93 0-11.01 3.4-13.45 8.36l5.03 3.85A8.86 8.86 0 0 1 24 14.14z" fill="#EA4335"/>
#     </svg>
#     <div class="gradient-container"><div class="gradient"></div></div>
#   </div>
#   <div class="carousel">
#     <a class="chip" href="https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQEf04S366xj0B4Tc64YjEFv0BxKSypoBT2SRuDFa4OrgJc0AwUxjMIZkQ_oPc1lCTUZiKfvgwT6KbZ4fipo1w9EGR0Tx1BWGrzQgoS2IIL3uTlzY6RWkSbqYxLuWHLVRdOSAlO5fWK_bIAWDwrn8fZFmgSQyIMng07gySBtH_Fp3c0nW7l4YFz-WZ6geaTJ_MW6vLCCywnBx_t4zSqgnckXvLAgFevWs0OLkCh9Mbld8Qo=">restaurants near de Young Museum San Francisco</a>
#     <a class="chip" href="https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQFl_cc_YucagG2bYtLzcACwkUrHYUbFosW-6JRLZLDlkzeB9MI-Svp97aY63aeFyHxLifa4NNoKM1lhJpBaoa00BBHGHYS8Ygf2j3I-SPLHbH-xpSnhfPfXjJVyENdnjE-YwW90UrjH4bOrH_ds-ae8OxyNe_maX7ZQhDWmho2cQBVC6y9biamjWAC7dlrVfdwHGRGQSn-9F0gqbkhWi0ax7yZS05t5h8BUWP5YhK8VWN8=">restaurants near Legion of Honor San Francisco</a>
#     <a class="chip" href="https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQGJp4CBF374xE_DLrN7AFUJhy8RTLJ0zU6LVu3-dLITDGGiD_G7Hm8r7isAOnsY68T8HbeANGGA9WErsIMilzcRftX8jVVTEE3fdya5lnK99bB1_36kjSCLnYPvKmq6eoWj4XHACg-vN2PSboXV-sAO1ydfTjd8TJLS3WtUkib5iHbo7MZK4Goe6mhgnngDqYBgHSoagnZNk3pxSQ==">museums in San Francisco</a>
#     <a class="chip" href="https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQHEpuodVuFofV1_6E3jgdAH5J5lfTAygtGyo3ZSmqBE66-tq_5V1iRu8AuGmlddItb6jQKQ5addWxHGChWVDO6aJfYpihypuhzr_ZSKn70qfSuk8789e16N-9lK0rsroULi-5quK6ygaf22o4gBBPlB4F5gP4JpOnBY1jV39kqY--xkLyUyWBr0Z2n9a1NHqmhw7gHZFD6e7xfjet8OencHuGZ8bvRmMA==">Legion of Honor museum San Francisco</a>
#     <a class="chip" href="https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQFlvdla_ueA9q--SDTBbWPYPVe1ZeIfmvt5dv8MZckBfci6u4VPm5VqLpNB_GMj6jtwGa66GZqsPbKPFwls8mmvRt36iwnOLPnvhr77AjxjYbTNO1o7sxt_mzt7Zft26q3U58hC8vFD_D4z746_CPSrOklPFOj8dkDk9ciy-ExOEu9M2IggIPPCS40lWhNuxCm4V2PZHgghUnmNQ9_CCMyn">de Young Museum San Francisco</a>
#   </div>
# </div>
# """
#   ),
#   web_search_queries=[
#     'museums in San Francisco',
#     'Legion of Honor museum San Francisco',
#     'restaurants near Legion of Honor San Francisco',
#     'de Young Museum San Francisco',
#     'restaurants near de Young Museum San Francisco',
#   ]
# ) partial=None turn_complete=None error_code=None error_message=None interrupted=None custom_metadata=None usage_metadata=GenerateContentResponseUsageMetadata(
#   candidates_token_count=62,
#   prompt_token_count=85,
#   prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=85
#     ),
#   ],
#   thoughts_token_count=868,
#   tool_use_prompt_token_count=260,
#   tool_use_prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=260
#     ),
#   ],
#   total_token_count=1275
# ) live_session_resumption_update=None invocation_id='e-cf5ffa5e-bac2-4101-b73f-c83707a98ade' author='planner_agent' actions=EventActions(skip_summarization=None, state_delta={'current_plan': 'Activity: Legion of Honor\nRestaurant: Legion of Honor Cafe'}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}) long_running_tool_ids=None branch=None id='5dea7b99-9565-4561-87d4-28154d9612c9' timestamp=1755966747.85271
# EVENT: content=Content(
#   parts=[
#     Part(
#       text='The plan is feasible and meets all constraints.'
#     ),
#   ],
#   role='model'
# ) grounding_metadata=GroundingMetadata(
#   search_entry_point=SearchEntryPoint(
#     rendered_content="""<style>
# .container {
#   align-items: center;
#   border-radius: 8px;
#   display: flex;
#   font-family: Google Sans, Roboto, sans-serif;
#   font-size: 14px;
#   line-height: 20px;
#   padding: 8px 12px;
# }
# .chip {
#   display: inline-block;
#   border: solid 1px;
#   border-radius: 16px;
#   min-width: 14px;
#   padding: 5px 16px;
#   text-align: center;
#   user-select: none;
#   margin: 0 8px;
#   -webkit-tap-highlight-color: transparent;
# }
# .carousel {
#   overflow: auto;
#   scrollbar-width: none;
#   white-space: nowrap;
#   margin-right: -12px;
# }
# .headline {
#   display: flex;
#   margin-right: 4px;
# }
# .gradient-container {
#   position: relative;
# }
# .gradient {
#   position: absolute;
#   transform: translate(3px, -9px);
#   height: 36px;
#   width: 9px;
# }
# @media (prefers-color-scheme: light) {
#   .container {
#     background-color: #fafafa;
#     box-shadow: 0 0 0 1px #0000000f;
#   }
#   .headline-label {
#     color: #1f1f1f;
#   }
#   .chip {
#     background-color: #ffffff;
#     border-color: #d2d2d2;
#     color: #5e5e5e;
#     text-decoration: none;
#   }
#   .chip:hover {
#     background-color: #f2f2f2;
#   }
#   .chip:focus {
#     background-color: #f2f2f2;
#   }
#   .chip:active {
#     background-color: #d8d8d8;
#     border-color: #b6b6b6;
#   }
#   .logo-dark {
#     display: none;
#   }
#   .gradient {
#     background: linear-gradient(90deg, #fafafa 15%, #fafafa00 100%);
#   }
# }
# @media (prefers-color-scheme: dark) {
#   .container {
#     background-color: #1f1f1f;
#     box-shadow: 0 0 0 1px #ffffff26;
#   }
#   .headline-label {
#     color: #fff;
#   }
#   .chip {
#     background-color: #2c2c2c;
#     border-color: #3c4043;
#     color: #fff;
#     text-decoration: none;
#   }
#   .chip:hover {
#     background-color: #353536;
#   }
#   .chip:focus {
#     background-color: #353536;
#   }
#   .chip:active {
#     background-color: #464849;
#     border-color: #53575b;
#   }
#   .logo-light {
#     display: none;
#   }
#   .gradient {
#     background: linear-gradient(90deg, #1f1f1f 15%, #1f1f1f00 100%);
#   }
# }
# </style>
# <div class="container">
#   <div class="headline">
#     <svg class="logo-light" width="18" height="18" viewBox="9 9 35 35" fill="none" xmlns="http://www.w3.org/2000/svg">
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M42.8622 27.0064C42.8622 25.7839 42.7525 24.6084 42.5487 23.4799H26.3109V30.1568H35.5897C35.1821 32.3041 33.9596 34.1222 32.1258 35.3448V39.6864H37.7213C40.9814 36.677 42.8622 32.2571 42.8622 27.0064V27.0064Z" fill="#4285F4"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M26.3109 43.8555C30.9659 43.8555 34.8687 42.3195 37.7213 39.6863L32.1258 35.3447C30.5898 36.3792 28.6306 37.0061 26.3109 37.0061C21.8282 37.0061 18.0195 33.9811 16.6559 29.906H10.9194V34.3573C13.7563 39.9841 19.5712 43.8555 26.3109 43.8555V43.8555Z" fill="#34A853"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M16.6559 29.8904C16.3111 28.8559 16.1074 27.7588 16.1074 26.6146C16.1074 25.4704 16.3111 24.3733 16.6559 23.3388V18.8875H10.9194C9.74388 21.2072 9.06992 23.8247 9.06992 26.6146C9.06992 29.4045 9.74388 32.022 10.9194 34.3417L15.3864 30.8621L16.6559 29.8904V29.8904Z" fill="#FBBC05"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M26.3109 16.2386C28.85 16.2386 31.107 17.1164 32.9095 18.8091L37.8466 13.8719C34.853 11.082 30.9659 9.3736 26.3109 9.3736C19.5712 9.3736 13.7563 13.245 10.9194 18.8875L16.6559 23.3388C18.0195 19.2636 21.8282 16.2386 26.3109 16.2386V16.2386Z" fill="#EA4335"/>
#     </svg>
#     <svg class="logo-dark" width="18" height="18" viewBox="0 0 48 48" xmlns="http://www.w3.org/2000/svg">
#       <circle cx="24" cy="23" fill="#FFF" r="22"/>
#       <path d="M33.76 34.26c2.75-2.56 4.49-6.37 4.49-11.26 0-.89-.08-1.84-.29-3H24.01v5.99h8.03c-.4 2.02-1.5 3.56-3.07 4.56v.75l3.91 2.97h.88z" fill="#4285F4"/>
#       <path d="M15.58 25.77A8.845 8.845 0 0 0 24 31.86c1.92 0 3.62-.46 4.97-1.31l4.79 3.71C31.14 36.7 27.65 38 24 38c-5.93 0-11.01-3.4-13.45-8.36l.17-1.01 4.06-2.85h.8z" fill="#34A853"/>
#       <path d="M15.59 20.21a8.864 8.864 0 0 0 0 5.58l-5.03 3.86c-.98-2-1.53-4.25-1.53-6.64 0-2.39.55-4.64 1.53-6.64l1-.22 3.81 2.98.22 1.08z" fill="#FBBC05"/>
#       <path d="M24 14.14c2.11 0 4.02.75 5.52 1.98l4.36-4.36C31.22 9.43 27.81 8 24 8c-5.93 0-11.01 3.4-13.45 8.36l5.03 3.85A8.86 8.86 0 0 1 24 14.14z" fill="#EA4335"/>
#     </svg>
#     <div class="gradient-container"><div class="gradient"></div></div>
#   </div>
#   <div class="carousel">
#     <a class="chip" href="https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQGKxzso_kegYpQji7tFTqOR0J3XzHL1OL9F4nXWOyB_KoBA5aeAeRkYi9oH6YmQMIgAbBHkZclB5nlAkcAtN-nAfcHE1MYKmDoieuQTjPeH7Zw970R0vTRPXfZ5cEY0GCdOPVPCZWDy6XLMzxqC_2zJrqSCxV4JlGndUimVfeYkrTEyYoSXysHMJc_sf18jltFStyIzdPIXsexd-2fsQ-7TIf3tLtBaPo7GpXtJfF6IFhQRoogZ6B8=">Legion of Honor to Legion of Honor Cafe travel time</a>
#     <a class="chip" href="https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQFzm7PxTBGzPfX2Li1FrfZ-jpDe1QR8aHGy3MOmDVUOMQVU3RmNEFGe3bph6KVcnQLdLvo0v4dF0-kVH5QzFbdT9QENTVxnN72QvyyBv_2uNCE31PvhW6yJrbP_cIIjJgySpyjeesLU9vVzSwvCwUk4B5CLUUa4h-w5inWGaRbEAKGHPQHwNCR7Z-vMLDdp3HOA0HxequIOyiEyPbgqLI9O">Legion of Honor Cafe location</a>
#   </div>
# </div>
# """
#   ),
#   web_search_queries=[
#     'Legion of Honor to Legion of Honor Cafe travel time',
#     'Legion of Honor Cafe location',
#   ]
# ) partial=None turn_complete=None error_code=None error_message=None interrupted=None custom_metadata=None usage_metadata=GenerateContentResponseUsageMetadata(
#   candidates_token_count=39,
#   prompt_token_count=181,
#   prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=181
#     ),
#   ],
#   thoughts_token_count=294,
#   tool_use_prompt_token_count=385,
#   tool_use_prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=385
#     ),
#   ],
#   total_token_count=899
# ) live_session_resumption_update=None invocation_id='e-cf5ffa5e-bac2-4101-b73f-c83707a98ade' author='critic_agent' actions=EventActions(skip_summarization=None, state_delta={'criticism': 'The plan is feasible and meets all constraints.'}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}) long_running_tool_ids=None branch=None id='c3b5666f-1525-4734-a146-a099ffe8b8bd' timestamp=1755966762.350747
#
# --------------------------------------------------
# ✅ Final Response:
# An error occurred: 400 INVALID_ARGUMENT. {'error': {'code': 400, 'message': 'Tool use with function calling is unsupported', 'status': 'INVALID_ARGUMENT'}}
# --------------------------------------------------
#
# --- iterative_planner_agent Complete ---
#
# ============================================================
# 🗣️ Processing New Query: 'Help me plan a trip to SF. I need one museum, one concert, and one great restaurant.'
# ============================================================
# 🧠 Asking the router agent to make a decision...
#
# 🚀 Running query for agent: 'router_agent' in session: '41ef6ee8-74ef-45c3-95d5-96eaa8996332'...
# 🚦 Router has selected route: 'parallel_planner_agent'
# --- Handing off to parallel_planner_agent ---
#
# 🚀 Running query for agent: 'parallel_planner_agent' in session: '955282de-fd68-47de-b90b-46737429a706'...
# EVENT: content=Content(
#   parts=[
#     Part(
#       text='California Academy of Sciences.'
#     ),
#   ],
#   role='model'
# ) grounding_metadata=GroundingMetadata(
#   search_entry_point=SearchEntryPoint(
#     rendered_content="""<style>
# .container {
#   align-items: center;
#   border-radius: 8px;
#   display: flex;
#   font-family: Google Sans, Roboto, sans-serif;
#   font-size: 14px;
#   line-height: 20px;
#   padding: 8px 12px;
# }
# .chip {
#   display: inline-block;
#   border: solid 1px;
#   border-radius: 16px;
#   min-width: 14px;
#   padding: 5px 16px;
#   text-align: center;
#   user-select: none;
#   margin: 0 8px;
#   -webkit-tap-highlight-color: transparent;
# }
# .carousel {
#   overflow: auto;
#   scrollbar-width: none;
#   white-space: nowrap;
#   margin-right: -12px;
# }
# .headline {
#   display: flex;
#   margin-right: 4px;
# }
# .gradient-container {
#   position: relative;
# }
# .gradient {
#   position: absolute;
#   transform: translate(3px, -9px);
#   height: 36px;
#   width: 9px;
# }
# @media (prefers-color-scheme: light) {
#   .container {
#     background-color: #fafafa;
#     box-shadow: 0 0 0 1px #0000000f;
#   }
#   .headline-label {
#     color: #1f1f1f;
#   }
#   .chip {
#     background-color: #ffffff;
#     border-color: #d2d2d2;
#     color: #5e5e5e;
#     text-decoration: none;
#   }
#   .chip:hover {
#     background-color: #f2f2f2;
#   }
#   .chip:focus {
#     background-color: #f2f2f2;
#   }
#   .chip:active {
#     background-color: #d8d8d8;
#     border-color: #b6b6b6;
#   }
#   .logo-dark {
#     display: none;
#   }
#   .gradient {
#     background: linear-gradient(90deg, #fafafa 15%, #fafafa00 100%);
#   }
# }
# @media (prefers-color-scheme: dark) {
#   .container {
#     background-color: #1f1f1f;
#     box-shadow: 0 0 0 1px #ffffff26;
#   }
#   .headline-label {
#     color: #fff;
#   }
#   .chip {
#     background-color: #2c2c2c;
#     border-color: #3c4043;
#     color: #fff;
#     text-decoration: none;
#   }
#   .chip:hover {
#     background-color: #353536;
#   }
#   .chip:focus {
#     background-color: #353536;
#   }
#   .chip:active {
#     background-color: #464849;
#     border-color: #53575b;
#   }
#   .logo-light {
#     display: none;
#   }
#   .gradient {
#     background: linear-gradient(90deg, #1f1f1f 15%, #1f1f1f00 100%);
#   }
# }
# </style>
# <div class="container">
#   <div class="headline">
#     <svg class="logo-light" width="18" height="18" viewBox="9 9 35 35" fill="none" xmlns="http://www.w3.org/2000/svg">
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M42.8622 27.0064C42.8622 25.7839 42.7525 24.6084 42.5487 23.4799H26.3109V30.1568H35.5897C35.1821 32.3041 33.9596 34.1222 32.1258 35.3448V39.6864H37.7213C40.9814 36.677 42.8622 32.2571 42.8622 27.0064V27.0064Z" fill="#4285F4"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M26.3109 43.8555C30.9659 43.8555 34.8687 42.3195 37.7213 39.6863L32.1258 35.3447C30.5898 36.3792 28.6306 37.0061 26.3109 37.0061C21.8282 37.0061 18.0195 33.9811 16.6559 29.906H10.9194V34.3573C13.7563 39.9841 19.5712 43.8555 26.3109 43.8555V43.8555Z" fill="#34A853"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M16.6559 29.8904C16.3111 28.8559 16.1074 27.7588 16.1074 26.6146C16.1074 25.4704 16.3111 24.3733 16.6559 23.3388V18.8875H10.9194C9.74388 21.2072 9.06992 23.8247 9.06992 26.6146C9.06992 29.4045 9.74388 32.022 10.9194 34.3417L15.3864 30.8621L16.6559 29.8904V29.8904Z" fill="#FBBC05"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M26.3109 16.2386C28.85 16.2386 31.107 17.1164 32.9095 18.8091L37.8466 13.8719C34.853 11.082 30.9659 9.3736 26.3109 9.3736C19.5712 9.3736 13.7563 13.245 10.9194 18.8875L16.6559 23.3388C18.0195 19.2636 21.8282 16.2386 26.3109 16.2386V16.2386Z" fill="#EA4335"/>
#     </svg>
#     <svg class="logo-dark" width="18" height="18" viewBox="0 0 48 48" xmlns="http://www.w3.org/2000/svg">
#       <circle cx="24" cy="23" fill="#FFF" r="22"/>
#       <path d="M33.76 34.26c2.75-2.56 4.49-6.37 4.49-11.26 0-.89-.08-1.84-.29-3H24.01v5.99h8.03c-.4 2.02-1.5 3.56-3.07 4.56v.75l3.91 2.97h.88z" fill="#4285F4"/>
#       <path d="M15.58 25.77A8.845 8.845 0 0 0 24 31.86c1.92 0 3.62-.46 4.97-1.31l4.79 3.71C31.14 36.7 27.65 38 24 38c-5.93 0-11.01-3.4-13.45-8.36l.17-1.01 4.06-2.85h.8z" fill="#34A853"/>
#       <path d="M15.59 20.21a8.864 8.864 0 0 0 0 5.58l-5.03 3.86c-.98-2-1.53-4.25-1.53-6.64 0-2.39.55-4.64 1.53-6.64l1-.22 3.81 2.98.22 1.08z" fill="#FBBC05"/>
#       <path d="M24 14.14c2.11 0 4.02.75 5.52 1.98l4.36-4.36C31.22 9.43 27.81 8 24 8c-5.93 0-11.01 3.4-13.45 8.36l5.03 3.85A8.86 8.86 0 0 1 24 14.14z" fill="#EA4335"/>
#     </svg>
#     <div class="gradient-container"><div class="gradient"></div></div>
#   </div>
#   <div class="carousel">
#     <a class="chip" href="https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQHX-pun3Bu6ceIShji8KdWKKDcfFGmgeqOMzWDoAQsIew15NXXzF20FeWt6wUUL3-1qak3jt6v7rhtzRR-Y5HCpar4xAnqhcyqY1T3TaoE2uAihD3mTPR4lLgBtPlkexeCW6JJHRnFHTAovGtW0GP8zddvoSjc0iu1pqQNkdyYBmiwcA5iC7P3y3FarmmNGln6NDbFYNpLwCmXLFIorqUg4Qf0=">top-rated museums San Francisco</a>
#     <a class="chip" href="https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQED5jH5s04qVcmwZcmkB-3WAEsWxKcXvc5lQxESx4qspaROTJ-z4phzzhu_Fdm_QSNxif5XoU0_gogwFkhxD70CyGeIBT1AKXA1UnLGVqPpy7ewfz3hvSj8osNdkq3zp_ARS0rmW64zzJeBHhek7dyL88sFlvk9oOl1bDRXfjZo7_VtNs5jKgjq_qEjA0i8qL_fYd8N7XUK9ghHt5f8nNTP">best museums in San Francisco</a>
#   </div>
# </div>
# """
#   ),
#   web_search_queries=[
#     'best museums in San Francisco',
#     'top-rated museums San Francisco',
#   ]
# ) partial=None turn_complete=None error_code=None error_message=None interrupted=None custom_metadata=None usage_metadata=GenerateContentResponseUsageMetadata(
#   candidates_token_count=29,
#   prompt_token_count=66,
#   prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=66
#     ),
#   ],
#   thoughts_token_count=445,
#   tool_use_prompt_token_count=226,
#   tool_use_prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=226
#     ),
#   ],
#   total_token_count=766
# ) live_session_resumption_update=None invocation_id='e-a62de101-4abf-47f2-88a4-1794d054948b' author='museum_finder_agent' actions=EventActions(skip_summarization=None, state_delta={'museum_result': 'California Academy of Sciences.'}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}) long_running_tool_ids=None branch='parallel_research_agent.museum_finder_agent' id='922e0839-76c1-467a-8dcb-580517ffa775' timestamp=1755966772.055968
# EVENT: content=Content(
#   parts=[
#     Part(
#       text='Snarky Puppy'
#     ),
#   ],
#   role='model'
# ) grounding_metadata=GroundingMetadata(
#   search_entry_point=SearchEntryPoint(
#     rendered_content="""<style>
# .container {
#   align-items: center;
#   border-radius: 8px;
#   display: flex;
#   font-family: Google Sans, Roboto, sans-serif;
#   font-size: 14px;
#   line-height: 20px;
#   padding: 8px 12px;
# }
# .chip {
#   display: inline-block;
#   border: solid 1px;
#   border-radius: 16px;
#   min-width: 14px;
#   padding: 5px 16px;
#   text-align: center;
#   user-select: none;
#   margin: 0 8px;
#   -webkit-tap-highlight-color: transparent;
# }
# .carousel {
#   overflow: auto;
#   scrollbar-width: none;
#   white-space: nowrap;
#   margin-right: -12px;
# }
# .headline {
#   display: flex;
#   margin-right: 4px;
# }
# .gradient-container {
#   position: relative;
# }
# .gradient {
#   position: absolute;
#   transform: translate(3px, -9px);
#   height: 36px;
#   width: 9px;
# }
# @media (prefers-color-scheme: light) {
#   .container {
#     background-color: #fafafa;
#     box-shadow: 0 0 0 1px #0000000f;
#   }
#   .headline-label {
#     color: #1f1f1f;
#   }
#   .chip {
#     background-color: #ffffff;
#     border-color: #d2d2d2;
#     color: #5e5e5e;
#     text-decoration: none;
#   }
#   .chip:hover {
#     background-color: #f2f2f2;
#   }
#   .chip:focus {
#     background-color: #f2f2f2;
#   }
#   .chip:active {
#     background-color: #d8d8d8;
#     border-color: #b6b6b6;
#   }
#   .logo-dark {
#     display: none;
#   }
#   .gradient {
#     background: linear-gradient(90deg, #fafafa 15%, #fafafa00 100%);
#   }
# }
# @media (prefers-color-scheme: dark) {
#   .container {
#     background-color: #1f1f1f;
#     box-shadow: 0 0 0 1px #ffffff26;
#   }
#   .headline-label {
#     color: #fff;
#   }
#   .chip {
#     background-color: #2c2c2c;
#     border-color: #3c4043;
#     color: #fff;
#     text-decoration: none;
#   }
#   .chip:hover {
#     background-color: #353536;
#   }
#   .chip:focus {
#     background-color: #353536;
#   }
#   .chip:active {
#     background-color: #464849;
#     border-color: #53575b;
#   }
#   .logo-light {
#     display: none;
#   }
#   .gradient {
#     background: linear-gradient(90deg, #1f1f1f 15%, #1f1f1f00 100%);
#   }
# }
# </style>
# <div class="container">
#   <div class="headline">
#     <svg class="logo-light" width="18" height="18" viewBox="9 9 35 35" fill="none" xmlns="http://www.w3.org/2000/svg">
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M42.8622 27.0064C42.8622 25.7839 42.7525 24.6084 42.5487 23.4799H26.3109V30.1568H35.5897C35.1821 32.3041 33.9596 34.1222 32.1258 35.3448V39.6864H37.7213C40.9814 36.677 42.8622 32.2571 42.8622 27.0064V27.0064Z" fill="#4285F4"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M26.3109 43.8555C30.9659 43.8555 34.8687 42.3195 37.7213 39.6863L32.1258 35.3447C30.5898 36.3792 28.6306 37.0061 26.3109 37.0061C21.8282 37.0061 18.0195 33.9811 16.6559 29.906H10.9194V34.3573C13.7563 39.9841 19.5712 43.8555 26.3109 43.8555V43.8555Z" fill="#34A853"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M16.6559 29.8904C16.3111 28.8559 16.1074 27.7588 16.1074 26.6146C16.1074 25.4704 16.3111 24.3733 16.6559 23.3388V18.8875H10.9194C9.74388 21.2072 9.06992 23.8247 9.06992 26.6146C9.06992 29.4045 9.74388 32.022 10.9194 34.3417L15.3864 30.8621L16.6559 29.8904V29.8904Z" fill="#FBBC05"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M26.3109 16.2386C28.85 16.2386 31.107 17.1164 32.9095 18.8091L37.8466 13.8719C34.853 11.082 30.9659 9.3736 26.3109 9.3736C19.5712 9.3736 13.7563 13.245 10.9194 18.8875L16.6559 23.3388C18.0195 19.2636 21.8282 16.2386 26.3109 16.2386V16.2386Z" fill="#EA4335"/>
#     </svg>
#     <svg class="logo-dark" width="18" height="18" viewBox="0 0 48 48" xmlns="http://www.w3.org/2000/svg">
#       <circle cx="24" cy="23" fill="#FFF" r="22"/>
#       <path d="M33.76 34.26c2.75-2.56 4.49-6.37 4.49-11.26 0-.89-.08-1.84-.29-3H24.01v5.99h8.03c-.4 2.02-1.5 3.56-3.07 4.56v.75l3.91 2.97h.88z" fill="#4285F4"/>
#       <path d="M15.58 25.77A8.845 8.845 0 0 0 24 31.86c1.92 0 3.62-.46 4.97-1.31l4.79 3.71C31.14 36.7 27.65 38 24 38c-5.93 0-11.01-3.4-13.45-8.36l.17-1.01 4.06-2.85h.8z" fill="#34A853"/>
#       <path d="M15.59 20.21a8.864 8.864 0 0 0 0 5.58l-5.03 3.86c-.98-2-1.53-4.25-1.53-6.64 0-2.39.55-4.64 1.53-6.64l1-.22 3.81 2.98.22 1.08z" fill="#FBBC05"/>
#       <path d="M24 14.14c2.11 0 4.02.75 5.52 1.98l4.36-4.36C31.22 9.43 27.81 8 24 8c-5.93 0-11.01 3.4-13.45 8.36l5.03 3.85A8.86 8.86 0 0 1 24 14.14z" fill="#EA4335"/>
#     </svg>
#     <div class="gradient-container"><div class="gradient"></div></div>
#   </div>
#   <div class="carousel">
#     <a class="chip" href="https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQHG3jRZn3Po6wcW3hSLpCZ54qLXVWdennBot3r8CxJr7MQnyTlBrBayt0Z3ftkK7klzSMrHXwiFXNzrpE9ZvNpj3dzH31oy6sD2ifvGu3yQ67iDrbfHQBMQ0WxNz3FEYDZ0vtOPV0e5B_SKzAmWNvQaTFkEFhtJmyotUf4udx-eaPLKB25XCFzSNYJa0DO18hbxzMjZgX_Fp4aOiwbO5QMx2w==">best restaurants San Francisco</a>
#     <a class="chip" href="https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQFbOnHa0I5lhxB_G0IfSzaM6Z84zJmGGE9nKViqSwY0pLPv0qkx72tcm2Pn0WU2Eo3fKun3iQ7Aql3JFDEnxCpBZjXPRBDhxy_mKLObYUI2ePgZ83biEkfQkUK5Q0vygwdHJLAsYHD3SnnzB218AUMjD5wZ5lr089RJnUy5ipRTquH1E3hLylzLuTzYkTBqKSJBInLhiTIaLds1zNFJDlbl">popular museums San Francisco</a>
#     <a class="chip" href="https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQERv2a3qvyGj9NswOgO9QB5jgWTrbSNdM13jvZZfPJUhqVw-9h6gUIjbfNWsVUdjDmAGV5XuyKKZGeoZ1Yn9s4nc7RXTkjBUa01VpdZSv-DaO-NMgwvbrWdUkrRpxVBrrETf7wc3pM7kGUCQOc8cYOW6ME0als4GW0arK5y3foRHmQP9CgAhVOAj6usngm3a2dU7H-gbUnaG2rd5Qu7J7xunQAMAGI=">concerts San Francisco August 2025</a>
#     <a class="chip" href="https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQFzQ_DFLtwCFGAAqzoT6neYGOnkNHaLNWGtBGK_nuhtVRLg3jipZgn50W0MhSI6M-kFfOQkYSh7Gkeb5IoFfxZ_pgQ5OY4DDwfynOqULJSqORI2H0JIpWTzbAPa4pgqGI5B1xf8z39UiCrfvZ5mviBqlb6mepPguGXdVzoB-7INLMUBYE5A5asJwh-h4QDpKS2JSO5rCFvjlx4tL7Ce0ImfYyycdWA52EM=">concerts San Francisco September 2025</a>
#   </div>
# </div>
# """
#   ),
#   web_search_queries=[
#     'concerts San Francisco August 2025',
#     'concerts San Francisco September 2025',
#     'popular museums San Francisco',
#     'best restaurants San Francisco',
#   ]
# ) partial=None turn_complete=None error_code=None error_message=None interrupted=None custom_metadata=None usage_metadata=GenerateContentResponseUsageMetadata(
#   candidates_token_count=49,
#   prompt_token_count=65,
#   prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=65
#     ),
#   ],
#   thoughts_token_count=1315,
#   tool_use_prompt_token_count=267,
#   tool_use_prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=267
#     ),
#   ],
#   total_token_count=1696
# ) live_session_resumption_update=None invocation_id='e-a62de101-4abf-47f2-88a4-1794d054948b' author='concert_finder_agent' actions=EventActions(skip_summarization=None, state_delta={'concert_result': 'Snarky Puppy'}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}) long_running_tool_ids=None branch='parallel_research_agent.concert_finder_agent' id='ca4fb87e-a277-4539-8a13-4414167f9d5b' timestamp=1755966772.152851
# EVENT: content=Content(
#   parts=[
#     Part(
#       text='Gary Danko'
#     ),
#   ],
#   role='model'
# ) grounding_metadata=GroundingMetadata(
#   search_entry_point=SearchEntryPoint(
#     rendered_content="""<style>
# .container {
#   align-items: center;
#   border-radius: 8px;
#   display: flex;
#   font-family: Google Sans, Roboto, sans-serif;
#   font-size: 14px;
#   line-height: 20px;
#   padding: 8px 12px;
# }
# .chip {
#   display: inline-block;
#   border: solid 1px;
#   border-radius: 16px;
#   min-width: 14px;
#   padding: 5px 16px;
#   text-align: center;
#   user-select: none;
#   margin: 0 8px;
#   -webkit-tap-highlight-color: transparent;
# }
# .carousel {
#   overflow: auto;
#   scrollbar-width: none;
#   white-space: nowrap;
#   margin-right: -12px;
# }
# .headline {
#   display: flex;
#   margin-right: 4px;
# }
# .gradient-container {
#   position: relative;
# }
# .gradient {
#   position: absolute;
#   transform: translate(3px, -9px);
#   height: 36px;
#   width: 9px;
# }
# @media (prefers-color-scheme: light) {
#   .container {
#     background-color: #fafafa;
#     box-shadow: 0 0 0 1px #0000000f;
#   }
#   .headline-label {
#     color: #1f1f1f;
#   }
#   .chip {
#     background-color: #ffffff;
#     border-color: #d2d2d2;
#     color: #5e5e5e;
#     text-decoration: none;
#   }
#   .chip:hover {
#     background-color: #f2f2f2;
#   }
#   .chip:focus {
#     background-color: #f2f2f2;
#   }
#   .chip:active {
#     background-color: #d8d8d8;
#     border-color: #b6b6b6;
#   }
#   .logo-dark {
#     display: none;
#   }
#   .gradient {
#     background: linear-gradient(90deg, #fafafa 15%, #fafafa00 100%);
#   }
# }
# @media (prefers-color-scheme: dark) {
#   .container {
#     background-color: #1f1f1f;
#     box-shadow: 0 0 0 1px #ffffff26;
#   }
#   .headline-label {
#     color: #fff;
#   }
#   .chip {
#     background-color: #2c2c2c;
#     border-color: #3c4043;
#     color: #fff;
#     text-decoration: none;
#   }
#   .chip:hover {
#     background-color: #353536;
#   }
#   .chip:focus {
#     background-color: #353536;
#   }
#   .chip:active {
#     background-color: #464849;
#     border-color: #53575b;
#   }
#   .logo-light {
#     display: none;
#   }
#   .gradient {
#     background: linear-gradient(90deg, #1f1f1f 15%, #1f1f1f00 100%);
#   }
# }
# </style>
# <div class="container">
#   <div class="headline">
#     <svg class="logo-light" width="18" height="18" viewBox="9 9 35 35" fill="none" xmlns="http://www.w3.org/2000/svg">
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M42.8622 27.0064C42.8622 25.7839 42.7525 24.6084 42.5487 23.4799H26.3109V30.1568H35.5897C35.1821 32.3041 33.9596 34.1222 32.1258 35.3448V39.6864H37.7213C40.9814 36.677 42.8622 32.2571 42.8622 27.0064V27.0064Z" fill="#4285F4"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M26.3109 43.8555C30.9659 43.8555 34.8687 42.3195 37.7213 39.6863L32.1258 35.3447C30.5898 36.3792 28.6306 37.0061 26.3109 37.0061C21.8282 37.0061 18.0195 33.9811 16.6559 29.906H10.9194V34.3573C13.7563 39.9841 19.5712 43.8555 26.3109 43.8555V43.8555Z" fill="#34A853"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M16.6559 29.8904C16.3111 28.8559 16.1074 27.7588 16.1074 26.6146C16.1074 25.4704 16.3111 24.3733 16.6559 23.3388V18.8875H10.9194C9.74388 21.2072 9.06992 23.8247 9.06992 26.6146C9.06992 29.4045 9.74388 32.022 10.9194 34.3417L15.3864 30.8621L16.6559 29.8904V29.8904Z" fill="#FBBC05"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M26.3109 16.2386C28.85 16.2386 31.107 17.1164 32.9095 18.8091L37.8466 13.8719C34.853 11.082 30.9659 9.3736 26.3109 9.3736C19.5712 9.3736 13.7563 13.245 10.9194 18.8875L16.6559 23.3388C18.0195 19.2636 21.8282 16.2386 26.3109 16.2386V16.2386Z" fill="#EA4335"/>
#     </svg>
#     <svg class="logo-dark" width="18" height="18" viewBox="0 0 48 48" xmlns="http://www.w3.org/2000/svg">
#       <circle cx="24" cy="23" fill="#FFF" r="22"/>
#       <path d="M33.76 34.26c2.75-2.56 4.49-6.37 4.49-11.26 0-.89-.08-1.84-.29-3H24.01v5.99h8.03c-.4 2.02-1.5 3.56-3.07 4.56v.75l3.91 2.97h.88z" fill="#4285F4"/>
#       <path d="M15.58 25.77A8.845 8.845 0 0 0 24 31.86c1.92 0 3.62-.46 4.97-1.31l4.79 3.71C31.14 36.7 27.65 38 24 38c-5.93 0-11.01-3.4-13.45-8.36l.17-1.01 4.06-2.85h.8z" fill="#34A853"/>
#       <path d="M15.59 20.21a8.864 8.864 0 0 0 0 5.58l-5.03 3.86c-.98-2-1.53-4.25-1.53-6.64 0-2.39.55-4.64 1.53-6.64l1-.22 3.81 2.98.22 1.08z" fill="#FBBC05"/>
#       <path d="M24 14.14c2.11 0 4.02.75 5.52 1.98l4.36-4.36C31.22 9.43 27.81 8 24 8c-5.93 0-11.01 3.4-13.45 8.36l5.03 3.85A8.86 8.86 0 0 1 24 14.14z" fill="#EA4335"/>
#     </svg>
#     <div class="gradient-container"><div class="gradient"></div></div>
#   </div>
#   <div class="carousel">
#     <a class="chip" href="https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQFGwfO0XCYXW9dTOM8xyc67ULzFWs45nG2NdWwmSo-aeLmCKa2riZNO7pknXhIp2pO-JmF3DagBsxBx7uHSfeh7MWdBE9rLBzycXYQJ3mlQZwA7-HfAJ2i7tQBehRzY27o8F9Rsofux5GLtFs9W9ZTJM1_DqN_O1iALMjfpbeqR6QlEUBQdd0U5tNQAuBxgHvEfMx68qLchZ008BKW_I9ZZTcBYxuMIr6DFgA==">Michelin star restaurants San Francisco</a>
#     <a class="chip" href="https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQElxuDdYgorFU3IYfBVwCBpDrEbFUztIkk-Lunya9EUnvEfCLNc2L3zPScs5L14M-oUu0XTgjV35cNzrvQos53yAHDMYkcwdWS0H5Tk2li_MmJNYP1_d7jsLSrZj_dsyh4LEhKfrk0eUNX5h11FJ0iGJp1pmOQXqCphIuE8ncm5jXuj78Yob99bzHdGdbMWUkOPOSw4PZJ6NDFPxC4cfW5fIuD6MnVLZeVp87m6Z2U=">upcoming concerts San Francisco August 2025</a>
#     <a class="chip" href="https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQFyKbV10vDavFWb20wxQdjNClgJy8TRcDkgLnUMFXPBtMEjkDAbuQjXkkotierLkT7P3umapzoqb0IzbjohaDyJZuZIpoxZYZLdLFrapC_IlInL1FGc3qRpGIUcM-PC_NKJPqp4pQ0PneCvPar_pQfZNsEYZkeWg7ify5MWdBOvrRfJl6soVO7iLMmyO4mvDniqsh0aLi0HjUusoSq3za4n">best museums in San Francisco</a>
#     <a class="chip" href="https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQEEAd7ei70NqVQT1CdeaZET3OrnV-zrcvsYcv_-Glpd53yNci4yANLLjnl79zlvLXWiid7rmcWiqG7PC1anC3ziUp7kNVHylKGpmwv8qfjbU8X7H-Wl4QIPmIPHKJMbGgif-kWs-kJWlRNlwT0bhqRmSoNVVC8jGR_3zHadgCoBGc7aolFCFiBjzP8VdAvijbpHkxbmnwEAB1OWzHId2Ue5SDDjgg==">best restaurants in San Francisco</a>
#   </div>
# </div>
# """
#   ),
#   web_search_queries=[
#     'best museums in San Francisco',
#     'upcoming concerts San Francisco August 2025',
#     'best restaurants in San Francisco',
#     'Michelin star restaurants San Francisco',
#   ]
# ) partial=None turn_complete=None error_code=None error_message=None interrupted=None custom_metadata=None usage_metadata=GenerateContentResponseUsageMetadata(
#   candidates_token_count=46,
#   prompt_token_count=107,
#   prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=107
#     ),
#   ],
#   thoughts_token_count=1551,
#   tool_use_prompt_token_count=398,
#   tool_use_prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=398
#     ),
#   ],
#   total_token_count=2102
# ) live_session_resumption_update=None invocation_id='e-a62de101-4abf-47f2-88a4-1794d054948b' author='restaurant_finder_agent' actions=EventActions(skip_summarization=None, state_delta={'restaurant_result': 'Gary Danko'}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}) long_running_tool_ids=None branch='parallel_research_agent.restaurant_finder_agent' id='21023fb4-fcae-43a4-bf89-a89d47e39870' timestamp=1755966772.242919
# EVENT: content=Content(
#   parts=[
#     Part(
#       text="""Here is a plan for your trip to San Francisco, incorporating your preferences:
#
# *   **Museum:** California Academy of Sciences
# *   **Concert:** Snarky Puppy
# *   **Restaurant:** Gary Danko"""
#     ),
#   ],
#   role='model'
# ) grounding_metadata=None partial=None turn_complete=None error_code=None error_message=None interrupted=None custom_metadata=None usage_metadata=GenerateContentResponseUsageMetadata(
#   candidates_token_count=45,
#   prompt_token_count=141,
#   prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=141
#     ),
#   ],
#   thoughts_token_count=39,
#   total_token_count=225
# ) live_session_resumption_update=None invocation_id='e-a62de101-4abf-47f2-88a4-1794d054948b' author='synthesis_agent' actions=EventActions(skip_summarization=None, state_delta={}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}) long_running_tool_ids=None branch=None id='a7f57b80-f604-455a-8946-67bd894a4d48' timestamp=1755966790.194343
#
# --------------------------------------------------
# ✅ Final Response:
# Here is a plan for your trip to San Francisco, incorporating your preferences:
#
# *   **Museum:** California Academy of Sciences
# *   **Concert:** Snarky Puppy
# *   **Restaurant:** Gary Danko
# --------------------------------------------------
#
# --- parallel_planner_agent Complete ---

# %% [markdown]
# ---
# ## 🎉 Congratulations! 🎉
#
# You've completed the Enhanced ADK Adventure! You have successfully. Let's review the advanced orchestration patterns you've successfully implemented:
#
# - **The Router Pattern**: You built a master router agent capable of analyzing user intent and delegating tasks to the appropriate specialist agent or workflow.
#
# - **Sequential Workflows**: Using SequentialAgent, you elegantly chained agents together, creating clean, readable code for multi-step tasks without manual data handling.
#
# - **Iterative Refinement**: You constructed a sophisticated feedback loop with LoopAgent, enabling your agents to plan, self-critique, and improve their output until it met specific constraints.
#
# - **Parallel Power**: You maximized speed and efficiency by using ParallelAgent to run multiple research tasks concurrently, later synthesizing the results into a unified response.

# %% [markdown]
# ```
#    __            /\_/\         /\_/\        /\_/\         __             (\__/)
# o-''|\_____/).  ( o.o )       ( -.- )      ( ^_^ )     o-''|\_____/).    ( ^_^ )
#  \_/|_)     )    > ^ <         > * <        >💖<         \_/|_)     )     / >🌸< \
#     \  __  /                                              \  __  /         /   \
#     (_/ (_/                                               (_/ (_/        (___|___)
# ```
